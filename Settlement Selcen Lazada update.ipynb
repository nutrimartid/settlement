# %% [markdown]
# # Read Selcen

# %%
### run 1

import pandas as pd
import numpy as np
import os
import re

selcen = pd.DataFrame()
for i in os.listdir('Settlement Project\Lazada\Seller Centre/'):
    print(i)
    if '$' not in i:
        if 'csv' in i:
            temp = pd.read_csv('Settlement Project\Lazada\Seller Centre/' + str(i), sep = ';')
        elif 'xlsx' in i:
            temp = pd.read_excel('Settlement Project\Lazada\Seller Centre/' + str(i))
            test = [' '.join(re.sub( r"([A-Z])", r" \1", x).split()).title() for x in temp.columns]
            test = [str(x).replace('Sku', 'SKU') for x in test]
            temp.columns = test
            temp = temp.rename(columns = {'Create Time' : 'Created at'})
            temp = temp[~temp['Order Item Id'].isin(selcen['Order Item Id'])]
        temp['Source'] = i
        true_col = ['Order Item Id', 'Order Type', 'Order Flag', 'Lazada Id', 'Seller SKU', 'Lazada SKU', 'Created at', 'Updated at', 'Order Number', 'Invoice Required', 'Customer Name', 
                    'Customer Email', 'National Registration Number', 'Shipping Name', 'Shipping Address', 'Shipping Address2', 'Shipping Address3', 'Shipping Address4', 'Shipping Address5', 
                    'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping City', 'Shipping Postcode', 'Shipping Country', 'Shipping Region', 'Billing Name', 'Billing Address', 
                    'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing City', 'Billing Postcode', 
                    'Billing Country', 'Payment Method', 'Paid Price', 'Unit Price', 'Shipping Fee', 'Wallet Credits', 'Item Name', 'Variation', 'CD Shipping Provider', 'Shipping Provider', 
                    'Shipment Type Name', 'Shipping Provider Type', 'CD Tracking Code', 'Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)',
                    'Tracking URL (first mile)', 'Promised shipping time', 'Premium', 'Status', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID', 'Bundle Discount',
                    'Refund Amount', 'Source']
        if temp.columns.to_list() == true_col :
            print('Column sama')
        else :
            true_col2 = ['Order Item Id', 'Order Type', 'Guarantee', 'Delivery Type','Lazada Id', 'Seller SKU', 'Lazada SKU', 'Ware House', 'Created at','Update Time', 
                         'Rts Sla', 'Tts Sla', 'Order Number', 'Invoice Required','Invoice Number', 'Delivered Date', 'Customer Name', 'Customer Email',
                         'National Registration Number', 'Shipping Name', 'Shipping Address','Shipping Address2', 'Shipping Address3', 'Shipping Address4','Shipping Address5', 
                         'Shipping Phone', 'Shipping Phone2', 'Shipping City', 'Shipping Post Code', 'Shipping Country','Shipping Region', 'Billing Name', 'Billing Addr', 
                         'Billing Addr2','Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone','Billing Phone2', 'Billing City', 'Billing Post Code',
                         'Billing Country', 'Tax Code', 'Branch Number', 'Tax Invoice Requested','Pay Method', 'Paid Price', 'Unit Price', 'Seller Discount Total',
                         'Shipping Fee', 'Wallet Credit', 'Item Name', 'Variation','Cd Shipping Provider', 'Shipping Provider', 'Shipment Type Name','Shipping Provider Type', 
                         'Cd Tracking Code', 'Tracking Code','Tracking Url', 'Shipping Provider F M', 'Tracking Code F M','Tracking Url F M', 'Promised Shipping Time', 
                         'Premium', 'Status','Buyer Failed Delivery Return Initiator','Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail',
                         'Buyer Failed Delivery User Name', 'Bundle Id', 'Bundle Discount','Refund Amount', 'Source']
            if temp.columns.to_list() == true_col2 :
                print('Column sama')
            else:
                print('Column beda')
                print([x for x in true_col if x not in temp.columns.to_list()])
                print([x for x in temp.columns.to_list() if x not in true_col])
        selcen = selcen.append(temp, ignore_index = True, sort = False)
# Out:
# 04 Seller Centre-22-28 Apr Lazada.csv
# Column sama
# Seller Center Lazada 20230101-05.xlsx
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230111-15.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230116-20.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230121-25.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230126-31.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230201-05.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230206-10.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230211-15.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230216-20.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230221-23.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230224-28.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230301-05.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230306-10.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230311-15.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230316-20.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230321-23.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230324-28.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230329-31.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230401-05.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230406-10.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230411-15.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230416-20.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230421-23.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230424-28.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230429-30.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230501-05.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230506-10.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230511-15.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230516-20.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230521-25.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230521_25.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230526-31.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230601-05.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230606-10.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230611-15.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']
# Seller Center Lazada 20230616-20.xlsx
# Column beda
# ...
# Seller Center Lazada 20240606-10.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240611-15.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240616-20.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240621-25.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240626-30.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240701-05.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240706-10.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240711-15.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240716-20.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazada 20240721-22.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Semi Managed', 'Flexible Delivery Time', 'Seller Note']
# Seller Center Lazasa 20230106-10.xlsx
# Column beda
# ['Order Flag', 'Updated at', 'Shipping Phone Number', 'Shipping Phone Number2', 'Shipping Postcode', 'Billing Address', 'Billing Address2', 'Billing Address3', 'Billing Address4', 'Billing Address5', 'Billing Phone Number', 'Billing Phone Number2', 'Billing Postcode', 'Payment Method', 'Wallet Credits', 'CD Shipping Provider', 'CD Tracking Code', 'Tracking URL', 'Shipping Provider (first mile)', 'Tracking Code (first mile)', 'Tracking URL (first mile)', 'Promised shipping time', 'Cancel / Return Initiator', 'Reason', 'Reason Detail', 'Editor', 'Bundle ID']
# ['Guarantee', 'Delivery Type', 'Ware House', 'Update Time', 'Rts Sla', 'Tts Sla', 'Invoice Number', 'Delivered Date', 'Shipping Phone', 'Shipping Phone2', 'Shipping Post Code', 'Billing Addr', 'Billing Addr2', 'Billing Addr3', 'Billing Addr4', 'Billing Addr5', 'Billing Phone', 'Billing Phone2', 'Billing Post Code', 'Tax Code', 'Branch Number', 'Tax Invoice Requested', 'Pay Method', 'Seller Discount Total', 'Wallet Credit', 'Cd Shipping Provider', 'Cd Tracking Code', 'Tracking Url', 'Shipping Provider F M', 'Tracking Code F M', 'Tracking Url F M', 'Promised Shipping Time', 'Buyer Failed Delivery Return Initiator', 'Buyer Failed Delivery Reason', 'Buyer Failed Delivery Detail', 'Buyer Failed Delivery User Name', 'Bundle Id', 'Seller Note']

# %%
### for backup
selcen_ori = selcen.copy()

# %%
## for backup
selcen = selcen_ori.copy()

# %%
## for display
pd.options.display.max_columns = 150

# %%
## run 2
selcen = selcen.rename(columns = {'Seller SKU' : 'SKU'})
selcen['Qty. Invoiced'] = 1
# selcen['Total Pembayaran'] = selcen['Total Pembayaran'].astype(str).str.replace('Rp', '').str.replace('.', '', regex = False)

selcen['True datetime'] = pd.to_datetime(selcen['Created at'])

# indeks = selcen[selcen['True datetime'].isnull()].index.to_list()
# selcen['True datetime'][indeks] = pd.to_datetime(selcen['Created at'], format = '%Y %b %d %H:%M:%s', errors='coerce')


selcen['Year'] = selcen['True datetime'].dt.year.astype(int)
selcen['Month'] = selcen['True datetime'].dt.month_name()

# %%
## check sett month
selcen[['Year', 'Month']].drop_duplicates()
# Out:
#         Year      Month
# 0       2021      April
# 12881   2023    January
# 30184   2023   February
# 57481   2023      March
# 101338  2023      April
# 130680  2023        May
# 171685  2023       June
# 219307  2023       July
# 258176  2023     August
# 297066  2023  September
# 345993  2023    October
# 424581  2023   November
# 497361  2023   December
# 570230  2024    January
# 622847  2024   February
# 652650  2024      March
# 688059  2024      April
# 704896  2024        May
# 739649  2024       June
# 797513  2024       July

# %%
## run 3
selcen_new = selcen[selcen['Year'] > 2022]

# %%
## run 4
temp = selcen_new.groupby(['Order Item Id'], dropna = False)['Source'].nunique().gt(1).reset_index()
temp = temp[temp['Source'] == True]
# selcen_new[selcen_new['Order Item Id'].isin(temp['Order Item Id'])][['Order Item Id', 'SKU', 'Item Name', 'Qty. Invoiced', 'Source']].sort_values('Order Item Id')

# %%
## run 5 must null
selcen_new[selcen_new[['Order Item Id']].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [Order Item Id, Order Type, Order Flag, Lazada Id, SKU, Lazada SKU, Created at, Updated at, Order Number, Invoice Required, Customer Name, Customer Email, National Registration Number, Shipping Name, Shipping Address, Shipping Address2, Shipping Address3, Shipping Address4, Shipping Address5, Shipping Phone Number, Shipping Phone Number2, Shipping City, Shipping Postcode, Shipping Country, Shipping Region, Billing Name, Billing Address, Billing Address2, Billing Address3, Billing Address4, Billing Address5, Billing Phone Number, Billing Phone Number2, Billing City, Billing Postcode, Billing Country, Payment Method, Paid Price, Unit Price, Shipping Fee, Wallet Credits, Item Name, Variation, CD Shipping Provider, Shipping Provider, Shipment Type Name, Shipping Provider Type, CD Tracking Code, Tracking Code, Tracking URL, Shipping Provider (first mile), Tracking Code (first mile), Tracking URL (first mile), Promised shipping time, Premium, Status, Cancel / Return Initiator, Reason, Reason Detail, Editor, Bundle ID, Bundle Discount, Refund Amount, Source, Guarantee, Delivery Type, Ware House, Update Time, Rts Sla, Tts Sla, Invoice Number, Delivered Date, Shipping Phone, Shipping Phone2, Shipping Post Code, Billing Addr, Billing Addr2, Billing Addr3, Billing Addr4, Billing Addr5, Billing Phone, Billing Phone2, Billing Post Code, Tax Code, Branch Number, Tax Invoice Requested, Pay Method, Seller Discount Total, Wallet Credit, Cd Shipping Provider, Cd Tracking Code, Tracking Url, Shipping Provider F M, Tracking Code F M, Tracking Url F M, Promised Shipping Time, Buyer Failed Delivery Return Initiator, Buyer Failed Delivery Reason, Buyer Failed Delivery Detail, Buyer Failed Delivery User Name, ...]
# Index: []

# %%
## check duplicate file
selcen_new[selcen_new['Order Item Id'].duplicated()]['Source'].unique()
# Out:
# array([], dtype=object)

# %%
## run 6 must null
cek_dups = selcen_new[(selcen_new[['Order Item Id', 'SKU']].duplicated(keep = False)) & (selcen_new['SKU'].notnull())].groupby('SKU')['Item Name'].unique().reset_index()
( cek_dups.join( pd.DataFrame(cek_dups['Item Name'].to_list())
                 .add_prefix('array_') )
        .drop('Item Name', axis = 1) ).values
# Out:
# array([], shape=(0, 1), dtype=object)

# %%
## run 7
indeks = selcen_new[selcen_new['Item Name'] == "(Free Gift) 3pcs L-Men Protein Crunch BBQ Beef 20g"].index.to_list()
selcen_new['SKU'][indeks] = '(B)2309005305P3'

indeks = selcen_new[selcen_new['Item Name'] == 'Buy 2 Get 2 – HiLo School Chocolate RTD UHT 200ml (ED 6 bulan)'].index.to_list()
selcen_new['SKU'][indeks] = '(E)2101492P4'

indeks = selcen_new[selcen_new['Item Name'] == 'Tropicana Slim White Coffee 4 Sachet x 3 pcs - Kopi Susu Nikmat Tanpa Gula Pasir'].index.to_list()
selcen_new['SKU'][indeks] = '2104170164P3'

indeks = selcen_new[selcen_new['SKU'] == '(B)2309005300'].index.to_list()
selcen_new['SKU'][indeks] = '(B)2309005305'

indeks = selcen_new[selcen_new['SKU'] == '(B)1101665318'].index.to_list()
selcen_new['SKU'][indeks] = '(B)1101665104'
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py:1135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_values(indexer, value)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == "":
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
## run 8
temp2 = selcen_new.copy()

import time
import pandas as pd
import numpy as np
import math

import smtplib 
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
from smtplib import SMTP
import smtplib
import sys
import requests
import os
    
data_SKU = pd.read_excel(r"D:\1. Masterdata\SKU_File\data_SKU.xlsx")

s = requests.Session()
s.get("https://tatanama.pythonanywhere.com")
s.post("https://tatanama.pythonanywhere.com", data = {'username' : 'ecommerce', 'password' : 'ttnmecom24'})
r = s.get("https://tatanama.pythonanywhere.com/download")

with open(r"D:\1. Masterdata\SKU_File\Master tatanama.xlsx", 'wb') as output:
    output.write(r.content)

if os.path.isfile(r"D:\1. Masterdata\SKU_File\Master tatanama.xlsx") :    
    SKU_append = pd.read_excel(r"D:\1. Masterdata\SKU_File\Master tatanama.xlsx")
    SKU_append.columns = [x.replace('_', ' ') for x in SKU_append.columns]
    data_SKU = data_SKU[~data_SKU['SKU'].astype(str).isin(SKU_append['SKU'].astype(str))]
    data_SKU = data_SKU.append(SKU_append, ignore_index = True, sort = False)

to_excel = data_SKU.to_excel(r"D:\1. Masterdata\SKU_File\data_SKU.xlsx", index = False)

# data_SKU = SKU_append.copy()

data_SKU = SKU_append.append(data_SKU[data_SKU['SKU'].isin(temp2[~temp2['SKU'].isin(SKU_append['SKU'])]['SKU'].drop_duplicates().values)], ignore_index = True, sort = False)

# %%
### run 8.1
data_SKU['Real SKU'] = data_SKU['SKU'].astype(str)
dfalias=pd.DataFrame()
for i in [x for x in data_SKU if 'Alias SKU' in x]:
    dfaliastemp=data_SKU[data_SKU[i].notnull()][['Real SKU',i]].rename(columns={i:'SKU Alias'})
    # dfaliastemp['SKU Alias']=dfaliastemp['SKU Alias'].astype(str)
    dfalias=dfalias.append(dfaliastemp)
cek=temp2[~temp2['SKU'].isin(data_SKU['Real SKU'].unique())]['SKU'].unique()
# dfalias[dfalias['SKU Alias'].isin(cek)]
for i in cek:
    skualias=dfalias[dfalias['SKU Alias']==i]['Real SKU'].unique()[0]
    selcen_new.loc[selcen_new['SKU']==i,'SKU']=skualias
    # print(skualias)
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
## must null
# temp2[~temp2['SKU'].isin(data_SKU['SKU'])][['Order Number', 'Item Name', 'SKU']].drop_duplicates('SKU').values
## must null
selcen_new[~selcen_new['SKU'].isin(data_SKU['SKU'])][['Order Number', 'Item Name', 'SKU']].drop_duplicates('SKU').values
# Out:
# array([], shape=(0, 3), dtype=object)

# %%
## run 8.2

from datetime import datetime,timedelta
listjanjian=requests.get('https://event.l-men.com/apiv1?type=janjian')
for i in listjanjian.json():
    sku=i['realsku']
    print(sku)
    start=datetime.fromtimestamp(int(i['startdate']/1000)).replace(hour=0)
    end=datetime.fromtimestamp(int(i['enddate']/1000)).replace(hour=23)
    print(i['notes'])
    selcen_new.loc[(selcen_new['SKU']==sku)&(selcen_new['True datetime']>=start)&(selcen_new['True datetime']<end),'Pemilik Budget']=i['notes']
    print('=====')
    # print(str(datetime.fromtimestamp(int(i['enddate']/1000)).replace(hour=0)))
# Out:
# 2T00803164
# Launching tahap 2
# =====
# 2T00803164P3
# Launching tahap 2
# =====
# 2T02703229P2
# Launching
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# =====
# PT25T74
# Launching
# =====
# 2T02703229
# Launching tahap 2
# =====
# 2104115110
# Launching tahap 2
# =====
# 2104115110P2
# Launching tahap 2
# =====
# 2104148024
# Launching tahap 2
# =====
# 2104148024P2
# Launching tahap 2
# =====
# 1N01402250P24
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 2104010270
# Marketing
# =====
# 1101909331
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 2HF0114021
# Launching tahap 2
# =====
# 2101751112
# Marketing
# =====
# 2101751112P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101384106
# Internal
# =====
# 2101384106P3
# Internal
# =====
# 2105055180P2
# Internal
# =====
# 2104523105P3
# Internal
# =====
# 2104508105P3
# Internal
# =====
# 2104543105P3
# Internal
# =====
# 2104589105P3
# Internal
# =====
# 2104241210P2
# Internal
# =====
# 2106386249P24
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101151180
# Internal
# =====
# 2101150180
# Internal
# =====
# 2101200180
# Internal
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102900130
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2309005305P20
# Marketing
# =====
# 2T01813126P2
# Launching
# =====
# PH22T17
# Marketing
# =====
# PH22T41
# Marketing
# =====
# PH19H22
# Launching
# =====
# PH22H95G277
# Marketing
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2101845360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 2101888360
# Marketing
# =====
# PH19H103
# Launching
# =====
# PH35H103
# Launching
# =====
# 2305551028
# Launching
# =====
# 2HF0113021
# Launching tahap 2
# =====
# 2HF0112021
# Launching tahap 2
# =====
# 1N01402250P4
# Internal
# =====
# 1N01402250P24
# Internal
# =====
# 2T00803164
# Internal
# =====
# 2T00803164P2
# Internal
# =====
# 2T00803164P3
# Internal
# =====
# 1101686318
# Marketing
# =====
# 1101694318
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 2T00803164
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 1101618318P2
# Marketing
# =====
# 1101618318
# Marketing
# =====
# 2309005305
# Marketing
# =====
# 2309005305P5
# Marketing
# =====
# 2309005305P10
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# (E)2101469180
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 2T01402249P4
# Launching
# =====
# 2T01402249P24
# Launching
# =====
# 1100534034
# Launching
# =====
# 2HC0109021
# Launching tahap 2
# =====
# 2305551028
# Launching tahap 2
# =====
# PH19H22
# Marketing
# =====
# PH22T41
# Marketing
# =====
# PH22T17
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# 2T01813126
# Launching tahap 2
# =====
# 2T01813126P2
# Launching tahap 2
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900130
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2101150180
# Internal
# =====
# 2101151180
# Internal
# =====
# 2101200180
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2101150180P2
# Internal
# =====
# 2101151180P2
# Internal
# =====
# 2101200180P2
# Internal
# =====
# 2304097159
# Internal
# =====
# 2104394210P2
# Internal
# =====
# 2104394210
# Internal
# =====
# PT26T54
# Internal
# =====
# 2T01705164P2
# Launching
# =====
# 2305551028
# Launching tahap 2
# =====
# PH22H95G277
# Marketing
# =====
# 1101665318
# Marketing
# =====
# 1101677318
# Marketing
# =====
# 1101653318
# Marketing
# =====
# 1101618318
# Marketing
# =====
# 2HH0813443P2
# Launching
# =====
# 2HF0114021P2
# Marketing
# =====
# 2LL1402249P4
# Launching
# =====
# 2LL1402249P24
# Launching
# =====
# 2LM0801029
# Launching
# =====
# PL32L33
# Launching
# =====
# 2HF0114021
# Marketing
# =====
# 2101651195
# Marketing
# =====
# 2101651195P2
# Marketing
# =====
# 2101453195
# Marketing
# =====
# 2305551028
# Internal
# =====
# 2101453195P2
# Marketing
# =====
# 2101486195
# Marketing
# =====
# 2101486195P2
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# (E)1101505453
# Internal
# =====
# 2304051180
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2304008180
# Internal
# =====
# 2TA0102180
# Launching tahap 2
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102000180
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2102000180P2
# Internal
# =====
# 2102900130
# Internal
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 1N03301456
# Launching
# =====
# 2T01402249P24
# Launching tahap 2
# =====
# 2LM0801029
# Launching tahap 2
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2T01402249P24
# Internal
# =====
# 2106386249P24
# Internal
# =====
# 2106386249P12
# Internal
# =====
# 2101888360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 2101845360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2305551028P3
# Internal
# =====
# 2305551028
# Internal
# =====
# 2305507288
# Internal
# =====
# 2305545288
# Internal
# =====
# 2305559288
# Internal
# =====
# 2305584288
# Internal
# =====
# 2105028180P2
# Internal
# =====
# 1N01402250P24
# Internal
# =====
# 2LM0801029P2
# Marketing
# =====
# PT25T41
# Internal
# =====
# 2104228230P2
# Internal
# =====
# 2104251230P2
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2304097159
# Marketing
# =====
# 2T00805043P2
# Launching
# =====
# 2T00805043P2
# Launching tahap 2
# =====
# 2105028180P2
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2T01402249P24
# Internal
# =====
# 2304051180P2
# Marketing
# =====
# PL7(2)G26
# Internal
# =====
# PL25(2)G26
# Internal
# =====
# PL27(2)G26
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# PL6(2)L28L31
# Internal
# =====
# 2304558112P4
# Internal
# =====
# (E)2101907250P4
# Marketing
# =====
# (E)2101845360
# Marketing
# =====
# 2101478180
# Internal
# =====
# 2101452195
# Internal
# =====
# 2101452190
# Internal
# =====
# 2101466148
# Internal
# =====
# 2101485195
# Internal
# =====
# 2101485180
# Internal
# =====
# 2101524180
# Internal
# =====
# 2101551195
# Internal
# =====
# 2101551190
# Internal
# =====
# 2101551180
# Internal
# =====
# 2101500180
# Internal
# =====
# 2101500190
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101150180P2
# Internal
# =====
# 2101151180P2
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2T02703229P2
# Internal
# =====
# 1N00838454
# Launching
# =====
# 2101500195
# Internal
# =====
# 2101578180
# Internal
# =====
# 2101452180
# Internal
# =====
# 2304558112P4
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2101459180
# Internal
# =====
# 2101479180
# Internal
# =====
# 2101401180
# Internal
# =====
# 2101444180
# Internal
# =====
# 2101428180
# Internal
# =====
# 2101428180P2
# Internal
# =====
# 2101401180P2
# Internal
# =====
# PL25(2)G26
# Internal
# =====
# PL27(2)G26
# Internal
# =====
# PL7(2)G26
# Internal
# =====
# 2HC0112021P2
# Launching
# =====
# 2HG0103050P2
# Launching
# =====
# 2101584180
# Internal
# =====
# 2101478180P2
# Internal
# =====
# 2101452195P2
# Internal
# =====
# 2101452180P2
# Internal
# =====
# 2101452190P2
# Internal
# =====
# 2101466148P2
# Internal
# =====
# 2101485195P2
# Internal
# =====
# 2101485180P2
# Internal
# =====
# 2101524180P2
# Internal
# =====
# 2101551195P2
# Internal
# =====
# 2101551180P2
# Internal
# =====
# 2101551190P2
# Internal
# =====
# 2101500180P2
# Internal
# =====
# 2101500190P2
# Internal
# =====
# 2101500195P2
# Internal
# =====
# 2101578180P2
# Internal
# =====
# 2101584180P2
# Internal
# =====
# 2HC0112021
# Launching tahap 2
# =====
# 2HC0112021P2
# Launching tahap 2
# =====
# 2104406
# Marketing
# =====
# (E)1101693318
# Internal
# =====
# 2101845360
# Marketing
# =====
# 2101888360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2101710110
# Marketing
# =====
# 2101710110P2
# Marketing
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2306551173P2
# Marketing
# =====
# 2306551173
# Marketing
# =====
# 2304051180
# Internal
# =====
# 2304034180
# Internal
# =====
# 2304008180
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2304034180P2
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# (E)2309005305P20
# Marketing
# =====
# 2T01813126
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2T01814125P2
# Launching
# =====
# 1N01402250P24
# Internal
# =====
# 2T00806053P2
# Launching
# =====
# 2T00806053P2
# Launching
# =====
# 2T00806053P2
# Launching
# =====
# 2T01705024P2
# Launching
# =====
# 2HH0816450P2
# Launching
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Marketing
# =====
# 2HF0111003P3
# Marketing
# =====
# 2HG0103050P2
# Launching tahap 2
# =====
# (E)2101845360
# Marketing
# =====
# 2T01403249P24
# Launching
# =====
# 2T01403249P4
# Launching
# =====
# 2T00806053P2
# Launching tahap 2
# =====
# 2T01705024P2
# Launching tahap 2
# =====
# 2T01814125P2
# Launching tahap 2
# =====
# 2T01814125
# Launching tahap 2
# =====
# 2T01403249P24
# Launching tahap 2
# =====
# 2T01403249P4
# Launching tahap 2
# =====
# (E)2106317152P2
# Marketing
# =====
# (E)2106317152
# Marketing
# =====
# 2103300316
# Marketing
# =====
# PT79T81
# Internal
# =====
# 2305551028P3
# Internal
# =====
# (E)2101469180
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101466148
# Marketing
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Internal
# =====
# 2HF0111003P3
# Marketing
# =====
# 2106386249P24
# Internal
# =====
# 2106386249P12
# Internal
# =====
# 2T01402249P24
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2T01403249P12
# Internal
# =====
# 2T01403249P24
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2LG0906288
# Launching
# =====
# 2LG0906288
# Launching
# =====
# PH107(2)G331
# Marketing
# =====
# PT79T81
# Internal
# =====
# (E)2305551288P2
# Internal
# =====
# (E)2305551288P3
# Internal
# =====
# 1N00804229
# Launching
# =====
# 2T00804164P2
# Launching
# =====
# 2T01705024P2
# Internal
# =====
# 2HC0112021P2
# Internal
# =====
# 2HC0113021P2
# Launching
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2101609180
# Marketing
# =====
# 2104241210
# Marketing
# =====
# 2104153110
# Marketing
# =====
# LN00000002
# Marketing
# =====
# 2LG0906288
# Launching tahap 2
# =====
# 2104115110P2
# Marketing
# =====
# 2T01813126
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# PL32L33
# Internal
# =====
# PL6(2)L32
# Marketing
# =====
# (E)2104406P2
# Marketing
# =====
# (E)2104406
# Marketing
# =====
# PH106H109(2)G334
# Launching
# =====
# PH64H109(2)G334
# Launching
# =====
# 2305551028P3
# Internal
# =====
# (E)2101524180P2
# Marketing
# =====
# (E)2305551288
# Internal
# =====
# (E)2HF0112021
# Marketing
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Marketing
# =====
# 2HF0111003P3
# Marketing
# =====
# 2304051180
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# 2304008180
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304558112P4
# Internal
# =====
# 2T01402249P4
# Internal
# =====
# 2106386249P4
# Internal
# =====
# 2T01403249P4
# Internal
# =====
# 2LC0903181P2
# Launching
# =====
# 2LH1204172P2
# Launching
# =====
# 2T01813126
# Internal
# =====
# 2101700037
# Internal
# =====
# 2T02603203P2
# Launching
# =====
# 2HH1409249P4
# Launching
# =====
# 2HH1409249P24
# Launching
# =====
# (E)2101469180
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101466148
# Marketing
# =====
# (E)2LD0905181
# Internal
# =====
# (E)2LD0905181P2
# Internal
# =====
# PB121H107
# Launching
# =====
# PH107B23
# Launching
# =====
# 2HC0112021P2
# Internal
# =====
# 2HC0113021P2
# Launching
# =====
# 2HC0113021
# Launching tahap 2
# =====
# 2HG0103050
# Launching
# =====
# 2HH0817441P2
# Launching
# =====
# (E)2106317152P2
# Marketing
# =====
# 2103300316
# Marketing
# =====
# 2T02603203P2
# Launching tahap 2
# =====
# (E)2HF0112021
# Marketing
# =====
# (E)2101864443
# Marketing
# =====
# 2LC0903181
# Launching tahap 2
# =====
# 2LH1204172
# Launching tahap 2
# =====
# 2HH1409249P4
# Launching tahap 2
# =====
# 2HH1409249P24
# Launching tahap 2
# =====
# 2104405
# Marketing
# =====
# 2104405P2
# Marketing
# =====
# 2106023014P3
# Marketing
# =====
# (E)2LD0905181
# Marketing
# =====
# 2HH0817441
# Launching tahap 2
# =====
# 2305507288
# Internal
# =====
# 2305545288
# Internal
# =====
# 2101684195
# Launching
# =====
# 2305551028P3
# Internal
# =====
# 2T01812126
# Marketing
# =====
# 2T00805043
# Marketing
# =====
# 2HH1409249P4
# Marketing
# =====
# 2HH1409249P24
# Marketing
# =====
# 2HH1409249P24
# Launching tahap 2
# =====
# 2HH1409249P4
# Launching tahap 2
# =====
# 2T00806053
# Marketing
# =====
# 2T01705024
# Marketing
# =====
# 2104148024
# Marketing
# =====
# 2HC0112021
# Marketing
# =====
# 2106023014P1
# Marketing
# =====
# 2HC0113021
# Marketing
# =====
# 2105028180
# Marketing
# =====
# 2T03201001
# Marketing
# =====
# 2101609180
# Marketing
# =====
# 2104241210
# Marketing
# =====
# 2104394210
# Marketing
# =====
# 2102300105
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 1101182250P24
# Marketing
# =====
# 1N00838454
# Marketing
# =====
# 2LH1204172
# Marketing
# =====
# 1N03301456
# Marketing
# =====
# 2LH1204172
# Launching tahap 2
# =====
# 1N00804229
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 1101656318
# Marketing
# =====
# 2304515112
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 1101677318
# Marketing
# =====
# 2LM0801029
# Marketing
# =====
# 2T01403249P4
# Marketing
# =====
# 2T01403249P24
# Marketing
# =====
# 2T02603203
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 1101182250P4
# Marketing
# =====
# 2HG0103050
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 2304051180
# Marketing
# =====
# PL32L33
# Marketing
# =====
# PL30L32
# Marketing
# =====
# PL32L35
# Marketing
# =====
# PL6L32
# Marketing
# =====
# PL7L32
# Marketing
# =====
# 2101684195
# Launching tahap 2
# =====
# 2T01402249P4
# Marketing
# =====
# 2T01402249P24
# Marketing
# =====
# 2T01403249P4
# Marketing
# =====
# 2T01403249P24
# Marketing
# =====
# 2106386249P4
# Marketing
# =====
# 2106386249P24
# Marketing
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0113021P2
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2HF0112021P2
# Marketing
# =====
# 2HF0114021P2
# Marketing
# =====
# 2101699155P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T01813126P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00804164P2
# Marketing
# =====
# 2104405
# Marketing
# =====
# 2LM0801029
# Marketing
# =====
# PL6L32
# Marketing
# =====
# PL32L33
# Launching
# =====
# PL7L32
# Marketing
# =====
# PL32L35
# Marketing
# =====
# PL30L32
# Marketing
# =====
# 2T02604203P2
# Launching
# =====
# 2306551173
# Marketing
# =====
# 2LH1204172
# Marketing
# =====
# PT79T86(4)
# Launching
# =====
# 2HF0114021
# Marketing
# =====
# 2HF0114021P2
# Marketing
# =====
# 2T01813126P2
# Marketing
# =====
# 2T01813126
# Marketing
# =====
# LN00000002
# Marketing
# =====
# 2T01404249P4
# Launching
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00804164P2
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 2LG0908060
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2T01813126
# Marketing
# =====
# 2T00805043
# Marketing
# =====
# 2T00805043P2
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0114021
# Marketing
# =====
# 2T00805043P2
# Marketing
# =====
# 2T00804024P2
# Launching
# =====
# 2101452195
# Marketing
# =====
# 2101485195
# Marketing
# =====
# 2101651195
# Marketing
# =====
# 2101684195
# Marketing
# =====
# 2101453195
# Marketing
# =====
# 2101486195
# Marketing
# =====
# 2101500195
# Marketing
# =====
# 2101551195
# Marketing
# =====
# 2HC0113021
# Marketing
# =====
# 2T00806053P2
# Internal
# =====
# 2HC0112021
# Marketing
# =====
# 2HH1409249P4
# Marketing
# =====
# 2101751112
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2HG0103050
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 2HH0817441
# Marketing
# =====
# 2HC0112021P2
# Marketing
# =====
# 2HC0113021P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2HH1409249P24
# Marketing
# =====
# 2T02604203P2
# Launching tahap 2
# =====
# 2304097159
# Marketing
# =====
# 2T01404249P4
# Launching tahap 2
# =====
# 2T01404249P24
# Launching tahap 2
# =====
# 1N03302456
# Launching
# =====
# 2T02604203
# Launching tahap 2
# =====
# PT79T85
# Launching tahap 2
# =====
# 2304051288
# Launching
# =====
# PN125N150
# Launching
# =====
# 1102560453
# Launching
# =====
# 1N01402250P4
# Launching
# =====
# 1N01402250P24
# Launching
# =====
# PT79G342
# Internal
# =====
# PT79G343
# Internal
# =====
# 2T01705024P2
# Marketing
# =====
# 2T01705024P2
# Marketing
# =====
# 2304051288P2
# Launching
# =====
# 2304051288
# Launching tahap 2
# =====
# 1N00840454
# Launching
# =====
# 1N00840454
# Launching
# =====
# 1N00840454
# Launching
# =====
# 2HF0115003P2
# Launching
# =====
# 1101677104
# Launching
# =====
# 2T01705024
# Marketing
# =====
# 2104115110
# Marketing
# =====
# 2104115110P2
# Marketing
# =====
# 2T00803164
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 2104148024
# Marketing
# =====
# 2104148024P2
# Marketing
# =====
# 2104119110
# Marketing
# =====
# 2104119110P2
# Marketing
# =====
# 2T00804024
# Launching tahap 2
# =====
# 2T02604203
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2HC0113021P2
# Marketing
# =====
# 2HC0112021P2
# Marketing
# =====
# 2306551173
# Internal
# =====
# 2LH1204172
# Internal
# =====
# 1NC1710075
# Launching
# =====
# 1NC1711075
# Launching
# =====
# 2LC0903181
# Marketing
# =====
# 2LC0903181P2
# Marketing
# =====
# 2104119110
# Marketing
# =====
# 2104119110P2
# Marketing
# =====
# 2305507288
# Marketing
# =====
# 2305559288
# Marketing
# =====
# 2106395308
# Marketing
# =====
# 2106395308P2
# Marketing
# =====
# 2106395308P3
# Marketing
# =====
# 2102300105
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 2304008180P2
# Marketing
# =====
# 2106023014
# Marketing
# =====
# 2106023014P2
# Marketing
# =====
# 2106023014P3
# Marketing
# =====
# 2T02604203P2
# Internal
# =====
# 2T02604203
# Internal
# =====
# 1N00804229P2
# Marketing
# =====
# 2103300316
# Marketing
# =====
# 2HF0115003
# Launching tahap 2
# =====

# %%
## run 9
temp2 = selcen_new.copy()

temp2 = temp2.rename(columns = {'Nama Produk' : 'Item Name'})

data_SKU.loc[data_SKU['Price List NFI'].isin(['-']), 'Price List NFI'] = 0
data_SKU['Price List NFI'] = data_SKU['Price List NFI'].astype(float).astype('int64')

data_SKU['Real SKU'] = data_SKU['SKU'].astype(str)
data_SKU['Real Nama Produk'] = data_SKU['Nama Produk'].astype(str)

list_col = ['Real SKU', 'Real Nama Produk', 'Brand', 'Sub Brand']

temp_merge = temp2.merge(data_SKU[list_col].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU').set_index(temp2.index)
for i in list_col:
    temp2[i] = temp_merge[str(i)]
    
list_col = ['SKU'] + data_SKU.columns[data_SKU.columns.get_loc('Produk 1'):data_SKU.columns.get_loc('Harga Cost 7')+1].to_list()
temp_merge = temp2.merge(data_SKU[list_col].drop_duplicates(['SKU']), how = 'left', left_on = 'Real SKU', right_on = 'SKU').set_index(temp2.index)
list_pcs = [x for x in temp_merge.columns if 'PCS' in x]
for i in list_pcs:
    temp_merge[i] = temp_merge[i] * temp_merge['Qty. Invoiced']

list_col = data_SKU.columns[data_SKU.columns.get_loc('Produk 1'):data_SKU.columns.get_loc('Harga Cost 7')+1].to_list()    
for i in list_col:
    temp2[i] = temp_merge[str(i)]
    
list_col = ['Real SKU', 'Price List NFI', 'Harga Cost']

temp_merge = temp2.merge(data_SKU[list_col].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU').set_index(temp2.index)
for i in list_col:
    if i == 'Real SKU':
        temp2[i] = temp_merge[str(i) + '_y']
    else :
        temp2[i] = temp_merge[str(i)]
    
temp2['Price List NFI'] = pd.to_numeric(temp2['Price List NFI']).astype(int)
temp2['Harga Cost'] = pd.to_numeric(temp2['Harga Cost']).astype(int)
temp2['Qty. Invoiced'] = pd.to_numeric(temp2['Qty. Invoiced']).astype(int)

temp2['Total Net'] = temp2['Price List NFI'] * temp2['Qty. Invoiced']
temp2['Total Harga Cost'] = temp2['Harga Cost'] * temp2['Qty. Invoiced']
temp2['Total Net Before PPN'] = temp2['Total Net']/1.11

print("Unbundling")
data_bundle1 = temp2[~temp2['Produk 1'].isnull()]
data_bundle1['Bundle Name'] = data_bundle1['Item Name']
data_bundle1['Item Name'] = data_bundle1['Produk 1']
data_bundle1['SKU'] = data_bundle1['SKU Produk 1']
data_bundle1['Qty. Invoiced'] = data_bundle1['PCS Produk 1']
data_bundle1['Price List NFI'] = data_bundle1['Price List NFI 1']
data_bundle1['Total Net'] = data_bundle1['Price List NFI 1']
data_bundle1['Bundle Flag'] = np.nan

data_bundle2 = temp2[~temp2['Produk 2'].isnull()]
data_bundle2['Bundle Name'] = data_bundle2['Item Name']
data_bundle2['Item Name'] = data_bundle2['Produk 2']
data_bundle2['SKU'] = data_bundle2['SKU Produk 2']
data_bundle2['Qty. Invoiced'] = data_bundle2['PCS Produk 2']
data_bundle2['Price List NFI'] = data_bundle2['Price List NFI 2']
data_bundle2['Total Net'] = data_bundle2['Price List NFI 2'] 
data_bundle2['Bundle Flag'] = np.nan

data_bundle3 = temp2[~temp2['Produk 3'].isnull()]
data_bundle3['Bundle Name'] = data_bundle3['Item Name']
data_bundle3['Item Name'] = data_bundle3['Produk 3']
data_bundle3['SKU'] = data_bundle3['SKU Produk 3']
data_bundle3['Qty. Invoiced'] = data_bundle3['PCS Produk 3']
data_bundle3['Price List NFI'] = data_bundle3['Price List NFI 3']
data_bundle3['Total Net'] = data_bundle3['Price List NFI 3'] 
data_bundle3['Bundle Flag'] = np.nan

data_bundle4 = temp2[~temp2['Produk 4'].isnull()]
data_bundle4['Bundle Name'] = data_bundle4['Item Name']
data_bundle4['Item Name'] = data_bundle4['Produk 4']
data_bundle4['SKU'] = data_bundle4['SKU Produk 4']
data_bundle4['Qty. Invoiced'] = data_bundle4['PCS Produk 4']
data_bundle4['Price List NFI'] = data_bundle4['Price List NFI 4']
data_bundle4['Total Net'] = data_bundle4['Price List NFI 4'] 
data_bundle4['Bundle Flag'] = np.nan

data_bundle5 = temp2[~temp2['Produk 5'].isnull()]
data_bundle5['Bundle Name'] = data_bundle5['Item Name']
data_bundle5['Item Name'] = data_bundle5['Produk 5']
data_bundle5['SKU'] = data_bundle5['SKU Produk 5']
data_bundle5['Qty. Invoiced'] = data_bundle5['PCS Produk 5']
data_bundle5['Price List NFI'] = data_bundle5['Price List NFI 5']
data_bundle5['Total Net'] = data_bundle5['Price List NFI 5']
data_bundle5['Bundle Flag'] = np.nan

data_bundle6 = temp2[~temp2['Produk 6'].isnull()]
data_bundle6['Bundle Name'] = data_bundle6['Item Name']
data_bundle6['Item Name'] = data_bundle6['Produk 6']
data_bundle6['SKU'] = data_bundle6['SKU Produk 6']
data_bundle6['Qty. Invoiced'] = data_bundle6['PCS Produk 6']
data_bundle6['Price List NFI'] = data_bundle6['Price List NFI 6']
data_bundle6['Total Net'] = data_bundle6['Price List NFI 6']
data_bundle6['Bundle Flag'] = np.nan

data_bundle7 = temp2[~temp2['Produk 7'].isnull()]
data_bundle7['Bundle Name'] = data_bundle7['Item Name']
data_bundle7['Item Name'] = data_bundle7['Produk 7']
data_bundle7['SKU'] = data_bundle7['SKU Produk 7']
data_bundle7['Qty. Invoiced'] = data_bundle7['PCS Produk 7']
data_bundle7['Price List NFI'] = data_bundle7['Price List NFI 7']
data_bundle7['Total Net'] = data_bundle7['Price List NFI 7']
data_bundle7['Bundle Flag'] = np.nan

data_bundle = data_bundle1.append([data_bundle2, data_bundle3, data_bundle4, data_bundle5, data_bundle6, data_bundle7], ignore_index = True, sort = False)
data_bundle['SKU'] = data_bundle['SKU'].astype(str)
data_bundle['SKU'] = data_bundle['SKU'].str.replace('\.0$', '', regex = True)
data_bundle[['Real SKU', 'Real Nama Produk', 'Brand', 'Sub Brand', 'Parent Item', 'Parent SKU']] = data_bundle.merge(data_SKU[['Real SKU', 'Nama Produk', 'Brand', 'Sub Brand', 'Parent Item', 'Parent SKU']].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU')[['Real SKU_y', 'Nama Produk', 'Brand_y', 'Sub Brand_y', 'Parent Item', 'Parent SKU']]

list_col = ['Real SKU', 'Price List NFI', 'Harga Cost']

data_bundle = data_bundle.drop(['Price List NFI', 'Harga Cost'], axis = 1)

temp_merge = data_bundle.merge(data_SKU[list_col].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU').set_index(data_bundle.index)
for i in list_col:
    if i == 'Real SKU':
        data_bundle[i] = temp_merge[str(i) + '_y']
    else :
        data_bundle[i] = temp_merge[str(i)]

data_bundle['Price List NFI'] = pd.to_numeric(data_bundle['Price List NFI']).astype(int)
data_bundle['Harga Cost'] = pd.to_numeric(data_bundle['Harga Cost']).astype(int)
data_bundle['Qty. Invoiced'] = pd.to_numeric(data_bundle['Qty. Invoiced']).astype(int)

data_bundle['Total Net'] = data_bundle['Price List NFI'] * data_bundle['Qty. Invoiced']
data_bundle['Total Harga Cost'] = data_bundle['Harga Cost'] * data_bundle['Qty. Invoiced']
data_bundle['Total Net Before PPN'] = data_bundle['Total Net']/1.11

for i in ['Unit Price', 'Paid Price', 'Shipping Fee']:
    data_bundle[i] = data_bundle[i].fillna(0) * data_bundle['Total Net Before PPN']/data_bundle.groupby(['Order Number', 'Bundle Name'])['Total Net Before PPN'].transform('sum')

print("Pricing")
temp2 = temp2.append(data_bundle, ignore_index = True, sort = False)

temp2['Price List NFI'] = pd.to_numeric(temp2['Price List NFI']).astype(int)
temp2['Harga Cost'] = pd.to_numeric(temp2['Harga Cost']).astype(int)
temp2['Qty. Invoiced'] = pd.to_numeric(temp2['Qty. Invoiced']).astype(int)

temp2['Total Net'] = temp2['Price List NFI'] * temp2['Qty. Invoiced']
temp2['Total Harga Cost'] = temp2['Harga Cost'] * temp2['Qty. Invoiced']
temp2['Total Net Before PPN'] = temp2['Total Net']/1.11
# Out:
# Unbundling
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Pricing

# %%
## run 10
selcen_sku = temp2.copy()

# %%
## run 11
j_conv = pd.read_excel("Settlement Project\Rumus Realisasi.xlsx", sheet_name = 'Paket Brand')
j_conv = j_conv.iloc[:,:5]
j_conv = j_conv.rename(columns = {'SKU' : 'Real SKU', 'SKU.1' : 'SKU Produk'})
j_conv = j_conv[j_conv['Real SKU'].notnull()]
j_conv['SKU Produk'] = j_conv['SKU Produk'].astype(str).str.replace('.0', '',regex = False)

temp_all = selcen_sku.copy()

temp_all['Real SKU'] = temp_all['Real SKU'].astype(str)
j_conv['Real SKU'] = j_conv['Real SKU'].astype(str)

temp_all = temp_all.merge(j_conv, how = 'left', on = 'Real SKU')

paket_j = temp_all[temp_all['SKU Produk'].notnull()]

paket_j['Bundle Name'] = paket_j['Item Name']
paket_j['Item Name'] = paket_j['Name']
paket_j['SKU'] = paket_j['SKU Produk']
paket_j['Qty. Invoiced'] = paket_j['Qty. Invoiced'] * paket_j['Konversi ke UOM'].astype(float)
paket_j['Bundle Flag'] = np.nan

import time
import pandas as pd
import numpy as np
import math

import smtplib 
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
from smtplib import SMTP
import smtplib
import sys
import requests
import os
    

print('A')
data_SKU = pd.read_excel(r'D:\1. Masterdata\SKU_File\data_SKU.xlsx')
print('A')
s = requests.Session()
s.get("https://tatanama.pythonanywhere.com")
s.post("https://tatanama.pythonanywhere.com", data = {'username' : 'ecommerce', 'password' : 'ttnmecom24'})
r = s.get("https://tatanama.pythonanywhere.com/download")

with open(r'D:\1. Masterdata\SKU_File\Master tatanama.xlsx', 'wb') as output:
    output.write(r.content)

if os.path.isfile(r'D:\1. Masterdata\SKU_File\Master tatanama.xlsx') :    
    SKU_append = pd.read_excel(r'D:\1. Masterdata\SKU_File\Master tatanama.xlsx')
    SKU_append.columns = [x.replace('_', ' ') for x in SKU_append.columns]
    data_SKU = data_SKU[~data_SKU['SKU'].astype(str).isin(SKU_append['SKU'].astype(str))]
    data_SKU = data_SKU.append(SKU_append, ignore_index = True, sort = False)
    
data_SKU['Real SKU'] = data_SKU['SKU'].astype(str)
data_SKU['Real Nama Produk'] = data_SKU['Nama Produk'].astype(str)
if 'Real SKU_y' in paket_j.columns:
    paket_j = paket_j.drop('Real SKU_y', axis = 1)
paket_j['SKU'] = paket_j['SKU'].astype(str)
paket_j[['Real SKU', 'Real Nama Produk', 'Brand', 'Sub Brand', 'Parent Item', 'Parent SKU', 'Price List NFI']] = paket_j.merge(data_SKU[['Real SKU', 'Nama Produk', 'Brand', 'Sub Brand', 'Parent Item', 'Parent SKU', 'Price List NFI']].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU').set_index(paket_j.index)[['Real SKU_y', 'Nama Produk', 'Brand_y', 'Sub Brand_y', 'Parent Item_y', 'Parent SKU_y', 'Price List NFI_y']]

paket_j['Price List NFI']=paket_j['Price List NFI'].astype(int)
paket_j['Total Net'] = paket_j['Price List NFI'] * paket_j['Qty. Invoiced']

for i in ['Unit Price', 'Paid Price', 'Shipping Fee']:
    paket_j[i] = paket_j[i] * paket_j['Total Net']/paket_j.groupby(['Order Number', 'Bundle Name'])['Total Net'].transform('sum')

paket_j = paket_j.drop(['Nama Paket', 'SKU Produk', 'Name', 'Konversi ke UOM'], axis = 1)
selcen_sku = selcen_sku.append(paket_j, ignore_index = True, sort = False)
indeks = selcen_sku[selcen_sku['Item Name'].isin(paket_j['Bundle Name'])].index.to_list()
selcen_sku['Brand'][indeks] = 'Bundle'
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# A
# A
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run for check, jika ingin di unbundling isi rumus realisasi xlsx sheet paket brand
selcen_sku[(selcen_sku['Real SKU'].str.contains('J'))&~(selcen_sku['Real SKU'].isin(j_conv['Real SKU'].unique()))][['Real SKU','Real Nama Produk']].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [Real SKU, Real Nama Produk]
# Index: []

# %%
## run 12
indeks = selcen_sku[(selcen_sku['Real SKU'].astype(str).str.contains('^\(B\)', regex = True)) &
      (~selcen_sku['Brand'].isin(['Bonus Produk', 'Gimmick']))].index.to_list()

selcen_sku['Brand'][indeks] = 'Bonus Produk'

indeks = selcen_sku[(selcen_sku['Real SKU'].astype(str).str.contains('^\(U\)', regex = True)) &
      (~selcen_sku['Brand'].isin(['Bonus Produk', 'Gimmick']))].index.to_list()

selcen_sku['Brand'][indeks] = 'Bonus Produk'
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# # Old NFI

# %%
## run 13
# source = pd.read_csv("D:\Backup\Backup 26 Mei\Settlement Project Backup\Realisasi Januari 2022\Final Result\Runningan Lazada Jan 2021 - Jan 2022 Real.csv", sep = ';')
source = pd.read_csv(r"D:\6. settlement\Code\Settlement Project\Backup\Realisasi Juni 2022\Final Result\Raw Unpivoted\CSV\Running Lazada By Selcen Jan 2022 - Jun 2022.csv", sep = ';')

source['True datetime'] = pd.to_datetime(source['True datetime'])
source = source[(source['Year'] > 2021) & (source['True datetime']<'2022-02-01')]

selcen_sku['Order Number'] = selcen_sku['Order Number'].astype(str).str.replace('.0', '', regex = False)
source['Order #'] = source['Order #'].astype(str).str.replace('.0', '', regex = False)

selcen_old = selcen_sku[selcen_sku['Order Number'].isin(source['Order #'])]

indeks = selcen_old[(selcen_old['Bundle Name'].astype(str).str.contains('-Rasa', regex = False)) & ~(selcen_old['Bundle Name'].astype(str).str.contains(' -Rasa', regex = False))].index.to_list()
selcen_old['Bundle Name'][indeks] = selcen_old['Bundle Name'].astype(str).str.replace('-Rasa', ' - Rasa', regex = False)

indeks = selcen_old[(selcen_old['Bundle Name'].astype(str).str.contains('-Flavor', regex = False)) & ~(selcen_old['Bundle Name'].astype(str).str.contains(' -Flavor', regex = False))].index.to_list()
selcen_old['Bundle Name'][indeks] = selcen_old['Bundle Name'].astype(str).str.replace('-Flavor', ' - Flavor', regex = False)

source['Product Name'] = source['Product Name'].fillna(source['Real Nama Produk'])

selcen_old_merge = selcen_old.merge(source[['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Price List NFI', 'Qty. Invoiced']].drop_duplicates(['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced']), how = 'left', left_on = ['Order Number', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'], right_on = ['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced']) 

selcen_old_null = selcen_old_merge[selcen_old_merge['Price List NFI_y'].isnull()]

selcen_old_null = selcen_old_null.drop(['Order #', 'Price List NFI_y'], axis = 1)
selcen_old_null = selcen_old_null.rename(columns = {'Price List NFI_x' : 'Price List NFI'})

selcen_old_null = selcen_old_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Price List NFI']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name', 'Price List NFI']), how = 'left', left_on = ['Order Number', 'Item Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(selcen_old_null.index) 
selcen_old_merge['Price List NFI_y'][selcen_old_null.index] = selcen_old_null['Price List NFI_y']

selcen_old_null = selcen_old_merge[selcen_old_merge['Price List NFI_y'].isnull()]

selcen_old_null = selcen_old_null.drop(['Order #', 'Price List NFI_y'], axis = 1)
selcen_old_null = selcen_old_null.rename(columns = {'Price List NFI_x' : 'Price List NFI'})

selcen_old_null = selcen_old_null.merge(source[['Order #', 'Real SKU', 'Bundle Name', 'Price List NFI']].drop_duplicates(['Order #', 'Real SKU', 'Bundle Name', 'Price List NFI']), how = 'left', left_on = ['Order Number', 'Real SKU',  'Bundle Name'], right_on = ['Order #', 'Real SKU', 'Bundle Name']).set_index(selcen_old_null.index) 
selcen_old_merge['Price List NFI_y'][selcen_old_null.index] = selcen_old_null['Price List NFI_y']

# selcen_old_null = selcen_old_merge[selcen_old_merge['Price List NFI_y'].isnull()]

# source2 = source.copy()

# # source2['Real SKU'] = source2['Real SKU'].astype(str).str.replace('2309005305', '2309005300')

# # indeks = source2[source2['Real SKU'] == '(B)2101809250'].index.to_list()
# # source2['Real SKU'][indeks] = '(U)2101809250'

# # indeks = source2[source2['Real SKU'] == 'PH48(3)B35'].index.to_list()
# # source2['Real SKU'][indeks] = '2101941250P4'

# # indeks = source2[source2['Real SKU'] == 'PH39(3)B17'].index.to_list()
# # source2['Real SKU'][indeks] = '2101809250P4'

# selcen_old_null = selcen_old_null.drop(['Order #', 'Price List NFI_y'], axis = 1)
# selcen_old_null = selcen_old_null.rename(columns = {'Price List NFI_x' : 'Price List NFI'})

# selcen_old_null = selcen_old_null.merge(source2[['Order #', 'Real SKU', 'Bundle Name', 'Price List NFI']].drop_duplicates(['Order #', 'Real SKU', 'Bundle Name']), how = 'left', left_on = ['Order Number', 'Real SKU',  'Bundle Name'], right_on = ['Order #', 'Real SKU', 'Bundle Name']).set_index(selcen_old_null.index) 

# selcen_old_merge['Price List NFI_y'][selcen_old_null.index] = selcen_old_null['Price List NFI_y']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order #'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22348\812401125.py in <module>
#       7
#       8 selcen_sku['Order Number'] = selcen_sku['Order Number'].astype(str).str.replace('.0', '', regex = False)
# ----> 9 source['Order #'] = source['Order #'].astype(str).str.replace('.0', '', regex = False)
#      10
#      11 selcen_old = selcen_sku[selcen_sku['Order Number'].isin(source['Order #'])]
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Order #'

# %%
## run 14
selcen_old_merge[(selcen_old_merge['Price List NFI_y'].isnull()) & (selcen_old_merge['Status'] != 'canceled')][['Order Number', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced', 'Status']]['Bundle Name'].unique()
# Out:
# array([], dtype=object)

# %%
## run 15
selcen_old_merge = selcen_old_merge.drop(['Price List NFI_x', 'Order #'], axis = 1)
selcen_old_merge = selcen_old_merge.rename(columns = {'Price List NFI_y' : 'Price List NFI'})

selcen_old_merge['Price List NFI'] = pd.to_numeric(selcen_old_merge['Price List NFI']).astype(float)
selcen_old_merge['Qty. Invoiced'] = pd.to_numeric(selcen_old_merge['Qty. Invoiced']).astype(float)

selcen_old_merge['Total Net'] = selcen_old_merge['Price List NFI'] * selcen_old_merge['Qty. Invoiced']

selcen_sku = selcen_sku[~selcen_sku['Order Number'].isin(selcen_old_merge['Order Number'])]
selcen_sku = selcen_sku.append(selcen_old_merge, ignore_index = True, sort = False)

selcen_sku['Total Net Before PPN'] = selcen_sku['Total Net']/1.11

# %%
selcen_sku['Total Net Before PPN'] = selcen_sku['Total Net']/1.11

# %%
## run 16
indeks = selcen_sku[(selcen_sku['Item Name'].astype(str).str.contains('-Flavor', regex = False)) & ~(selcen_sku['Item Name'].astype(str).str.contains(' -Flavor', regex = False))].index.to_list()
selcen_sku['Item Name'][indeks] = selcen_sku['Item Name'].astype(str).str.replace('-Flavor', ' - Flavor', regex = False)

indeks = selcen_sku[(selcen_sku['Item Name'].astype(str).str.contains('-Rasa', regex = False)) & ~(selcen_sku['Item Name'].astype(str).str.contains(' -Rasa', regex = False))].index.to_list()
selcen_sku['Item Name'][indeks] = selcen_sku['Item Name'].astype(str).str.replace('-Rasa', ' - Rasa', regex = False)

indeks = selcen_sku[(selcen_sku['Bundle Name'].astype(str).str.contains('-Rasa', regex = False)) & ~(selcen_sku['Bundle Name'].astype(str).str.contains(' -Rasa', regex = False))].index.to_list()
selcen_sku['Bundle Name'][indeks] = selcen_sku['Bundle Name'].astype(str).str.replace('-Rasa', ' - Rasa', regex = False)

indeks = selcen_sku[(selcen_sku['Bundle Name'].astype(str).str.contains('-Flavor', regex = False)) & ~(selcen_sku['Bundle Name'].astype(str).str.contains(' -Flavor', regex = False))].index.to_list()
selcen_sku['Bundle Name'][indeks] = selcen_sku['Bundle Name'].astype(str).str.replace('-Flavor', ' - Flavor', regex = False)
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == "":

# %% [markdown]
# # Fulfillment

# %%
## run 17
wms = pd.DataFrame()
rencol=pd.read_excel("Settlement Project\Lazada\dict_col_fulfiment.xlsx")
for i in os.listdir('Settlement Project\Lazada\Fulfillment/'):
    print(i)
    temp = pd.read_excel('Settlement Project\Lazada\Fulfillment/' + str(i))
    if 'datareport/Customer Order No.' in temp.columns:
        temp=temp.rename(columns=dict(rencol.values)) 
    temp['Source'] = i
    true_col = ['Customer Order No.', 'Order Time', 'Update Time', 'Number of SKUs', 'Platform SKU', 'Seller SKU', 'Platform SKU Name', 'Number of Items', 'Delivery Type', 
                'Update Time.1', 'Status', 'Platform', 'Source']
    if 'Customer Order No.' in wms.columns:
        temp = temp[~temp['Customer Order No.'].isin(wms['Customer Order No.'])]
    if temp.columns.to_list() == true_col :
        print('Column sama')
    else:
        print('Column beda')
        
        print([x for x in true_col if x not in temp.columns.to_list()])
        print([x for x in temp.columns.to_list() if x not in true_col])
    wms = wms.append(temp, ignore_index = True, sort = False)
# Out:
# fulfillment-sales-report-export-20231109-11.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export-20231112-15.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export-20231116-23.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export-20231124-30.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export-20231201-08.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export-20231209-15.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export-20231216-22.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export-20231223-28.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202301.xlsx
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202302.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202303.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202304.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202305.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202306 part 2.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202306.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202307.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202308.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202309.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202310-part 2.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202310.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202311.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202401.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202402.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202403.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202404.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export202405.xlsx
# Column beda
# ['Number of SKUs']
# []
# fulfillment-sales-report-export2112312250091409402-11-0113.xlsx
# Column sama
# fulfillment-sales-report-export2112312252318785810-11-1430.xlsx
# Column sama

# %%
## run 18
temp = wms.groupby(['Customer Order No.'], dropna = False)['Source'].nunique().gt(1).reset_index()
temp = temp[temp['Source'] == True]
wms[wms['Customer Order No.'].isin(temp['Customer Order No.'])].sort_values('Customer Order No.')
# temp
# Out:
# Empty DataFrame
# Columns: [Customer Order No., Order Time, Update Time, Platform SKU, Seller SKU, Platform SKU Name, Number of Items, Delivery Type, Update Time.1, Status, Platform, Source, Number of SKUs]
# Index: []

# %%
## for backup
wms_ori = wms.copy()
# wms_ori2 = wms.copy()

# %%
## for backup
wms = wms_ori.copy()

# %%
## run 19
wms = wms.rename(columns = {'Seller SKU' : 'Real SKU'})

# %%
# wms[(wms['Real SKU'] == 'NON DATA') & (wms['Number of Items'] > 1)].sort_values('Order Time').drop_duplicates('Platform SKU Name')

# %%
# wms[(wms['Real SKU'].astype(str).str.contains('P')) & (wms['Customer Order No.'].isin(selcen_sku['Order Number']))& (wms['Number of Items'] > 1)].sort_values('Order Time')

# %%
## run 20
wms_non = wms[(wms['Real SKU'] == 'NON DATA') | (wms['Real SKU'].isnull())]
wms_data = wms[wms['Real SKU'] != 'NON DATA']

indeks = wms_data[wms_data['Real SKU'] == '(E)1101984453-1'].index.to_list()
wms_data['Real SKU'][indeks] = '(E)1101984453'
indeks = wms_data[wms_data['Real SKU'] == '2104148164PX'].index.to_list()
wms_data['Real SKU'][indeks] = '2104148164P2'
wms_data[~wms_data['Real SKU'].isin(data_SKU['SKU'])]

### yang non akan di handle belakangan dont panic wkwkw
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py:1135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_values(indexer, value)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#         Customer Order No.           Order Time          Update Time  \
# 0         1294641057195194  2023-11-11 22:47:04  2023-11-16 11:53:01
# 10        1294630859512114  2023-11-11 22:47:30  2023-11-14 11:04:28
# 46        1306094183328933  2023-11-11 22:25:13  2023-11-14 16:52:06
# 48        1306183106207105  2023-11-11 22:37:46  2023-11-15 10:44:40
# 52        1306183106207105  2023-11-11 22:37:46  2023-11-15 10:44:40
# ...                    ...                  ...                  ...
# 279875    1443406928423396  2024-05-01 14:39:10  2024-05-03 17:17:54
# 279922    1443142542149161  2024-05-01 08:37:09  2024-05-03 22:04:53
# 279931    1430097232338121  2024-05-01 11:45:09  2024-05-03 19:17:24
# 279954    1429949243929450  2024-05-01 07:12:15  2024-05-04 17:26:29
# 279978    1442990162964752  2024-04-30 23:16:06  2024-05-02 15:55:11
#
#                       Platform SKU      Real SKU  \
# 0        7575362707_ID-13985534650           NaN
# 10       7811326146_ID-14261226942           NaN
# 46       7650456226_ID-14058462162           NaN
# 48       7650456226_ID-14058462162           NaN
# 52       7485274322_ID-13899402008           NaN
# ...                            ...           ...
# 279875   8039502077_ID-14460978502  2304051151V1
# 279922   7696796751_ID-14149252146           NaN
# 279931   6618460567_ID-12586650720  2101609180V1
# 279954  HI108TBAA2NZ2BANID-4911183           NaN
# 279978  HI108TBAA2NZ2BANID-4911183           NaN
#
#                                         Platform SKU Name  Number of Items  \
# 0       HiLo Teen+ Collagen Mix Berries Club 400g - Su...                2
# 10      HiLo Teen HI PROTEIN Melon 400g – Susu Tinggi ...                2
# 46      Tropicana Slim 7 Fruits Fiber Daily 12 Sachet ...                2
# 48      Tropicana Slim 7 Fruits Fiber Daily 12 Sachet ...                1
# 52      Tropicana Slim Collagen Drink Strawberry 200g ...                1
# ...                                                   ...              ...
# 279875  L-Men Gain Mass Chocolate 225g - 19g Whey Prot...                1
# 279922  BUY 2 GET 2 - Tropicana Slim Oat Drink Japanes...                3
# 279931  HiLo Teen Taro 500g - Susu Tinggi Kalsium Lebi...                1
# 279954  HiLo Teen Yoghurt Banana 250gr - Susu Tinggi K...                4
# 279978  HiLo Teen Yoghurt Banana 250gr - Susu Tinggi K...                2
#
#        Delivery Type        Update Time.1     Status Platform  \
# 0           STANDARD  2023-11-16 11:53:01  Delivered   LAZADA
# 10          STANDARD  2023-11-14 11:04:28  Delivered   LAZADA
# 46          STANDARD  2023-11-14 16:52:06  Delivered   LAZADA
# 48          STANDARD  2023-11-15 10:44:40  Delivered   LAZADA
# 52          STANDARD  2023-11-15 10:44:40  Delivered   LAZADA
# ...              ...                  ...        ...      ...
# 279875      STANDARD  2024-05-03 17:17:54  Delivered   LAZADA
# 279922       ECONOMY  2024-05-03 22:04:53  Delivered   LAZADA
# 279931       ECONOMY  2024-05-03 19:17:24  Delivered   LAZADA
# 279954      STANDARD  2024-05-04 17:26:29  Delivered   LAZADA
# 279978      STANDARD  2024-05-02 15:55:11  Delivered   LAZADA
#
#                                                   Source  Number of SKUs
# 0       fulfillment-sales-report-export-20231109-11.xlsx             NaN
# 10      fulfillment-sales-report-export-20231109-11.xlsx             NaN
# 46      fulfillment-sales-report-export-20231109-11.xlsx             NaN
# 48      fulfillment-sales-report-export-20231109-11.xlsx             NaN
# 52      fulfillment-sales-report-export-20231109-11.xlsx             NaN
# ...                                                  ...             ...
# 279875        fulfillment-sales-report-export202405.xlsx             NaN
# 279922        fulfillment-sales-report-export202405.xlsx             NaN
# 279931        fulfillment-sales-report-export202405.xlsx             NaN
# 279954        fulfillment-sales-report-export202405.xlsx             NaN
# 279978        fulfillment-sales-report-export202405.xlsx             NaN
#
# [7016 rows x 13 columns]

# %%
## run 21
import time
import pandas as pd
import numpy as np
import math

import smtplib 
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
from smtplib import SMTP
import smtplib
import sys
import requests
import os
    

list_col = ['SKU'] + data_SKU.columns[data_SKU.columns.get_loc('Produk 1'):data_SKU.columns.get_loc('Harga Cost 7')+1].to_list()
wms_data = wms_data.merge(data_SKU[list_col].drop_duplicates(['SKU']), how = 'left', left_on = 'Real SKU', right_on = 'SKU')
list_pcs = [x for x in wms_data.columns if 'PCS' in x]
for i in list_pcs:
    wms_data[i] = wms_data[i] * wms_data['Number of Items']

print("Unbundling")
data_bundle1 = wms_data[~wms_data['Produk 1'].isnull()]
data_bundle1['Real SKU'] = data_bundle1['SKU Produk 1']
data_bundle1['Number of Items'] = data_bundle1['PCS Produk 1']

data_bundle2 = wms_data[~wms_data['Produk 2'].isnull()]
data_bundle2['Real SKU'] = data_bundle2['SKU Produk 2']
data_bundle2['Number of Items'] = data_bundle2['PCS Produk 2']

data_bundle3 = wms_data[~wms_data['Produk 3'].isnull()]
data_bundle3['Real SKU'] = data_bundle3['SKU Produk 3']
data_bundle3['Number of Items'] = data_bundle3['PCS Produk 3']

data_bundle4 = wms_data[~wms_data['Produk 4'].isnull()]
data_bundle4['Real SKU'] = data_bundle4['SKU Produk 4']
data_bundle4['Number of Items'] = data_bundle4['PCS Produk 4']

data_bundle5 = wms_data[~wms_data['Produk 5'].isnull()]
data_bundle5['Real SKU'] = data_bundle5['SKU Produk 5']
data_bundle5['Number of Items'] = data_bundle5['PCS Produk 5']

data_bundle6 = wms_data[~wms_data['Produk 6'].isnull()]
data_bundle6['Real SKU'] = data_bundle6['SKU Produk 6']
data_bundle6['Number of Items'] = data_bundle6['PCS Produk 6']

data_bundle7 = wms_data[~wms_data['Produk 7'].isnull()]
data_bundle7['Real SKU'] = data_bundle7['SKU Produk 7']
data_bundle7['Number of Items'] = data_bundle7['PCS Produk 7']

data_bundle = data_bundle1.append([data_bundle2, data_bundle3, data_bundle4, data_bundle5, data_bundle6, data_bundle7], ignore_index = True, sort = False)
# Out:
# Unbundling
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run 22
fbl_merge = selcen_sku[selcen_sku['Shipment Type Name'] == 'own_warehouse']
lzd_merge = selcen_sku[selcen_sku['Shipment Type Name'] == 'dropshipping']

lzd_merge = lzd_merge.reset_index(drop = True)
wms_data['Customer Order No.'] = wms_data['Customer Order No.'].astype(str)

bundle_wms_data = fbl_merge[fbl_merge['Bundle Name'].notnull()]
lazada_wms_data = fbl_merge[fbl_merge['Bundle Name'].isnull()]

wms_data = wms_data.groupby(['Customer Order No.', 'Platform SKU']).agg({'Status' : 'first', 'Number of Items' : 'sum'}).reset_index()
wms_data['WH'] = 'Lazada Warehouse'
wms_data = wms_data.rename(columns = {'Number of Items' : 'Warehouse Quantity'})

lazada_wms_data['Order Number'] = lazada_wms_data['Order Number'].astype(str)
lazada_wms_data = lazada_wms_data.merge(wms_data.drop_duplicates(['Customer Order No.', 'Platform SKU']), how = 'left', left_on = ['Order Number', 'Lazada SKU'], right_on = ['Customer Order No.', 'Platform SKU'])
lazada_wms_data['Warehouse Quantity'] = lazada_wms_data['Warehouse Quantity'] * lazada_wms_data['Qty. Invoiced']/lazada_wms_data.groupby(['Order Number', 'Real SKU'])['Qty. Invoiced'].transform('sum')


data_bundle = data_bundle.rename(columns = {'Number of Items' : 'Warehouse Quantity', 'Customer Order No.' : 'Order Number', 'Platform SKU Name' : 'Bundle Name'})
bundle_wms_data['Order Number'] = bundle_wms_data['Order Number'].astype(str)
bundle_wms_data['Real SKU'] = bundle_wms_data['Real SKU'].astype(str)
data_bundle['Order Number'] = data_bundle['Order Number'].astype(str)
data_bundle['Real SKU'] = data_bundle['Real SKU'].astype(str)

# data_bundle['Bundle Name'] = data_bundle['Bundle Name'].astype(str).str.replace('-Rasa:Lainnya', '', regex = False)
# bundle_wms_data['Bundle Name'] = bundle_wms_data['Bundle Name'].astype(str).str.replace('-Rasa:Lainnya', '', regex = False)

bundle_wms_data_merge = bundle_wms_data.merge(data_bundle[['Order Number', 'Real SKU', 'Platform SKU', 'Status', 'Warehouse Quantity']].drop_duplicates(['Order Number', 'Real SKU', 'Platform SKU']), how = 'left', left_on = ['Order Number', 'Real SKU', 'Lazada SKU'], right_on = ['Order Number', 'Real SKU', 'Platform SKU'])
bundle_wms_data_merge = bundle_wms_data_merge.rename(columns = {'Product Name_x' : 'Product Name'})

bundle_duplicate = bundle_wms_data_merge[bundle_wms_data_merge[['Order Number', 'Real SKU', 'Bundle Name']].duplicated(keep = False)]
bundle_notduplicate = bundle_wms_data_merge[~bundle_wms_data_merge.index.isin(bundle_duplicate.index)]

bundle_duplicate['Warehouse Quantity'] = bundle_duplicate['Warehouse Quantity'] * bundle_duplicate['Qty. Invoiced']/bundle_duplicate.groupby(['Order Number', 'Bundle Name', 'Real SKU'])['Qty. Invoiced'].transform('sum')

bundle_wms_data_merge = bundle_notduplicate.append(bundle_duplicate, ignore_index = True, sort = False)
# bundle_wms_data_merge = bundle_wms_data_merge.drop('Product Name_y', axis = 1)

lazada_wms_data = lazada_wms_data.append(bundle_wms_data_merge, ignore_index = True, sort = False)

# lazada_wms_data_null = lazada_wms_data[(lazada_wms_data['Order Number'].isin(wms_data['Customer Order No.'])) & (lazada_wms_data['Status'].isnull())]

# wms_data_ori['Customer Order No.'] = wms_data_ori['Customer Order No.'].astype(str)
# wms_data_ori = wms_data_ori.groupby(['Customer Order No.', 'Seller SKU']).agg({'Status' : 'first', 'Number of Items' : 'sum'}).reset_index()
# wms_data_ori['WH'] = 'Lazada Warehouse'
# wms_data_ori = wms_data_ori.rename(columns = {'Number of Items' : 'Warehouse Quantity'})

# lazada_wms_data_null = lazada_wms_data_null.merge(wms_data_ori.drop_duplicates(['Customer Order No.', 'Seller SKU']), how = 'left', left_on = ['Order Number', 'Real SKU'], right_on = ['Customer Order No.', 'Seller SKU']).set_index(lazada_wms_data_null.index)

# lazada_wms_data_null_bundle = lazada_wms_data_null[lazada_wms_data_null['Brand'] == 'Bundle']
# lazada_wms_data_null_real = lazada_wms_data_null[lazada_wms_data_null['Brand'] != 'Bundle']

# data_bundle['WH'] = 'Lazada Warehouse'
# # lazada_wms_data_null_real = lazada_wms_data_null_real.rename(columns = {'WH_y' : 'WH', 'Status_y' : 'Status'})
# buat_bundle = data_bundle.groupby(['Order Number', 'Real SKU']).agg({'WH' : 'first', 'Status' : 'first', 'Warehouse Quantity' : 'sum'}).reset_index()
# lazada_wms_data_null_bundle = lazada_wms_data_null_bundle.drop(['WH_y', 'Status_y'], axis = 1)
# temp_lzd_bundle = lazada_wms_data_null_bundle.merge(data_bundle.drop_duplicates(['Order Number', 'Real SKU']), how = 'left', on = ['Order Number', 'Real SKU']).set_index(lazada_wms_data_null_bundle.index)

# lazada_wms_data_null['Status_y'][temp_lzd_bundle.index] = temp_lzd_bundle['Status']
# lazada_wms_data_null['WH_y'][temp_lzd_bundle.index] = temp_lzd_bundle['WH']

# lazada_wms_data['Status'][lazada_wms_data_null.index] = lazada_wms_data_null['Status_y']
# lazada_wms_data['WH'][lazada_wms_data_null.index] = lazada_wms_data_null['WH_y']
# lazada_wms_data['Warehouse Quantity'][lazada_wms_data_null.index] = lazada_wms_data_null['Warehouse Quantity_y']

fbl_wms_data = lazada_wms_data.copy()
del(lazada_wms_data)
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
lazada_wms_data[['Order Number', 'Lazada SKU']].info()
wms_data[['Customer Order No.', 'Platform SKU']].info()
wms_data['Customer Order No.']

# %%
# wms_non = wms[wms['Real SKU'] == 'NON DATA']

# %%
## run 23
wms_non = wms[(wms['Real SKU'] == 'NON DATA') | (wms['Real SKU'].isnull())]

wms_non = wms_non.merge(selcen_sku[['Real SKU', 'Lazada SKU', 'Brand']].drop_duplicates('Lazada SKU'), how = 'left', left_on = ['Platform SKU'], right_on = ['Lazada SKU'])
wms_non['Real SKU'] = wms_non['Real SKU_y']
wms_non = wms_non.drop(['Real SKU_x', 'Real SKU_y', 'Lazada SKU'], axis = 1)

# temp = wms_non[wms_non['Customer Order No.'] == 751321202119191]
# wms_non = wms_non[pd.to_datetime(wms_non['Order Time']).dt.year > 2021]
# wms_non = wms_non.append(temp, ignore_index = True, sort = False)

wms_non[wms_non['Real SKU'].isnull()].drop_duplicates('Platform SKU Name')
# Out:
#       Customer Order No.           Order Time          Update Time  \
# 1039    1341483967794862  2023-12-20 12:01:21  2023-12-22 14:58:46
# 1307    1060292727386091  2023-01-29 18:26:38  2023-01-30 20:07:07
# 6981     736994150652604  2021-11-19 21:16:16  2021-11-22 17:06:09
#
#                    Platform SKU  \
# 1039  7910822720_ID-14326656392
# 1307  7228430534_ID-13558384057
# 6981   5119512958_ID-9516878900
#
#                                       Platform SKU Name  Number of Items  \
# 1039  [GIFT] Tropicana Slim Sweetener Classic 50 Sac...                2
# 1307  [GIFT] Tropicana Slim Orange Cocoa 4 Sachet - ...                1
# 6981  Paket Es Tinggi Kalsium - HiLo Es Teler 10 Sac...                1
#
#      Delivery Type        Update Time.1     Status Platform  \
# 1039      STANDARD  2023-12-22 14:58:46  Delivered   LAZADA
# 1307      STANDARD  2023-01-30 20:07:07  Delivered   LAZADA
# 6981      standard  2021-11-22 17:06:09  Delivered   LAZADA
#
#                                                  Source  Number of SKUs Brand  \
# 1039   fulfillment-sales-report-export-20231216-22.xlsx             NaN   NaN
# 1307         fulfillment-sales-report-export202301.xlsx             NaN   NaN
# 6981  fulfillment-sales-report-export211231225231878...             1.0   NaN
#
#      Real SKU
# 1039      NaN
# 1307      NaN
# 6981      NaN

# %%
## run 24
list_col = ['SKU'] + data_SKU.columns[data_SKU.columns.get_loc('Produk 1'):data_SKU.columns.get_loc('Harga Cost 7')+1].to_list()
wms_non = wms_non.merge(data_SKU[list_col].drop_duplicates(['SKU']), how = 'left', left_on = 'Real SKU', right_on = 'SKU')
list_pcs = [x for x in wms_non.columns if 'PCS' in x]
for i in list_pcs:
    wms_non[i] = wms_non[i] * wms_non['Number of Items']

print("Unbundling")
data_bundle1 = wms_non[~wms_non['Produk 1'].isnull()]
data_bundle1['Real SKU'] = data_bundle1['SKU Produk 1']
data_bundle1['Number of Items'] = data_bundle1['PCS Produk 1']

data_bundle2 = wms_non[~wms_non['Produk 2'].isnull()]
data_bundle2['Real SKU'] = data_bundle2['SKU Produk 2']
data_bundle2['Number of Items'] = data_bundle2['PCS Produk 2']

data_bundle3 = wms_non[~wms_non['Produk 3'].isnull()]
data_bundle3['Real SKU'] = data_bundle3['SKU Produk 3']
data_bundle3['Number of Items'] = data_bundle3['PCS Produk 3']

data_bundle4 = wms_non[~wms_non['Produk 4'].isnull()]
data_bundle4['Real SKU'] = data_bundle4['SKU Produk 4']
data_bundle4['Number of Items'] = data_bundle4['PCS Produk 4']

data_bundle5 = wms_non[~wms_non['Produk 5'].isnull()]
data_bundle5['Real SKU'] = data_bundle5['SKU Produk 5']
data_bundle5['Number of Items'] = data_bundle5['PCS Produk 5']

data_bundle6 = wms_non[~wms_non['Produk 6'].isnull()]
data_bundle6['Real SKU'] = data_bundle6['SKU Produk 6']
data_bundle6['Number of Items'] = data_bundle6['PCS Produk 6']

data_bundle7 = wms_non[~wms_non['Produk 7'].isnull()]
data_bundle7['Real SKU'] = data_bundle7['SKU Produk 7']
data_bundle7['Number of Items'] = data_bundle7['PCS Produk 7']

data_bundle = data_bundle1.append([data_bundle2, data_bundle3, data_bundle4, data_bundle5, data_bundle6, data_bundle7], ignore_index = True, sort = False)
# Out:
# Unbundling
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
## run 25
wms_non = wms_non.append(data_bundle, ignore_index = True, sort = False)
wms_non = wms_non.groupby(['Customer Order No.', 'Real SKU']).agg({'Status' : 'first', 'Number of Items' : 'sum'}).reset_index()
wms_non['WH'] = 'Lazada Warehouse'
wms_non = wms_non.rename(columns = {'Number of Items' : 'Warehouse Quantity'})

# %%
## run 26
wms_non['Customer Order No.'] = wms_non['Customer Order No.'].astype(str).str.replace('.0', '',regex = False)

# %%
## run 27
fbl_null = fbl_wms_data[(fbl_wms_data['Order Number'].isin(wms_non['Customer Order No.'])) & (fbl_wms_data['Warehouse Quantity'].isnull())].copy()

fbl_null = fbl_null.drop(['Status_y', 'Warehouse Quantity', 'WH'],axis = 1)

fbl_null = fbl_null.merge(wms_non.drop_duplicates(['Customer Order No.', 'Real SKU']), how = 'left', left_on = ['Order Number', 'Real SKU'], right_on = ['Customer Order No.', 'Real SKU']).set_index(fbl_null.index)
fbl_null['Warehouse Quantity'] = fbl_null['Warehouse Quantity'] * fbl_null['Qty. Invoiced']/fbl_null.groupby(['Order Number', 'Real SKU'])['Qty. Invoiced'].transform('sum')

fbl_null_bundle = fbl_null[fbl_null['Brand'] == 'Bundle']

temp_buat_bundle = fbl_null.groupby(['Order Number', 'Bundle Name']).agg({'WH' : 'first', 'Status' : 'first', 'Warehouse Quantity' : 'max', 'Qty. Invoiced' : 'max'}).reset_index()
temp_buat_bundle['Warehouse Quantity'] = temp_buat_bundle['Warehouse Quantity']/temp_buat_bundle['Qty. Invoiced']
temp_buat_bundle = temp_buat_bundle.drop('Qty. Invoiced', axis = 1)

fbl_null_bundle = fbl_null_bundle.merge(temp_buat_bundle.drop_duplicates(['Order Number', 'Bundle Name']), how = 'left', left_on = ['Order Number', 'Item Name'], right_on = ['Order Number', 'Bundle Name']).set_index(fbl_null_bundle.index)
fbl_null_bundle['Warehouse Quantity_y'] = fbl_null_bundle['Warehouse Quantity_y']*fbl_null_bundle['Qty. Invoiced']

fbl_null['Status'][fbl_null_bundle.index] = fbl_null_bundle['Status_y']
fbl_null['WH'][fbl_null_bundle.index] = fbl_null_bundle['WH_y']
fbl_null['Warehouse Quantity'][fbl_null_bundle.index] = fbl_null_bundle['Warehouse Quantity_y']
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:9203: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Status_x'} in the result is deprecated and will raise a MergeError in a future version.
#   validate=validate,
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run 28
fbl_wms_data['Status_y'][fbl_null.index] = fbl_null['Status']
fbl_wms_data['WH'][fbl_null.index] = fbl_null['WH']
fbl_wms_data['Warehouse Quantity'][fbl_null.index] = fbl_null['Warehouse Quantity']

fbl_wms_data = fbl_wms_data.rename(columns = {'Status_x' : 'Order Status', 'Status_y' : 'Status'})
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
## run 29
fbl_null = fbl_wms_data[(fbl_wms_data['Order Number'].isin(wms_non['Customer Order No.'])) & (fbl_wms_data['Warehouse Quantity'].isnull())].copy()

fbl_null = fbl_null.drop(['Status', 'Warehouse Quantity', 'WH'],axis = 1)

wms_non2 = wms_non.copy()
wms_non2['Real SKU'] = wms_non2['Real SKU'].astype(str).str.replace('(U)2309005305','(B)2309005305', regex = False)

fbl_null = fbl_null.merge(wms_non2.drop_duplicates(['Customer Order No.', 'Real SKU']), how = 'left', left_on = ['Order Number', 'Real SKU'], right_on = ['Customer Order No.', 'Real SKU']).set_index(fbl_null.index)
fbl_null['Warehouse Quantity'] = fbl_null['Warehouse Quantity'] * fbl_null['Qty. Invoiced']/fbl_null.groupby(['Order Number', 'Real SKU'])['Qty. Invoiced'].transform('sum')

fbl_null_bundle = fbl_null[fbl_null['Brand'] == 'Bundle']

temp_buat_bundle = fbl_null.groupby(['Order Number', 'Bundle Name']).agg({'WH' : 'first', 'Status' : 'first', 'Warehouse Quantity' : 'max', 'Qty. Invoiced' : 'max'}).reset_index()
temp_buat_bundle['Warehouse Quantity'] = temp_buat_bundle['Warehouse Quantity']/temp_buat_bundle['Qty. Invoiced']
temp_buat_bundle = temp_buat_bundle.drop('Qty. Invoiced', axis = 1)

fbl_null_bundle = fbl_null_bundle.merge(temp_buat_bundle.drop_duplicates(['Order Number', 'Bundle Name']), how = 'left', left_on = ['Order Number', 'Item Name'], right_on = ['Order Number', 'Bundle Name']).set_index(fbl_null_bundle.index)
fbl_null_bundle['Warehouse Quantity_y'] = fbl_null_bundle['Warehouse Quantity_y']*fbl_null_bundle['Qty. Invoiced']

fbl_null['Status'][fbl_null_bundle.index] = fbl_null_bundle['Status_y']
fbl_null['WH'][fbl_null_bundle.index] = fbl_null_bundle['WH_y']
fbl_null['Warehouse Quantity'][fbl_null_bundle.index] = fbl_null_bundle['Warehouse Quantity_y']
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run 30
fbl_wms_data['Status'][fbl_null.index] = fbl_null['Status']
fbl_wms_data['WH'][fbl_null.index] = fbl_null['WH']
fbl_wms_data['Warehouse Quantity'][fbl_null.index] = fbl_null['Warehouse Quantity']

# fbl_wms_data = fbl_wms_data.rename(columns = {'Status_x' : 'Order Status', 'Status_y' : 'Status'})
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
## run 31
import pandas as pd
import numpy as np
import pypyodbc

conn = pypyodbc.connect('Driver={SQL Server};'
                        'Server=NFI-DB-01;'
                        'Database=gudang;'
                        # 'UID=andra.miftah;'
                        # 'PWD=24nutrifoodindonesia21;'
                        'Trusted_Connection=yes;'
                       )

cursor = conn.cursor()
wms_telkom = pd.read_sql(r"""SELECT t1.id, t1.order_id,t1.status, t1.quantity, t1.product_id, t2.id,  t2.order_number, t2.invoice_number, t2.channel, t2.order_date, t3.id, t3.sku, t3.name
  FROM [gudang].[dbo].[outbound_items] as t1
  left join orders as t2
  on t1.order_id = t2.id
  left join products as t3
  on t1.product_id = t3.id
  where t2.channel = 'FBL' or t2.channel = 'Lazada'""", conn)


# wms_telkom=pd.read_excel(r"D:\Downloads\Data Gudang 20221122 (1).xlsx")
# wms_telkom=wms_telkom[wms_telkom['channel']=='Lazada']

wms_telkom_copy=wms_telkom.copy()

# %%
## for backup
wms_telkom=wms_telkom_copy.copy()

# %%
## run 32

# outbound_items = pd.read_csv(r'Backup Gudang 4 Sept 2021 Gudang Baru/outbound_items.csv', sep = ';')
# orders = pd.read_csv(r'Backup Gudang 4 Sept 2021 Gudang Baru/orders.csv', sep = ';')
# products = pd.read_csv(r'Backup Gudang 4 Sept 2021 Gudang Baru/products.csv', sep = ';')

# wms_telkom2 = outbound_items[['id', 'order_id','status', 'quantity', 'product_id']].merge(
#     orders[['id',  'order_number', 'invoice_number', 'channel', 'order_date']], how = 'left', left_on = 'order_id', right_on = 'id'
# ).merge(
#     products[['id', 'sku', 'name']], how = 'left', left_on = 'product_id', right_on = 'id'
# )
# wms_telkom2 = wms_telkom2[wms_telkom2['channel'].isin(['Lazada', 'FBL'])]
if 'STATUS' in wms_telkom.columns:
    wms_telkom = wms_telkom.rename(columns = {'STATUS':'status'})
wms_telkom = wms_telkom[['order_number', 'sku', 'status', 'quantity']].drop_duplicates()
# wms_telkom2 = wms_telkom2[['invoice_number', 'sku', 'status', 'quantity']].drop_duplicates()
# wms_telkom = wms_telkom.append(wms_telkom2, ignore_index = True, sort = False)

wms_telkom['WH'] = 'Telkom'
wms_telkom = wms_telkom.rename(columns = {'order_number' : 'Customer Order No.', 'status':'Status', 'sku' : 'Platform SKU', 'quantity' : 'Warehouse Quantity'})

colname = wms_telkom.columns.to_list()
wms_telkom_all = wms_telkom.merge(j_conv, how = 'left', left_on = ['Platform SKU'], right_on = ['Real SKU'])
wms_j = wms_telkom_all[wms_telkom_all['SKU Produk'].notnull()]

wms_j['Platform SKU'] = wms_j['SKU Produk']
wms_j['Warehouse Quantity'] = wms_j['Warehouse Quantity'] * wms_j['Konversi ke UOM'].astype(float)

wms_telkom = wms_telkom.append(wms_j, ignore_index = True, sort = False)
wms_telkom = wms_telkom[colname]

lzd_merge = selcen_sku[selcen_sku['Shipment Type Name'] == 'dropshipping'].reset_index(drop = True)

indeks = lzd_merge[(lzd_merge['Real SKU'].isin(['(B)2309005305P3', '(B)2309005300P3']))].index.to_list()
lzd_merge['Brand'][indeks] = 'Bundle'

lzd_merge['Order Number'] = lzd_merge['Order Number'].astype(str)
wms_telkom['Customer Order No.'] = wms_telkom['Customer Order No.'].astype(str)

wms_telkom = wms_telkom.groupby(['Customer Order No.', 'Platform SKU', 'Status',
       'WH'])['Warehouse Quantity'].sum().reset_index()

lzd_merge['Real SKU'] = lzd_merge['Real SKU'].astype(str).str.replace('.0', '', regex = False)
lzd_merge = lzd_merge.rename(columns = {'Status' : 'Order Status'})
wms_telkom['Platform SKU'] = wms_telkom['Platform SKU'].astype(str)

temp_cek_telkom = lzd_merge.merge(wms_telkom[['Customer Order No.', 'Platform SKU']].drop_duplicates(), how = 'left', left_on = ['Order Number', 'Real SKU'], right_on = ['Customer Order No.', 'Platform SKU']).set_index(lzd_merge.index)
temp_cek_telkom = temp_cek_telkom[temp_cek_telkom['Order Number'].isin(wms_telkom['Customer Order No.'])]
temp_telkom = lzd_merge.iloc[temp_cek_telkom.index]

temp_telkom['Order Number'] = temp_telkom['Order Number'].astype(str)
wms_telkom['Customer Order No.'] = wms_telkom['Customer Order No.'].astype(str)

temp_telkom['Real SKU'] = temp_telkom['Real SKU'].astype(str).str.replace('.0', '', regex = False)
wms_telkom['Platform SKU'] = wms_telkom['Platform SKU'].astype(str)

temp_telkom = temp_telkom.merge(wms_telkom.drop_duplicates(['Customer Order No.', 'Platform SKU']), how = 'left', left_on = ['Order Number', 'Real SKU'], right_on = ['Customer Order No.', 'Platform SKU'])

temp_telkom['Warehouse Quantity'] = temp_telkom['Warehouse Quantity'] * temp_telkom['Qty. Invoiced']/temp_telkom.groupby(['Order Number', 'Real SKU'])['Qty. Invoiced'].transform('sum')


indeks = temp_telkom[(temp_telkom['Item Name'].astype(str).str.contains('-Rasa', regex = False)) & ~(temp_telkom['Item Name'].astype(str).str.contains(' -Rasa', regex = False))].index.to_list()
temp_telkom['Item Name'][indeks] = temp_telkom['Item Name'].astype(str).str.replace('-Rasa', ' - Rasa', regex = False)

indeks = temp_telkom[(temp_telkom['Item Name'].astype(str).str.contains('-Flavor', regex = False)) & ~(temp_telkom['Item Name'].astype(str).str.contains(' -Flavor', regex = False))].index.to_list()
temp_telkom['Item Name'][indeks] = temp_telkom['Item Name'].astype(str).str.replace('-Flavor', ' - Flavor', regex = False)

indeks = temp_telkom[(temp_telkom['Bundle Name'].astype(str).str.contains('-Rasa', regex = False)) & ~(temp_telkom['Bundle Name'].astype(str).str.contains(' -Rasa', regex = False))].index.to_list()
temp_telkom['Bundle Name'][indeks] = temp_telkom['Bundle Name'].astype(str).str.replace('-Rasa', ' - Rasa', regex = False)

indeks = temp_telkom[(temp_telkom['Bundle Name'].astype(str).str.contains('-Flavor', regex = False)) & ~(temp_telkom['Bundle Name'].astype(str).str.contains(' -Flavor', regex = False))].index.to_list()
temp_telkom['Bundle Name'][indeks] = temp_telkom['Bundle Name'].astype(str).str.replace('-Flavor', ' - Flavor', regex = False)


temp_telkom_bundle = temp_telkom[temp_telkom['Brand'] == 'Bundle']

temp_buat_bundle = temp_telkom.groupby(['Order Number', 'Bundle Name']).agg({'WH' : 'first', 'Status' : 'first', 'Warehouse Quantity' : 'max', 'Qty. Invoiced' : 'max'}).reset_index()
temp_buat_bundle['Warehouse Quantity'] = temp_buat_bundle['Warehouse Quantity']/temp_buat_bundle['Qty. Invoiced']
temp_buat_bundle = temp_buat_bundle.drop('Qty. Invoiced', axis = 1)

temp_telkom_bundle = temp_telkom_bundle.merge(temp_buat_bundle.drop_duplicates(['Order Number', 'Bundle Name']), how = 'left', left_on = ['Order Number', 'Item Name'], right_on = ['Order Number', 'Bundle Name']).set_index(temp_telkom_bundle.index)
temp_telkom_bundle['Warehouse Quantity_y'] = temp_telkom_bundle['Warehouse Quantity_y']*temp_telkom_bundle['Qty. Invoiced']

temp_telkom['Status'][temp_telkom_bundle.index] = temp_telkom_bundle['Status_y']
temp_telkom['WH'][temp_telkom_bundle.index] = temp_telkom_bundle['WH_y']
temp_telkom['Warehouse Quantity'][temp_telkom_bundle.index] = temp_telkom_bundle['Warehouse Quantity_y']

lzd_merge = lzd_merge.drop(temp_cek_telkom.index, axis = 0)
lzd_merge = lzd_merge.append(temp_telkom, ignore_index = True, sort = False)
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run 33
lzd_merge_null = lzd_merge[(lzd_merge['Order Number'].isin(wms_telkom['Customer Order No.'])) & 
        (lzd_merge['Status'].isnull())]

temp_telkom = lzd_merge_null[lzd_merge_null['Order Number'].isin(wms_telkom['Customer Order No.'])]
wms_telkom2 = wms_telkom.copy()

indeks = wms_telkom2[wms_telkom2['Platform SKU'] == '2101809250'].index.to_list()
wms_telkom2['Platform SKU'][indeks] = '(E)2101809250'

indeks = wms_telkom2[wms_telkom2['Platform SKU'] == '1101996453'].index.to_list()
wms_telkom2['Platform SKU'][indeks] = '(E)1101996453'

indeks = wms_telkom2[wms_telkom2['Platform SKU'] == '2101947250'].index.to_list()
wms_telkom2['Platform SKU'][indeks] = '(E)2101947250'

wms_telkom2['Platform SKU'] = wms_telkom2['Platform SKU'].astype(str).str.replace('2309005305', '2309005300')

temp_telkom = temp_telkom.drop(['WH', 'Customer Order No.', 'Status', 'Platform SKU', 'Warehouse Quantity'], axis = 1)
temp_telkom['Order Number'] = temp_telkom['Order Number'].astype(str)
wms_telkom2['Customer Order No.'] = wms_telkom2['Customer Order No.'].astype(str)

temp_telkom['Real SKU'] = temp_telkom['Real SKU'].astype(str).str.replace('.0', '', regex = False)
wms_telkom2['Platform SKU'] = wms_telkom2['Platform SKU'].astype(str)

temp_telkom = temp_telkom.merge(wms_telkom2.drop_duplicates(['Customer Order No.', 'Platform SKU']), how = 'left', left_on = ['Order Number', 'Real SKU'], right_on = ['Customer Order No.', 'Platform SKU']).set_index(temp_telkom.index)
temp_telkom['Warehouse Quantity'] = temp_telkom['Warehouse Quantity'] * temp_telkom['Qty. Invoiced']/temp_telkom.groupby(['Order Number', 'Real SKU'])['Qty. Invoiced'].transform('sum')

temp_telkom_bundle = temp_telkom[temp_telkom['Brand'] == 'Bundle']

temp_buat_bundle = temp_telkom.groupby(['Order Number', 'Bundle Name']).agg({'WH' : 'first', 'Status' : 'first', 'Warehouse Quantity' : 'max', 'Qty. Invoiced' : 'max'}).reset_index()
temp_buat_bundle['Warehouse Quantity'] = temp_buat_bundle['Warehouse Quantity']/temp_buat_bundle['Qty. Invoiced']
temp_buat_bundle = temp_buat_bundle.drop('Qty. Invoiced', axis = 1)

temp_telkom_bundle = temp_telkom_bundle.merge(temp_buat_bundle.drop_duplicates(['Order Number', 'Bundle Name']), how = 'left', left_on = ['Order Number', 'Item Name'], right_on = ['Order Number', 'Bundle Name']).set_index(temp_telkom_bundle.index)
temp_telkom_bundle['Warehouse Quantity_y'] = temp_telkom_bundle['Warehouse Quantity_y']*temp_telkom_bundle['Qty. Invoiced']

temp_telkom['Status'][temp_telkom_bundle.index] = temp_telkom_bundle['Status_y']
temp_telkom['WH'][temp_telkom_bundle.index] = temp_telkom_bundle['WH_y']
temp_telkom['Warehouse Quantity'][temp_telkom_bundle.index] = temp_telkom_bundle['Warehouse Quantity_y']

lzd_merge['Status'][temp_telkom.index] = temp_telkom['Status']
lzd_merge['WH'][temp_telkom.index] = temp_telkom['WH']
lzd_merge['Warehouse Quantity'][temp_telkom.index] = temp_telkom['Warehouse Quantity']
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == "":
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run 34 # kemuingkinan tidak terkriim dr gudang NFI
lzd_merge[(lzd_merge['Status'].isnull()) &
          (lzd_merge['Order Number'].isin(wms_telkom['Customer Order No.'])) &
          (lzd_merge['Bundle Name'].isnull())].groupby(['Real SKU', 'Real Nama Produk', 'Platform SKU', 'Lazada SKU', 'Item Name'], dropna = False)['Order Number'].first().reset_index()
# Out:
#               Real SKU                                   Real Nama Produk  \
# 0   (B)(R)2LM0801029P2      SAMPLING - L-Men Isopower Stargizing 2 Sachet
# 1        (E)1101692318    (Near ED) Lokalate Kopi Pisang Bakar Epe 10 sch
# 2        (E)1101693318            (Near ED) Lokalate Kopi Tape Ketan 10's
# 3      (E)2101816250P4  BUY 2 GET 2 : (Near ED) HiLo Milky Vanilla Coo...
# 4      (E)2101907250P4       4 pak HiLo RTD Kacang Hijau 200 ml - Near ED
# 5      (E)2HF1403250P4  (Near ED) HiLo School Cotton Candy 200ml - Rea...
# 6           1101522453                          NutriSari Blewah (40 sch)
# 7           1101529453                          Nutrisari Anggur (40 Sch)
# 8           1101534453                     NutriSari Sweet Mango (40 sch)
# 9           1101543453                     NutriSari Apel Jeruk 40 Sachet
# 10          1101558453        Nutrisari Jeruk Nipis 40'sachet (4 Renceng)
# 11        1101569326P4                    NutriSari Jeruk Peras (160 Sch)
# 12          1101588453                    NutriSari Milky Orange (40 sch)
# 13          1101686318              Lokalate Kopi Kawista 10 Sachet Polos
# 14          1101909331           Nutrisari American Sweet Orange (40 Sch)
# 15        1101909331P4          NutriSari American Sweet Orange (160 Sch)
# 16        1101909331P4          NutriSari American Sweet Orange (160 Sch)
# 17          1101930453                        NutriSari Cocopandan 40 sch
# 18          1101954453                          NutriSari Semangka 40 sch
# 19          1101954454                    NutriSari Semangka 40 sch x 11g
# 20          1101976453                         NutriSari Markisa (40 Sch)
# 21          1101984453                            NutriSari Es Rujak (4R)
# 22          1101989454                  NutriSari Es Cincau 40 sch x 11 g
# 23        1101989454P4  NutriSari Es Cincau 160 Sachet - Minuman Buah ...
# 24          1102070337               NutriSari Lychee Tea Refill 400 gram
# 25        1NA0809005P2               W'Dank Sereh Jahe Nipis 10sch (2pcs)
# 26         21014281P24  Hilo School Vanilla Vegiberi Ready To Drink Su...
# 27          21014281P4  Hilo School Vanilla Vegiberi Ready To Drink Su...
# 28           2101656P4  Hilo Teen Coffee Tiramisu Ready To Drink Susu ...
# 29          2101808450                       Hilo Chocolate Taro (10 sch)
# 30        2101808450P2  TWIN PACK - HiLo Chocolate Taro 2 X 10 sachet ...
# 31          2101845443                         Hilo Es Ketan Hitam 10 sch
# 32        2101847443P2                   Twin Pack HiLo Thai Tea (10 sch)
# 33        2101891443P2    Twin pack HiLo Swiss Chocolate (10 sch) Renceng
# 34        2102900130P2              Twin Pack: Tropicana Slim Diabtx 100s
# 35          2309005305               L-Men Protein Crunch BBQ Beef (20gr)
# 36          2HH0813443                              HiLo Teh Tarik 10 Sch
# 37        2T01403249P4  buy 2 get 2 - Tropicana Slim RTD Oat Drink Mel...
# 38      PN34(3)N45G117  NutriSari Mango Smoothie 200ml (3pcs) + NutriS...
#
#     Platform SKU                 Lazada SKU  \
# 0            NaN  7627454689_ID-14035154477
# 1            NaN  7361450804_ID-13767048937
# 2            NaN  7361498194_ID-13767106316
# 3            NaN  7682852549_ID-14113936594
# 4            NaN  6618254523_ID-12586246452
# 5            NaN  7905520005_ID-14321628614
# 6            NaN    882898026_ID-1299216205
# 7            NaN  6735304892_ID-12788368200
# 8            NaN   1464740088_ID-2722932186
# 9            NaN   5151908788_ID-9585032424
# 10           NaN   1040214653_ID-1580494324
# 11           NaN     670762151_ID-931748448
# 12           NaN   1960878319_ID-3846684884
# 13           NaN   1575086373_ID-3022088904
# 14           NaN    938640389_ID-1414166989
# 15           NaN     670676200_ID-931444373
# 16           NaN     670676200_ID-931444373
# 17           NaN   4248766765_ID-7172182976
# 18           NaN   4357076810_ID-7478482152
# 19           NaN   4357076810_ID-7478482152
# 20           NaN    882894083_ID-1299222299
# 21           NaN   1105702993_ID-1742596619
# 22           NaN   4148094631_ID-6995084700
# 23           NaN  7895838854_ID-14311396040
# 24           NaN  5806056123_ID-11264756058
# 25           NaN  7989302128_ID-14409144620
# 26           NaN   1018838036_ID-1526392133
# 27           NaN  6600098298_ID-12549308394
# 28           NaN   5095704089_ID-9448752543
# 29           NaN  6424006520_ID-12186314276
# 30           NaN    860572392_ID-1249664300
# 31           NaN  6255044442_ID-11882850669
# 32           NaN     420699143_ID-475650839
# 33           NaN     670224952_ID-930410316
# 34           NaN   1640072770_ID-3172162308
# 35           NaN   4607124026_ID-8028636853
# 36           NaN  7328586131_ID-13728212852
# 37           NaN  7696796751_ID-14149252146
# 38           NaN  8019744555_ID-14444032163
#
#                                             Item Name      Order Number
# 0   [GIFT] 2 Sachet L-Men Isopower Creatine Stargi...  1226117461058062
# 1   LIMITED DEALS : Lokalate Kopi Pisang Bakar Epe...  1117537134399026
# 2   LIMITED DEALS : Lokalate Kopi Tape Ketan 10 Sa...  1117537134399026
# 3   CLEARANCE SALE: HiLo UHT Milky Vanilla Cookies...  1371808799358395
# 4   Buy 2 Get 2 - HiLo Kacang Hijau RTD 200 ml - 4...  1184577338991339
# 5   CLEARANCE SALE : HiLo School UHT Cotton Candy ...  1324417249604041
# 6   NutriSari Blewah/Cantaloupe 40 Sachets - Juice...  1270030809606678
# 7   NutriSari Anggur 40 Sachet  - Minuman Buah Vit...  1261198150491427
# 8   NutriSari Sweet Mango 40 Sachet - Minuman Buah...  1155280045426870
# 9   NutriSari Apel Jeruk 40 Sachet - Minuman Buah ...  1310855644369306
# 10  NutriSari Jeruk Nipis 40 Sachet - Minuman Buah...  1261198150491427
# 11  NutriSari Jeruk Peras 160 sachet - Minuman Bua...  1125459241101668
# 12  NutriSari Milky Orange 40 Sachets - Juice with...  1270030809606678
# 13  Lokalate Kopi Kawista 10 Sachet - Kopi Sachet ...  1161529158754744
# 14  NutriSari American Sweet Orange 40 Sachet - Mi...  1193480618596661
# 15  NutriSari American Sweet Orange 160 sachet - M...  1259385138779604
# 16  NutriSari American Sweet Orange 160 sachet - M...  1301327400872337
# 17  NutriSari Cocopandan 40 sch - Minuman Buah Vit...  1310855644369306
# 18  NutriSari Watermelon 40 Sachet - Juice with Vi...  1261198150491427
# 19  NutriSari Watermelon 40 Sachet - Juice with Vi...  1270030809606678
# 20  NutriSari Markisa 40 Sachet - Minuman Buah Vit...  1155280045426870
# 21  NutriSari Es Rujak 40 Sachet - Minuman Buah Vi...  1310855644369306
# 22  NutriSari Es Cincau 40 Sachet - Minuman Buah V...  1312837285472322
# 23  NutriSari Es Cincau 160 Sachet - Minuman Buah ...  1326987932389940
# 24  NutriSari Lychee Tea Powder Drink Refill 400 g...  1309945033213226
# 25  BUY 1 GET 1 FREE - W'Dank Sereh Jahe Nipis 10 Sch  1371247260192535
# 26  HiLo School Vanilla Vegiberi Ready To Drink 20...  1113966265536726
# 27  HiLo School Vanilla Vegiberi Ready To Drink 20...  1031517018184505
# 28  HiLo Teen UHT Coffee Tiramisu Ready To Drink 2...  1413080115335663
# 29  HiLo Chocolate Taro 10 sachet - Minuman Cokela...  1106641941816632
# 30  Twin Pack : HiLo Chocolate Taro 10 Sch - Minum...  1301281807206009
# 31                         HiLo Es Ketan Hitam 10 sch  1261640007984829
# 32  Hilo Thai Tea 10 sch x 2 pcs - Minuman Tinggi ...  1312809982287280
# 33  HiLo Swiss Chocolate 10 sch x 2 pcs - Minuman ...  1301281807206009
# 34  Twin Pack - Tropicana Slim Sweetener Diabtx 10...  1093726380316331
# 35  L-Men Protein Crunch BBQ Beef 20g (12g protein...  1096690676501833
# 36  HiLo Teh Tarik 10 Sch - Teh Tarik Tinggi Kalsi...  1261640007984829
# 37  Tropicana Slim Oat Drink Japanese Cantaloupe M...  1257119897217091
# 38  HiLo untuk 35+ Tahun (336gr - 500gr) - Susu Ti...  1402077837084124

# %%
# lzd_merge[['Status','Order Number','Bundle Name','Real SKU', 'Real Nama Produk', 'Platform SKU', 'Lazada SKU', 'Item Name']]
wms_telkom[wms_telkom['Customer Order No.']=='1096690676501833']
# Out:
#       Customer Order No.   Platform SKU     Status      WH  Warehouse Quantity
# 20951   1096690676501833  (E)2101888360  confirmed  Telkom                 1.0

# %%
## run 35
lazada_wms = fbl_wms_data.append(lzd_merge, ignore_index = True, sort = False)

# %%
## run 36
lazada_wms = lazada_wms.rename(columns = {'Shipping Fee' : 'Selcen Shipping Fee'})

# %%
## SKIP THIS

import os
import pandas as pd
import numpy as np

settlement = pd.DataFrame()
for i in os.listdir('Settlement Project\Lazada\Settlement/'):
    print(i)
    if 'finance' in i:
        if '2021-08-02' in i or '2021-08-09' in i or '2021-08-16' in i or '2021-08-23' in i:
            temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i), sep = ';')
        else :
            temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i))
    else :
        temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i), sep = ';')
    temp['Source'] = i
    true_col = ['Transaction Date', 'Transaction Type', 'Fee Name', 'Transaction Number', 'Details', 'Seller SKU', 'Lazada SKU', 'Amount', 'VAT in Amount', 'WHT Amount', 
                'WHT included in Amount', 'Statement', 'Paid Status', 'Order No.', 'Order Item No.', 'Order Item Status', 'Shipping Provider', 'Shipping Speed', 
                'Shipment Type', 'Reference', 'Comment', 'PaymentRefId', 'Source']
    if temp.columns.to_list() == true_col :
        print('Column sama')
    else:
        print('Column beda')
        print([x for x in true_col if x not in temp.columns.to_list()])
        print([x for x in temp.columns.to_list() if x not in true_col])
    settlement = settlement.append(temp, ignore_index = True, sort = False)
    
list_cat = pd.read_excel(r'Settlement Project\Lazada/Converter Settlement.xlsx')
settlement_cat = settlement.merge(list_cat, how = 'left', left_on = settlement['Fee Name'].str.lower(), right_on = list_cat['Fee Name'].str.lower())
settlement_cat['Order No.'] = settlement_cat['Order No.'].astype(str).str.replace('.0', '', regex = False)

display(settlement_cat[(settlement_cat['Kategori'].isnull()) & (settlement_cat['Statement'].astype(str).str.contains('2022'))].drop_duplicates('Fee Name_x'))

settlement_cat = settlement_cat.drop_duplicates(['key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Order Item No.'])
settlement_cat = settlement_cat.groupby(['key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Lazada SKU', 'Kategori'], dropna = False)['Amount'].sum().reset_index()


set_pivot = pd.pivot_table(settlement_cat, values = 'Amount', index = ['Order No.', 'Seller SKU'], columns = 'Kategori', aggfunc=np.sum).reset_index()

# %%
list_cat = pd.read_excel(r'Settlement Project\Lazada/Converter Settlement.xlsx')
settlement_cat = settlement.merge(list_cat, how = 'left', left_on = settlement['Fee Name'].str.lower(), right_on = list_cat['Fee Name'].str.lower())
settlement_cat['Order No.'] = settlement_cat['Order No.'].astype(str).str.replace('.0', '', regex = False)

display(settlement_cat[(settlement_cat['Kategori'].isnull()) & (settlement_cat['Statement'].astype(str).str.contains('2022'))].drop_duplicates('Fee Name_x'))

settlement_cat = settlement_cat.drop_duplicates(['key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Order Item No.'])

# %%
settlement_cat.to_csv('Rekap Settlement Lazada 2021-2022.csv',sep=";",index=False)

# %%
## run 37
import os
import pandas as pd

settlement = pd.DataFrame()
for i in os.listdir('Settlement Project\Lazada\Settlement/'):
    print(i)
    if 'finance' in i:
        if '2021-08-02' in i or '2021-08-09' in i or '2021-08-16' in i or '2021-08-23' in i:
            temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i), sep = ';')
        else :
            temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i))
    else :
        temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i), sep = ';')
    temp['Source'] = i
    true_col = ['Transaction Date', 'Transaction Type', 'Fee Name', 'Transaction Number', 'Details', 'Seller SKU', 'Lazada SKU', 'Amount', 'VAT in Amount', 'WHT Amount', 
                'WHT included in Amount', 'Statement', 'Paid Status', 'Order No.', 'Order Item No.', 'Order Item Status', 'Shipping Provider', 'Shipping Speed', 
                'Shipment Type', 'Reference', 'Comment', 'PaymentRefId', 'Source']
    if temp.columns.to_list() == true_col :
        print('Column sama')
    else:
        print('Column beda')
        print([x for x in true_col if x not in temp.columns.to_list()])
        print([x for x in temp.columns.to_list() if x not in true_col])
    settlement = settlement.append(temp, ignore_index = True, sort = False)
# Out:
# 0118e4649624f5da67abea1627f8094c.csv
# Column sama
# 01e948e55523ac72e14bd0753f6b5177.csv
# Column sama
# 022838f21f2585a7553fbae1cef0cc41.csv
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Column sama
# 042eb545c5f22f9cf6fbab3daf6f1172.csv
# Column sama
# 04402c11aa89e293037975d0d0f01792.csv
# Column sama
# 05043df4aa921801210a9acb37d07969.csv
# Column sama
# 06265a5aa605bb2227981cf166c76644.csv
# Column sama
# 07965605690d45cd0fe5833c38801353.csv
# Column sama
# 0aaec4b29c8ff2771fd1fb6249c272d4.csv
# Column sama
# 0bd3d7eaa70facffdbac788e41eca109.csv
# Column sama
# 0dc739791e0940e9283ad6613d7ed910.csv
# Column sama
# 0efacfd3ee85eaa05c5e807df1c55b83.csv
# Column sama
# 0f26a4e9666658b068df52f3faf03dd3.csv
# Column sama
# 10f10f2faae7e4ed4a6f8065e8feca32.csv
# Column sama
# 14e251a1596fe04fa29f4081e1fb6c78.csv
# Column sama
# 150ca316c163487c9c30866b6a8f1140.csv
# Column sama
# 182cafdc91948090f90646b92e1f07ff.csv
# Column sama
# 1875292ccf6acf66ac24b411cf47c3ff.csv
# Column sama
# 190f1a3aa4ebf9435a259e1320bc30c6.csv
# Column sama
# 199dee8408daedf03d0c706a3bf66dde.csv
# Column sama
# 1a10817a2fdc1bbe71397ab4ef2d084f.csv
# Column sama
# 1bbb39098ed753eb9f31a64e35f7128a.csv
# Column sama
# 1f125a1aa15b003acf5415b4b3ce9bd3.csv
# Column sama
# 1f22ad8a9570d0fa3eb9c09cc072a1b4.csv
# Column sama
# 215ae414ce636db037d0d28052f8abfd.csv
# Column sama
# 21ebbfc7dbeae1ded34bf6c282a89799.csv
# Column sama
# 22db68a0ca1d286ed7e597d56a50ec33.csv
# Column sama
# 2393f7897f0b7fa832695a2ad1f154a0.csv
# Column sama
# 244b8cb51abf377d50536f0dcd5fd5d3.csv
# Column sama
# 25368e6d8f61f888744fd23db8d76c33.csv
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Column sama
# 27b80084349d17ae97ad45fa9b572fb9.csv
# Column sama
# 28a47e2268d75afcd72e2c3507c1b470.csv
# Column sama
# 2a72b46b974dde1ec1891e5ad5d14714.csv
# Column sama
# 2addfbbcf2eb1c2d88d168708975477b.csv
# Column sama
# 2f18dea4ee4391fe78cd2bba6f21bc40.csv
# Column sama
# 30ea9d81e93941d111ab29dbd408c4d8.csv
# Column sama
# 310e6b274cf0947e3caec8785f858033.csv
# Column sama
# 34e494fca000be35bacc78ab6f46d2a6.csv
# Column sama
# 371af7983ef02c7f59301418dc178cd9.csv
# Column sama
# 375801e5487ee2c14fb8eb0a125aa1b0.csv
# Column sama
# 3b62a795613f7df3d71d579a8298b823.csv
# Column sama
# 3beca8415d2ff04dedd35d86fe7e2601.csv
# Column sama
# 40a0bd9e6e37966d8be228540f5b8d8f.csv
# Column sama
# 4c28b63494119226648cacbe5951fbc0.csv
# Column sama
# 51325796bce27b937f1deddbe776dcfc.csv
# Column sama
# 51371a861962a9a243cf8184b24e23f4.csv
# Column sama
# 5232cd6e4c3896a0e026ad03c0f3dbf6.csv
# Column sama
# 55e02cfa0609e15018de6d7cf1418016.csv
# Column sama
# 562c29ff3561227170bd3c12af1b87e8.csv
# Column sama
# 565897dfa6407ab253bbb3409b90b03a.csv
# Column sama
# 565c5521f1eaff7f634dd44052f8f58c.csv
# Column sama
# 56d4bf71b70b427a86597e3e60854493.csv
# Column sama
# 5c22bee4421ac154ff36b91278e3f660.csv
# Column sama
# 651815b08b7eb9d11aa7f71e72f75697.csv
# Column sama
# 6541ed782806ead07dffd660704dee4c.csv
# Column sama
# 6ba34dae524317df6f25f48bbf5766aa.csv
# Column sama
# 6ee7c07533fbf23b6d4759b84e9b83d8.csv
# Column sama
# 72863b0cc344d9ee9830e33df5abca6e.csv
# Column sama
# 72dfbd59bfe0125e40b073581321f233.csv
# Column sama
# 740cc3e7e0a3df3f3aab5d72b1f7f00d.csv
# Column sama
# 742df3c8d00554c1f7f9f4ae1aefdbc2.csv
# Column sama
# 745ffd9b745f7828c6a2aa4d85481749.csv
# Column sama
# 78623ecdc52b79c80e720261d8a2e742.csv
# Column sama
# 7a65cbb427d8c6537e95f8a96d944d72.csv
# Column sama
# 7c6d273f456bc8868e7175fb0aca33d9.csv
# Column sama
# 7ecced00a9a38c2e3e14940c59b25e49.csv
# Column sama
# 80607251f9cdd61bd0496cbae7c17f05.csv
# Column sama
# 807bda08d5823b792c38f92b347775dc.csv
# Column sama
# 8533634bb5d783134217519ba4a88fc3.csv
# Column sama
# 867f3ca9fc0c402aa06e46bef7ee0415.csv
# Column sama
# 8758ed7ab34489057c70c98861a00d87.csv
# Column sama
# 8a9db88f9565a621b807a084ff9842f8.csv
# Column sama
# 8b3d97ac57f0afd26725d7b971edc64a.csv
# Column sama
# 9003aefdd4dcccb9534e8ac6e1e54a49.csv
# Column sama
# 914be656bf4ca410410bc41e24055029.csv
# Column sama
# 974c36d8450a10cfadf1ba903832318e.csv
# Column sama
# 9d69dab8571cfa34b94e333099e9425a.csv
# Column sama
# 9dc34ab20f5f5bc59512fe244b87f9fb.csv
# Column sama
# 9de43ffb5a23ef5cf3013d70a0857efb.csv
# Column sama
# 9e48dfef51f2c9c790c45dc8bf138ae4.csv
# Column sama
# 9ea39a49dc403514c3829185b2a0c1d0.csv
# Column sama
# a61cfa5ab38d51373a5f8c6aebde20ce.csv
# Column sama
# ab465575845455bc45d86c6396d51fc4.csv
# Column sama
# afe578618103e1fd6ce353a4f98384b4.csv
# Column sama
# b01661f0628df3971548abfb577298b0.csv
# Column sama
# b033e6f9aab96d48be409bb3a83253f1.csv
# Column sama
# b1a0c6131cca51ff655e2d42a00d6420.csv
# Column sama
# b4b54d7779fb5e68db583ac3e85b3651.csv
# Column sama
# b67476712ada3957935b7396fb6194af.csv
# Column sama
# b8b5a7a140edc6956e73d1b1408e6cba.csv
# Column sama
# bb86fc52206698623ea8714f86d9e4fb.csv
# Column sama
# bc30b01a5ca12ac2c8178d83d7712dc1.csv
# Column sama
# be2913d2120f30f2d3fd6c99acc6860a.csv
# Column sama
# bfb04ddf67f9124981c620ebf26ff175.csv
# Column sama
# c24ccbb1858488e270e5d6fc86d77c12.csv
# Column sama
# c45e68018d600bc7be3b4011009eba5a.csv
# Column sama
# c5e79637e601413471b7f8e731b60291.csv
# Column sama
# cc3aa256a4c073ea585991f8e78b3b0b.csv
# Column sama
# cfa346c6c1331a1e56e16b1675115ce7.csv
# Column sama
# d3ca833712faa4c7e0baf6c34bcc659a.csv
# Column sama
# d6bc3ea1f8e0da8fce3ae5f4ddcb6d83.csv
# Column sama
# d79c4d91ae08121510146d09f9505792.csv
# Column sama
# d813670277579e0bc16be53148a5ac38.csv
# Column sama
# d94e4df9e0de37f259bbc30fca52cd35.csv
# Column sama
# dca5c168b1bd64d45a7d8d5810abe40f.csv
# Column sama
# dcb1bdb6da23c32f0efe44cc868746c3.csv
# Column sama
# dd337a6097460d04f52b3d83b9930b35.csv
# Column sama
# dee6b94fc475414ec28f1eacf0aa3e3d.csv
# Column sama
# e82ad4945c8e01c773f8a456677e6ca2.csv
# Column sama
# eb665d08a209125bbbc5d603ff3a6607.csv
# Column sama
# ec58efb5724cdaafe69f4a9fc4ddb037.csv
# Column sama
# ee9f2b70db231eafb04fe455db993b2b.csv
# Column sama
# f07398f6b0c1e6ef0cfbe11fa1cf13eb.csv
# Column sama
# fae01f9ac44255141bdbd0de92968063.csv
# Column sama
# fb4306d9d2cae7b66ad13b37d8f9e6c3.csv
# Column sama
# fd455732a2990ecba99cc456d2d01900.csv
# Column sama
# ffb0967571b068578dcabeb7f14ba2c0.csv
# Column sama

# %%
## for backup
settlement_copy=settlement.copy()

# %%
## for backup
settlement=settlement_copy.copy()

# %%
settlement[settlement['Lazada SKU'].isnull()][['Fee Name']].drop_duplicates().sort_values('Fee Name').reset_index(drop=True)#[settlement['Order No.']==1282699509140819].to

# %%
settlement[(settlement['Fee Name']=='Seller balance adjustments - Credit')&(settlement['Lazada SKU'].isnull())]#[['Fee Name']].drop_duplicates().sort_values('Fee Name').reset_index(drop=True).to_excel('fee name settlement lazada (non Order).xlsx',index=False)

# %%
settlement[settlement['Fee Name']=='Free Shipping Max Fee'][['Transaction Date','Fee Name','Amount','Order No.']].to_excel('shipping laz.xlsx',index=False)

# %%
settlement['Fee Name'].unique()
# Out:
# array(['FBL Item Handling Fee', 'Wrong Weight Adjustment', 'Commission',
#        'Free Shipping Max Fee', 'LCP Fee', 'Payment Fee',
#        'Item Price Credit', 'Lazada Bonus', 'Lazada Bonus - LZD co-fund',
#        'Campaign Fee', 'Promotional Charges Vouchers',
#        'Commission fee - correction for undercharge',
#        'Payment fee - correction for undercharge', 'Lost Claim',
#        'Reversal Item Price', 'Reversal Commission', 'Reversal LCP Fee',
#        'Sponsored Affiliates', 'Damaged Claim',
#        'LazFlash Extra/Everyday Below $9.99 Subsidy',
#        'Promotional Charges Flexi-Combo', 'FBL Bundling Fee',
#        'FBL Relabeling Fee', 'Reversal Promotional Charges Vouchers',
#        'Reversal Campaign Fee', 'Lazada Bonus - Reversal',
#        'Lazada Bonus - LZD co-fund - Reversal', 'Sponsored Product Fee',
#        'Shipping Fee Subsidy (By Seller)', 'Lazcoin discount',
#        'Everyday Below $9.99 Subsidy - Reversal/Everyday Below $9.99 Subsidy - Reversal',
#        'Storage Fee', 'Reversal Promotional Charges Flexi-Combo',
#        'FBL Item Handling Fee Discount', 'Shipping Fee Claims',
#        'Reimbursements Withholding tax',
#        'Seller balance adjustments - Credit',
#        'Sponsored Affiliates Refund', 'Reversal Lazcoin discount',
#        'FBL Handling Fee', 'Adjustments Campaign Fee',
#        'Buyer Review Incentive', 'Shipping Fee Correction',
#        'Item Price Subsidy', 'LazSubsidy', 'LCP Fee - Adjustment',
#        'FBL Outbound Fee',
#        'Commission fee refund -\xa0correction for overcharge', 'Free Shi',
#        'Adjustments Item Charge', 'Seller Incentive', 'Pullout Charge',
#        'Reversal Marketing Solution - Social Media Advertising'],
#       dtype=object)

# %%
##Run 37.1
list_cat = pd.read_excel(r'Settlement Project\Lazada/Converter Settlement.xlsx')
settlement_cat = settlement.merge(list_cat, how = 'left', left_on = settlement['Fee Name'].str.lower(), right_on = list_cat['Fee Name'].str.lower())
settlement_cat['Order No.'] = settlement_cat['Order No.'].astype(str).str.replace('.0', '', regex = False)

display(settlement_cat[(settlement_cat['Kategori'].isnull()) & (settlement_cat['Statement'].astype(str).str.contains('2023'))].drop_duplicates('Fee Name_x'))

settlement_cat = settlement_cat.drop_duplicates(['Transaction Number','key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Order Item No.'])
settlement_cat = settlement_cat.groupby(['key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Lazada SKU', 'Kategori'], dropna = False)['Amount'].sum().reset_index()


set_pivot = pd.pivot_table(settlement_cat, values = 'Amount', index = ['Order No.', 'Seller SKU'], columns = 'Kategori', aggfunc=np.sum).reset_index()


# indeks = lazada_wms[(lazada_wms['Order Number'].isin(['559843140940047', '570053517364893', '575957908200754',
#        '577436614667847', '581773151953393', '580784173888189',
#        '579252087390821', '583280309680693', '584406184163482',
#        '588374178583373', '593364733555669', '588645498508270',
#        '594172356552868', '589503459931050', '594020923234251',
#        '589428225222831', '593962925532162', '589367060015532',
#        '593877586114364', '593864327866052', '593837547275614',
#        '593305539632042', '593345977890705', '593756924841819',
#        '593731525177823', '593702979642006', '593694337695107',
#        '593680923404018', '588995293082147', '593555385780987',
#        '593293552996555', '588965810091534', '588954206670966',
#        '593491929312305', '593401902198461', '588819489968863',
#        '593249764268270', '593185587440558', '593129198674005',
#        '593107598461876', '588539419232974', '593104986085405',
#        '593092994762343', '593073368079777', '590367025213685',
#        '590358640068270', '594913320926038', '594884156934733',
#        '594869579365652', '590258088924976', '590234288354116',
#        '590254608264809', '594793350250446', '590199653348313',
#        '594718779068892', '594725942611774', '590119219895375',
#        '594661371334535', '594621183568903', '590054248795184',
#        '590013674417216', '590053015915262', '594577173324152',
#        '594561965181950', '589966062726742', '594527372175614',
#        '589927810658895', '589865638770513', '589856040817448',
#        '589825854186704', '589771800551067', '594284550997184',
#        '589706807705424', '594261317584967', '594199931063036',
#        '595939384524081', '595929398398589', '595904587150546',
#        '595830789026275', '591134298798589', '595780535198589',
#        '591094215398589', '595762388498589', '591153013325708',
#        '595750941320645', '595654931855706', '595684122674005',
#        '591035295324258', '595638902189716', '595617318036237',
#        '595582345878430', '590978824279055', '595457520058163',
#        '590827657814707', '590804894081596', '590791025107124',
#        '595377128277618', '595376915530919', '595234116430750',
#        '590644410151423', '595179186328420', '595157561508697',
#        '590536471216064', '600802357828790', '596112234729713',
#        '596012073162610', '595908480071136', '595877888916064',
#        '600582582342683', '595876035754794', '600510709997379',
#        '595776012117106', '595730202237782', '595582410941333',
#        '595521094823473', '595041632796594', '594991806324076',
#        '599604199324530', '599583760458961', '594935671784084',
#        '599577115751594', '594902865242113', '599556918276104',
#        '599544718368129', '594790437300144', '594752630645222',
#        '599357309627724', '599294380026506', '599182571538223',
#        '599112726973387', '594477412023933', '598899572856620',
#        '594224465085127', '594196086344168', '598784949947209',
#        '598711795152111', '594083495533791', '593993894924689',
#        '593920238449841', '593889617803385', '593865053092399',
#        '598063766922849', '593817088095184', '598401164078318',
#        '593783046561716', '598348315439422', '593731216980820',
#        '593693880837137', '593683844664323', '598067311522492',
#        '593440016191958', '598027924989819', '593361297377935',
#        '593300093127907', '593328627600361', '597194072187590',
#        '601862391003411', '596959259188060', '596948269606644',
#        '601622114150736', '596896672440727', '596850884618023',
#        '601374998521519', '601425527089233', '596754622322755',
#        '596710658162799', '601236119027872', '602944935032754',
#        '602945731602975', '598201876696064', '602890912032824',
#        '602700501288223', '598002235480992', '602647362437495',
#        '602665902282685', '602591538164879', '597916028988860',
#        '602583125588451', '597905018609822', '597869053377392',
#        '602519558256799', '597824057268488', '602467746523267',
#        '602382330971431', '602359924639337', '602340706687825',
#        '602307957414034', '597344417954512', '601965346879402',
#        '603778367893693', '603735704477524', '598876237481883',
#        '603430962325847', '598744855716768', '598735288226863',
#        '598741473840500', '603316134465448', '603322317613372',
#        '598651479420102', '603244518842123', '598499685419970',
#        '598482092634877', '603134945969772', '598466236693023',
#        '598455639149416', '598432061497459', '599637452132800',
#        '599612035376841', '604162768072064', '604158531241374',
#        '599364833007914', '603950566489370', '603943948217185',
#        '603895127652459', '606081301072062', '606010105343029',
#        '601234631674671', '601209255605424', '605718700173135',
#        '600931421886752', '605537906427543', '600671605813389',
#        '605293965672243', '605284158010790', '605205995065167',
#        '605052548095184', '604969186516768', '604695317327158',
#        '604671397611645', '604661196994892', '601793824281742',
#        '606452707196321', '601716056421857', '602072032874148',
#        '606675172494148', '602011296948313', '601981852693595',
#        '607081541959909', '602274011161069', '609265912710790',
#        '609162585439503', '609178510485567', '604032038469420',
#        '608593756577486', '603730818024267', '608102558873387',
#        '603402256711078', '603363812810866', '603160081407487',
#        '610106182769178', '609989532190676', '605001864235652',
#        '609602399145526', '609587357293108', '604823886767992',
#        '610701155545775', '605791698895484', '610200544132538',
#        '611234981563429', '606249450081272', '606115899390720',
#        '611824116558135', '611779194588223', '611793103063246',
#        '607015245183311', '613791139290373', '608935248776162',
#        '608906255379668', '613661328981358', '608749062894551',
#        '607532848220093', '609674051400474', '609593271342019',
#        '609499009318865', '609211614978639', '615055360901433',
#        '614848523561978', '614765992993023', '615322732997379',
#        '611736898514328', '611245260542025', '618164168220507',
#        '613226069177192', '617684719984473', '617324982915475',
#        '611984865482003', '616764349229865', '616695142439870',
#        '611901851728349', '645374694477695', '645373896877695',
#        '651866515266131', '578611062239848'])) &
#                    (lazada_wms['Item Name'] == 'Tropicana Slim Sirup Cocopandan 750ml - Sirup Bebas Gula')].index.to_list()
# lazada_wms['Lazada SKU'][indeks] = 'TR086WNAACKQ4RANID-28082439'

# indeks = set_pivot[set_pivot['Seller SKU'].astype(str) == 'PE14E23H63B61'].index.to_list()
# set_pivot['Seller SKU'][indeks] = 'PE23H63B18B61'

# indeks = set_pivot[set_pivot['Seller SKU'].astype(str) == 'PE14E23H63B61'].index.to_list()
# set_pivot['Seller SKU'][indeks] = 'PE23H63B18B61'

# indeks = set_pivot[set_pivot['Seller SKU'].astype(str) == '(B)2101813443P4'].index.to_list()
# set_pivot['Seller SKU'][indeks] = 'PH63(2)B61(2)'

# indeks = set_pivot[set_pivot['Seller SKU'].astype(str) == '2101813443P4'].index.to_list()
# set_pivot['Seller SKU'][indeks] = 'PH63(2)B61(2)'

# indeks = set_pivot[set_pivot['Seller SKU'].astype(str) == '(B)2101845443P4'].index.to_list()
# set_pivot['Seller SKU'][indeks] = '2101845443P4'

# index = lazada_wms[lazada_wms['SKU'].astype(str) == '2101845443P4'].index.to_list()
# lazada_wms['Brand'][index] = 'Bundle'
# lazada_wms['Bundle Flag'][index] = 'Bundle'
# lazada_wms['Parent Item'][index] = 'HiLo Ketan Hitam 40 Sch'

set_pivot['Order No.'] = set_pivot['Order No.'].astype(str)
set_pivot['Seller SKU'] = set_pivot['Seller SKU'].astype(str)


### tambahan timo jan 23
set_pivot.loc[set_pivot['Seller SKU']=='(E)2101492P04','Seller SKU']='(E)2101492P4'

lazada_wms['Order Number'] = lazada_wms['Order Number'].astype(str)
lazada_wms['Real SKU'] = lazada_wms['Real SKU'].astype(str)

no_prop = lazada_wms[lazada_wms['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])]
lazada_prop = lazada_wms[~lazada_wms['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])]

bundle_wms = lazada_prop[lazada_prop['Bundle Name'].notnull()]
lazada_set = lazada_prop[lazada_prop['Bundle Name'].isnull()]


set_pivot_copy=set_pivot.copy() #cek

lazada_set = lazada_set.merge(set_pivot.drop_duplicates(['Order No.', 'Seller SKU']), how = 'left', left_on = ['Order Number', 'Real SKU'], right_on = ['Order No.', 'Seller SKU'])
lazada_set['BTL Cost'] = lazada_set['BTL Cost'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number', 'Item Name'])['Total Net Before PPN'].transform('sum')
lazada_set['ComFee'] = lazada_set['ComFee'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number', 'Item Name'])['Total Net Before PPN'].transform('sum')
lazada_set['FullFee'] = lazada_set['FullFee'].fillna(0) * lazada_set['Qty. Invoiced']/lazada_set.groupby(['Order Number', 'Item Name'])['Qty. Invoiced'].transform('sum')
lazada_set['Payment Fee'] = lazada_set['Payment Fee'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number', 'Item Name'])['Total Net Before PPN'].transform('sum')
lazada_set['Shipping Fee'] = lazada_set['Shipping Fee'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number', 'Item Name'])['Total Net Before PPN'].transform('sum')
lazada_set['Total Transfer'] = lazada_set['Total Transfer'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number', 'Item Name'])['Total Net Before PPN'].transform('sum')

lazada_set_copy=lazada_set.copy() #cek

bundle_set = bundle_wms.merge(lazada_set.groupby(['Order Number', 'Item Name'])[['BTL Cost', 'ComFee', 'FullFee','Payment Fee', 'Shipping Fee', 'Total Transfer']].sum().reset_index(), how = 'left', left_on = ['Order Number', 'Bundle Name'], right_on = ['Order Number', 'Item Name'])
# display(bundle_set[['BTL Cost']].head(5))
bundle_set = bundle_set.rename(columns = {'Item Name_x' : 'Item Name'})
bundle_set = bundle_set.drop('Item Name_y', axis = 1)

bundle_set['BTL Cost'] = bundle_set['BTL Cost'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['Order Number', 'Bundle Name'])['Total Net Before PPN'].transform('sum')
bundle_set['ComFee'] = bundle_set['ComFee'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['Order Number', 'Bundle Name'])['Total Net Before PPN'].transform('sum')
bundle_set['FullFee'] = bundle_set['FullFee'].fillna(0) * bundle_set['Qty. Invoiced']/bundle_set.groupby(['Order Number', 'Bundle Name'])['Qty. Invoiced'].transform('sum')
bundle_set['Payment Fee'] = bundle_set['Payment Fee'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['Order Number', 'Bundle Name'])['Total Net Before PPN'].transform('sum')
bundle_set['Shipping Fee'] = bundle_set['Shipping Fee'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['Order Number', 'Bundle Name'])['Total Net Before PPN'].transform('sum')
bundle_set['Total Transfer'] = bundle_set['Total Transfer'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['Order Number', 'Bundle Name'])['Total Net Before PPN'].transform('sum')

bundle_set_copy=bundle_set.copy() #cek

lazada_set = lazada_set.append(bundle_set, ignore_index = True, sort = False)
lazada_set = lazada_set.append(no_prop, ignore_index = True, sort = False)

no_details = settlement[(settlement['Details'].isnull()) & (settlement['Order No.'].notnull())]
no_details_cat = no_details.merge(list_cat, how = 'left', left_on = no_details['Fee Name'].str.lower(), right_on = list_cat['Fee Name'].str.lower())
no_details_cat['Order No.'] = no_details_cat['Order No.'].astype(str).str.replace('.0', '', regex = False)
no_details_cat = no_details_cat.drop_duplicates(['key_0', 'Fee Name_x', 'Order No.', 'Transaction Number'])
no_details_cat = no_details_cat.groupby(['key_0', 'Fee Name_x', 'Order No.', 'Kategori'])['Amount'].sum().reset_index()
no_details_cat = no_details_cat[no_details_cat['Order No.'] != '0']

no_details_pivot = pd.pivot_table(no_details_cat, values = 'Amount', index = ['Order No.'], columns = 'Kategori', aggfunc=np.sum).reset_index()

no_prop = lazada_set[lazada_set['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])]
lazada_prop = lazada_set[~lazada_set['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])]

bundle_wms = lazada_prop[lazada_prop['Bundle Name'].notnull()]
lazada_set = lazada_prop[lazada_prop['Bundle Name'].isnull()]

lazada_set = lazada_set.merge(no_details_pivot, how = 'left', left_on = ['Order Number'], right_on = ['Order No.'])
if 'BTL Cost_x' in lazada_set.columns: ## timo Mar 23
    lazada_set['BTL Cost'] = lazada_set['BTL Cost_x'] + (lazada_set['BTL Cost_y'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number'])['Total Net Before PPN'].transform('sum'))
if 'ComFee_x' in lazada_set.columns:
    lazada_set['ComFee'] = lazada_set['ComFee_x'] + (lazada_set['ComFee_y'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number'])['Total Net Before PPN'].transform('sum'))
if 'ComFee_x' in lazada_set.columns:
    lazada_set['FullFee'] = lazada_set['FullFee_x'] + (lazada_set['FullFee_y'].fillna(0) * lazada_set['Qty. Invoiced']/lazada_set.groupby(['Order Number'])['Qty. Invoiced'].transform('sum'))
if 'Payment Fee_x' in lazada_set.columns:
    lazada_set['Payment Fee'] = lazada_set['Payment Fee_x'] + (lazada_set['Payment Fee_y'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number'])['Total Net Before PPN'].transform('sum'))
if 'Shipping Fee_x' in lazada_set.columns:
    lazada_set['Shipping Fee'] = lazada_set['Shipping Fee_x'] + (lazada_set['Shipping Fee_y'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number'])['Total Net Before PPN'].transform('sum'))
if 'Total Transfer_x' in lazada_set.columns:
    lazada_set['Total Transfer'] = lazada_set['Total Transfer_x'] + (lazada_set['Total Transfer_y'].fillna(0) * lazada_set['Total Net Before PPN']/lazada_set.groupby(['Order Number'])['Total Net Before PPN'].transform('sum'))

bundle_wms = bundle_wms.drop(['BTL Cost'], axis = 1)
bundle_set = bundle_wms.merge(lazada_set.groupby(['Order Number', 'Item Name'])[['BTL Cost']].sum().reset_index(), how = 'left', left_on = ['Order Number', 'Bundle Name'], right_on = ['Order Number', 'Item Name'])
bundle_set = bundle_set.rename(columns = {'Item Name_x' : 'Item Name'})
bundle_set = bundle_set.drop('Item Name_y', axis = 1)

bundle_set['BTL Cost'] = bundle_set['BTL Cost'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['Order Number', 'Bundle Name'])['Total Net Before PPN'].transform('sum')

lazada_set = lazada_set.append(bundle_set, ignore_index = True, sort = False)
lazada_set = lazada_set.append(no_prop, ignore_index = True, sort = False)

no_details['Order No.'] = no_details['Order No.'].astype(str).str.replace('.0', '', regex = False)

# settlement_cat = settlement.merge(list_cat, how = 'left', left_on = settlement['Fee Name'].str.lower(), right_on = list_cat['Fee Name'].str.lower())
# settlement_cat['Order No.'] = settlement_cat['Order No.'].astype(str).str.replace('.0', '', regex = False)

set_refund = settlement_cat[settlement_cat['Fee Name_x'] == 'Reversal Item Price'][['Order No.', 'Seller SKU']]

bundle_payment = lazada_set[lazada_set['Bundle Name'].notnull()]
lazada_payment = lazada_set[lazada_set['Bundle Name'].isnull()]

indeks = lazada_payment[lazada_payment['Order No._x'].notnull()].index.to_list()
lazada_payment['Paid'] = np.nan
lazada_payment['Paid'][indeks] = 'Paid'
lazada_payment['Paid'] = lazada_payment['Paid'].fillna('Unpaid')

indeks = lazada_payment[(lazada_payment['Paid'] == 'Paid') & (lazada_payment['Total Transfer'] == 0)&
                        ~(lazada_payment['Real SKU'].str.contains('(B)'))].index.to_list()
lazada_payment['Paid'][indeks] = 'Refund'

lazada_payment = lazada_payment.drop('Order No._y', axis = 1)

gimmick_tapi_bundle = ['(B)2309005305P3', '(B)2309005300P3','(B)(R)2LM0801029P2']## tambah item feb 2024
# print(lazada_payment[(lazada_payment['Order Number']=='1226117461058062')][['Order Number','Real SKU','Paid','Order Paid','Brand','Order No._x']])
paid_order = lazada_payment[(lazada_payment['Paid'] == 'Paid') & (lazada_payment['Brand'] == 'L-Men')]['Order Number'].unique()
indeks = lazada_payment[(lazada_payment['Real SKU'].isin(gimmick_tapi_bundle)) &
                       (lazada_payment['Order Number'].isin(paid_order))].index.to_list()
lazada_payment['Paid'][indeks] = 'Paid'

temp = lazada_payment.merge(set_refund.drop_duplicates(['Order No.', 'Seller SKU']), how = 'left', left_on = ['Order Number', 'Real SKU'], right_on = ['Order No.', 'Seller SKU']).set_index(lazada_payment.index)
indeks = temp[temp['Order No._y'].notnull()].index.to_list()
lazada_payment['Paid'][indeks] = 'Half Paid'

# indeks = lazada_payment[(lazada_payment['Paid'] == 'Half Paid') & (lazada_payment['Total Transfer'] == 0)].index.to_list()
indeks = lazada_payment[(lazada_payment['Paid'] == 'Half Paid') & (lazada_payment['Total Transfer'] == 0)&
                        ~(lazada_payment['Real SKU'].str.contains('(B)'))].index.to_list() ### feb 2024 gimmick dianggap refund
lazada_payment['Paid'][indeks] = 'Refund'

temp_status = lazada_payment.drop_duplicates(['Order Number', 'Paid']).sort_values(['Paid']).groupby('Order Number')['Paid'].agg(lambda x: ','.join(x)).reset_index()
temp_status = temp_status.rename(columns = {'Paid' : 'Order Paid'})

lazada_payment = lazada_payment.merge(temp_status, how = 'left', on = 'Order Number')

# order_nol = lazada_payment[lazada_payment['Paid Order'] == 'Paid'].groupby('Order Number')['Total Transfer'].sum().reset_index()
# half_nol = order_nol[(order_nol['Total Transfer'] != 0)]['Order Number'].unique()
# full_nol = order_nol[(order_nol['Total Transfer'] == 0) ]['Order Number'].unique()
# orderitem_nol = lazada_payment[(lazada_payment['Total Transfer'] == 0)]['Order Number'].unique()

# indeks = lazada_payment[(lazada_payment['Order Number'].isin(orderitem_nol)) & (lazada_payment['Order Number'].isin(full_nol) & (lazada_payment['Paid'] == 'Paid'))].index.to_list()
# lazada_payment['Order Paid'][indeks] = 'Full Nol'

# indeks = lazada_payment[(lazada_payment['Order Number'].isin(orderitem_nol)) & (lazada_payment['Order Number'].isin(half_nol) & (lazada_payment['Paid'] == 'Paid'))].index.to_list()
# lazada_payment['Order Paid'][indeks] = 'Half Nol'


bundle_payment = bundle_payment.merge(lazada_payment.groupby(['Order Number', 'Item Name'])[['Paid', 'Order Paid']].first().reset_index(), how = 'left', left_on = ['Order Number', 'Bundle Name'], right_on = ['Order Number', 'Item Name'])
bundle_payment = bundle_payment.rename(columns = {'Item Name_x' : 'Item Name'})
bundle_payment = bundle_payment.drop('Item Name_y', axis = 1)

lazada_payment = lazada_payment.append(bundle_payment, ignore_index = True, sort = False)
# Out:
#                                       key_0 Transaction Date  \
# 85674                 sponsored product fee      09-Nov-2023
# 984112  seller balance adjustments - credit      21-Nov-2023
#
#                   Transaction Type                           Fee Name_x  \
# 85674   Other Services-Lazada Fees                Sponsored Product Fee
# 984112                Orders-Sales  Seller balance adjustments - Credit
#
#             Transaction Number Details Seller SKU Lazada SKU     Amount  \
# 85674   ID109XE-NI9PQH6-231109     NaN        NaN        NaN -1198800.0
# 984112  ID109XE-MPTJES8-231121     NaN        NaN        NaN   735878.0
#
#         VAT in Amount  WHT Amount WHT included in Amount  \
# 85674        118800.0         0.0                     No
# 984112            0.0         0.0                     No
#
#                         Statement Paid Status Order No.  Order Item No.  \
# 85674   09 Nov 2023 - 09 Nov 2023        paid         0             NaN
# 984112  21 Nov 2023 - 21 Nov 2023        paid         0             NaN
#
#        Order Item Status Shipping Provider Shipping Speed Shipment Type  \
# 85674                NaN               NaN            NaN           NaN
# 984112               NaN               NaN            NaN           NaN
#
#         Reference                                            Comment  \
# 85674         0.0               Hot Slot Hot Deals Fee (Sept Payday)
# 984112        0.0  Reimbursement for Commission Waiver Lazmall La...
#
#         PaymentRefId                                Source  Unnamed: 0  \
# 85674            NaN  01e948e55523ac72e14bd0753f6b5177.csv         NaN
# 984112           NaN  1bbb39098ed753eb9f31a64e35f7128a.csv         NaN
#
#        Fee Name_y Kategori Note
# 85674         NaN      NaN  NaN
# 984112        NaN      NaN  NaN
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:232: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py:1135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_values(indexer, value)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:234: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:237: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:247: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:9203: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Order No._x'} in the result is deprecated and will raise a MergeError in a future version.
#   validate=validate,
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:251: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:255: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# settlement_cat[settlement_cat['Order No.']=='1282699509140819']

settlement_cat[(settlement_cat['Kategori'].isnull())].drop_duplicates('Fee Name_x')[['Fee Name_x','Order No.','Amount']].values
# Out:
# array([['FBL Outbound Fee', '0', -10802076.0],
#        ['Free Shi', 'nan', 0.0],
#        ['Reversal Marketing Solution - Social Media Advertising', '0',
#         6778783.0],
#        ['Seller balance adjustments - Credit', '0', 30585056.0],
#        ['Sponsored Product Fee', '0', -1198800.0]], dtype=object)

# %%
import numpy as np

# %%
### run 38

# import os
# import pandas as pd

# settlement = pd.DataFrame()
# for i in os.listdir('Settlement Project\Lazada\Settlement/'):
#     print(i)
#     if 'finance' in i:
#         if '2021-08-02' in i or '2021-08-09' in i or '2021-08-16' in i or '2021-08-23' in i:
#             temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i), sep = ';')
#         else :
#             temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i))
#     else :
#         temp = pd.read_csv('Settlement Project\Lazada\Settlement/' + str(i), sep = ';')
#     temp['Source'] = i
#     true_col = ['Transaction Date', 'Transaction Type', 'Fee Name', 'Transaction Number', 'Details', 'Seller SKU', 'Lazada SKU', 'Amount', 'VAT in Amount', 'WHT Amount', 
#                 'WHT included in Amount', 'Statement', 'Paid Status', 'Order No.', 'Order Item No.', 'Order Item Status', 'Shipping Provider', 'Shipping Speed', 
#                 'Shipment Type', 'Reference', 'Comment', 'PaymentRefId', 'Source']
#     if temp.columns.to_list() == true_col :
#         print('Column sama')
#     else:
#         print('Column beda')
#         print([x for x in true_col if x not in temp.columns.to_list()])
#         print([x for x in temp.columns.to_list() if x not in true_col])
#     settlement = settlement.append(temp, ignore_index = True, sort = False)
    
list_cat = pd.read_excel(r'Settlement Project\Lazada/Converter Settlement.xlsx')
settlement_cat = settlement.merge(list_cat, how = 'left', left_on = settlement['Fee Name'].str.lower(), right_on = list_cat['Fee Name'].str.lower())
settlement_cat['Order No.'] = settlement_cat['Order No.'].astype(str).str.replace('.0', '', regex = False)
settlement_cat = settlement_cat.drop_duplicates(['key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Order Item No.'])
settlement_cat = settlement_cat.groupby(['key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Lazada SKU', 'Kategori'], dropna = False)['Amount'].sum().reset_index()

settlement_cat[settlement_cat['Kategori'].isnull()]['Fee Name_x'].unique()
# Out:
# array(['FBL Outbound Fee', 'Free Shi',
#        'Reversal Marketing Solution - Social Media Advertising',
#        'Seller balance adjustments - Credit', 'Sponsored Product Fee'],
#       dtype=object)

# %%
settlement_cat[(settlement_cat['Kategori'].isnull())&
               (settlement_cat['Order No.'].str.len()>5)]#['Fee Name_x'].unique()
# list_cat = pd.read_excel(r'Settlement Project\Lazada/Converter Settlement.xlsx')
# # settlement[settlement['Fee Name']=='Commission fee refund -\xa0correction for overcharge']
# list_cat['Fee Name'][63]
# Out:
# Empty DataFrame
# Columns: [key_0, Fee Name_x, Order No., Seller SKU, Lazada SKU, Kategori, Amount]
# Index: []

# %%
### run 39
settlement_cat = settlement.merge(list_cat, how = 'left', left_on = settlement['Fee Name'].str.lower(), right_on = list_cat['Fee Name'].str.lower())
settlement_cat['Order No.'] = settlement_cat['Order No.'].astype(str).str.replace('.0', '', regex = False)

display(settlement_cat[(settlement_cat['Kategori'].isnull()) &
              (settlement_cat['Statement'].astype(str).str.contains('2022'))].drop_duplicates('Fee Name_x')
       )
settlement_cat = settlement_cat.drop_duplicates(['key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Order Item No.'])
settlement_cat = settlement_cat.groupby(['key_0', 'Fee Name_x', 'Order No.', 'Seller SKU', 'Lazada SKU', 'Kategori'], dropna = False)['Amount'].sum().reset_index()
# Out:
# Empty DataFrame
# Columns: [key_0, Transaction Date, Transaction Type, Fee Name_x, Transaction Number, Details, Seller SKU, Lazada SKU, Amount, VAT in Amount, WHT Amount, WHT included in Amount, Statement, Paid Status, Order No., Order Item No., Order Item Status, Shipping Provider, Shipping Speed, Shipment Type, Reference, Comment, PaymentRefId, Source, Unnamed: 0, Fee Name_y, Kategori, Note]
# Index: []

# %%
settlement[settlement['Fee Name'].isnull()]['Statement'].unique()
# settlement['Fee Name'].unique()
# Out:
# array([], dtype=object)

# %%
# settlement[]

# %%
### run 40
gimmick_tapi_bundle = ['(B)2309005305P3', '(B)2309005300P3','(B)(R)2LM0801029P2']

paid_order = lazada_payment[(lazada_payment['Paid'] == 'Paid') & (lazada_payment['Brand'] == 'L-Men')]['Order Number'].unique()
indeks = lazada_payment[(lazada_payment['Real SKU'].isin(gimmick_tapi_bundle)) &
                       (lazada_payment['Order Number'].isin(paid_order))].index.to_list()
lazada_payment['Paid'][indeks] = 'Paid'
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
## run 41

# indeks = lazada_payment[(lazada_payment['Paid'] == 'Paid') &
#       (lazada_payment['Shipment Type Name'] == 'dropshipping') &
#       (lazada_payment['Status'].isnull()) &
#       (pd.to_datetimelazada_payment['True datetime'] > '2021-07-28') &
#        (lazada_payment['True datetime'] < '2021-09-06')
#       ].index.to_list()
# lazada_payment['Status'][indeks] = 'confirmed'
# lazada_payment['Warehouse Quantity'][indeks] = lazada_payment['Qty. Invoiced'][indeks]

tambah_unpaid = pd.read_excel(r'Settlement Project/unpaid order to Andra.xlsx', sheet_name = 'Unpaid to cancel or not found')
tambah_unpaid2 = pd.read_excel(r'Settlement Project/Unpaid Mar.xlsx', sheet_name = 'lazada')

tambah_unpaid['Order Number'] = tambah_unpaid['Order #'].astype(str)
tambah_unpaid = tambah_unpaid.append(tambah_unpaid2, ignore_index = True, sort = False)
indeks = lazada_payment[(lazada_payment['Order Number'].isin(tambah_unpaid['Order Number'])) & (lazada_payment['Shipment Type Name'] == 'dropshipping')].index.to_list()
print(len(indeks))
lazada_payment['Order Status'][indeks] = 'Cancel'
lazada_payment['Paid'][indeks] = 'Cancel'

rumus_status = pd.read_excel(r'Settlement Project/Rumus Status.xlsx', sheet_name = 'lazada')
if len(rumus_status != 0):
    for i in range(len(rumus_status)):
        stat = rumus_status['Order Status'][i]
        indeks = lazada_payment[(lazada_payment['Paid'] == 'Unpaid') &
                             (lazada_payment['Order Status'].str.lower() == stat.lower())].index.to_list()
        lazada_payment['Order Status'][indeks] = 'Cancel'
        lazada_payment['Paid'][indeks] = 'Cancel'


unpaid = lazada_payment[lazada_payment['Paid'] == 'Unpaid']
paid = lazada_payment[lazada_payment['Paid'] != 'Unpaid']

unpaid['Total Transfer'] = unpaid['Paid Price']
unpaid['BTL Cost'] = 0

no_prop = unpaid[unpaid['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])]
unpaid_prop = unpaid[~unpaid['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])]

unpaid_real = unpaid_prop[unpaid_prop['Bundle Name'].isnull()]
unpaid_bundle = unpaid_prop[unpaid_prop['Bundle Name'].notnull()]

unpaid_real['FullFee'] = unpaid_real['Qty. Invoiced'] * 3000

temp_unpaid_real = unpaid_real.groupby(['Order Number', 'Item Name'])['FullFee'].sum().reset_index()
unpaid_bundle['FullFee'] = unpaid_bundle.merge(temp_unpaid_real.drop_duplicates(['Order Number', 'Item Name']), how = 'left', left_on = ['Order Number', 'Bundle Name'], right_on = ['Order Number', 'Item Name']).set_index(unpaid_bundle.index)['FullFee_y']
unpaid_bundle['FullFee'] = unpaid_bundle['FullFee'].fillna(0) * unpaid_bundle['Qty. Invoiced']/unpaid_bundle.groupby(['Order Number', 'Bundle Name'])['Qty. Invoiced'].transform('sum')

indeks = unpaid_real[(unpaid_real['Brand'] != 'Bundle') & (unpaid_real['Brand'] != 'L-Men')].index.to_list()
# unpaid_real.loc[(unpaid_real['Brand'] != 'Bundle') & (unpaid_real['Brand'] != 'L-Men'),'ComFee']=unpaid_real['Paid Price'] * 4.95 / 100
unpaid_real['ComFee'][indeks] = unpaid_real['Paid Price'][indeks] * 4.95 / 100

indeks = unpaid_real[(unpaid_real['Brand'] == 'L-Men')].index.to_list()
unpaid_real['ComFee'][indeks] = unpaid_real['Paid Price'][indeks] * 0.99 / 100

indeks = unpaid_real[(unpaid_real['Brand'] == 'Bundle') & 
                     (unpaid_real['Real SKU'].astype(str).str.contains('^P', regex = True))].index.to_list()
unpaid_real['ComFee'][indeks] = unpaid_real['Paid Price'][indeks] * 4.95 / 100

indeks = unpaid_real[(unpaid_real['Brand'] == 'Bundle') & 
                     (unpaid_real['Real SKU'].astype(str).str.contains('^P', regex = True)) &
                    (unpaid_real['Real SKU'].astype(str).str.contains('^[^NHTE]+$', regex = True))].index.to_list()
unpaid_real['ComFee'][indeks] = unpaid_real['Paid Price'][indeks] * 0.99 / 100

sku_lmen = lazada_set[lazada_set['Brand'] == 'L-Men']['Real SKU'].unique()

indeks = unpaid_real[(unpaid_real['Brand'] == 'Bundle') & 
                     (~unpaid_real['Real SKU'].astype(str).str.contains('^P', regex = True)) &
                    (~unpaid_real['SKU Produk 1'].isin(sku_lmen))].index.to_list()
unpaid_real['ComFee'][indeks] = unpaid_real['Paid Price'][indeks] * 4.95 / 100

indeks = unpaid_real[(unpaid_real['Brand'] == 'Bundle') & 
                     (~unpaid_real['Real SKU'].astype(str).str.contains('^P', regex = True)) &
                    (unpaid_real['SKU Produk 1'].isin(sku_lmen))].index.to_list()
unpaid_real['ComFee'][indeks] = unpaid_real['Paid Price'][indeks] * 0.99 / 100

temp_unpaid_real = unpaid_real.groupby(['Order Number', 'Item Name'])['ComFee'].sum().reset_index()
unpaid_bundle['ComFee'] = unpaid_bundle.merge(temp_unpaid_real.drop_duplicates(['Order Number', 'Item Name']), how = 'left', left_on = ['Order Number', 'Bundle Name'], right_on = ['Order Number', 'Item Name']).set_index(unpaid_bundle.index)['ComFee_y']
unpaid_bundle['ComFee'] = unpaid_bundle['ComFee'].fillna(0) * unpaid_bundle['Total Net Before PPN']/unpaid_bundle.groupby(['Order Number', 'Bundle Name'])['Total Net Before PPN'].transform('sum')

unpaid_prop = unpaid_real.append(unpaid_bundle, ignore_index = True, sort = False)
unpaid = unpaid_prop.append(no_prop, ignore_index = True, sort = False)

unpaid['Payment Fee'] = 0
unpaid['Shipping Fee'] = 0

lazada_set = paid.append(unpaid, ignore_index = True, sort = False)

lazada_set['Bi Produk'] = lazada_set['BTL Cost'] + lazada_set['Total Transfer']
lazada_set['Real BTL Cost'] = lazada_set['Bi Produk'] - lazada_set['Total Net Before PPN']
# Out:
# 0
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py:1135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_values(indexer, value)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# [i for i in indeks if i not in unpaid_real.index]
# unpaid_real['ComFee'][indeks]
# unpaid_real['ComFee'][indeks] = unpaid_real['Paid Price'][indeks] * 4.95 / 100
unpaid_real['ComFee'][429059]
# Out:
# 0.0

# %%
lazada_set[(lazada_set['Total Transfer'].isnull()) & (lazada_set['Order Number'].isin(settlement_cat['Order No.'])) & (~lazada_set['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])) &
          (lazada_set['Bundle Name'].isnull())].groupby(['Item Name','Real SKU', 'Real Nama Produk', 'Bundle Name'], dropna = False)['Order Number'].first().reset_index()

# %%
## for display only
pd.options.display.max_columns = 150

# %%
## run 42
indeks = lazada_set[(lazada_set['Paid'] == 'Paid') & (lazada_set['WH'] == 'Telkom')].index.to_list()
lazada_set['Status'][indeks] = 'confirmed'

indeks = lazada_set[lazada_set['Paid'] == 'Paid-0'].index.to_list()
lazada_set['Paid'][indeks] = 'Refund'

indeks = lazada_set[(lazada_set['Paid'] == 'Unpaid') & (lazada_set['Status'].isin(['Delivery Failed', 'Out of stock',
       'Cancelled']))].index.to_list()
lazada_set['Paid'][indeks] = 'Cancel'

lazada_set_gimmick = lazada_set[lazada_set['Brand'].isin(['Gimmick', 'Bonus Produk'])]
paid = lazada_set[lazada_set['Paid'] == 'Paid']['Order Number'].unique()

indeks = lazada_set_gimmick[lazada_set_gimmick['Order Number'].isin(paid)].index.to_list()
lazada_set['Paid'][indeks] = 'Paid'

total_trx = lazada_set.drop('BTL Cost', axis = 1)

total_trx = total_trx.rename(columns = {
    'Lazada SKU' : 'Product ID',
    'Paid Price' : 'Total Selcen',
    'Status Seller Centre' : 'Order Status_y',
    'Shipment Type Name' : 'Warehouse Origin',
    'Status' : 'SO STATUS',
    'Bi Produk' : 'Total Produk Prop',
    'FullFee' : 'Fullfee Prop',
    'ComFee' : 'Comfee Prop',
    'Real BTL Cost' : 'BTL Cost',
    'Created at' : 'Order Date Seller Centre'
})

total_trx_full = total_trx.copy()

total_trx_full = total_trx_full.rename(columns = {
    'Total Selcen' : 'Total Seller Centre', 
    'Order Status_y' : 'Order Status Seller Centre',
    'SO STATUS' : 'Status Gudang'
})

total_trx_full['Total Produk Prop Adj'] = total_trx_full['Total Produk Prop']/1.11
total_trx_full['BTL Cost'] = total_trx_full['Total Produk Prop Adj'] - total_trx_full['Total Net Before PPN']
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run 43
import numpy as np

temp_order = total_trx_full.groupby(['Order Number', 'Paid'])['Fullfee Prop'].sum().reset_index()
orders = temp_order[(temp_order['Paid'] == 'Paid') & (temp_order['Fullfee Prop'] == 0)]['Order Number'].unique()

sept_total = total_trx_full[(total_trx_full['Order Number'].isin(orders)) & 
                           (total_trx_full['Warehouse Origin'] == 'own_warehouse')]
print(len(sept_total))
nonsept_trx = total_trx_full[~total_trx_full.index.isin(sept_total.index)]

sept_trx = sept_total[sept_total['Paid'].isin(['Paid', 'Half Paid'])]
sept_notpaid = sept_total[~sept_total['Paid'].isin(['Paid', 'Half Paid'])]

no_prop = sept_trx[sept_trx['Brand'].isin(['Bonus Produk', 'Gimmick'])]
sept_prop = sept_trx[~sept_trx['Brand'].isin(['Bonus Produk', 'Gimmick'])]

total_trx_real = sept_prop[sept_prop['Bundle Name'].isnull()]
total_trx_bundle = sept_prop[sept_prop['Bundle Name'].notnull()]

total_trx_real['Fullfee Prop'] = total_trx_real['Qty. Invoiced'] * -2750

indeks = total_trx_real[(total_trx_real['Brand'] == 'Bundle')].index.to_list()
total_trx_real['Fullfee Prop'][indeks] = total_trx_real['Fullfee Prop'][indeks] - 1200

# total_trx_bundle = total_trx_bundle.drop('Fullfee Prop', axis = 1)
total_trx_bundle['Fullfee Prop'] = total_trx_bundle.merge(total_trx_real[['Order Number', 'Item Name', 'Fullfee Prop']].drop_duplicates(['Order Number', 'Item Name']), how = 'left', left_on = ['Order Number', 'Bundle Name'], right_on = ['Order Number', 'Item Name']).set_index(total_trx_bundle.index)['Fullfee Prop_y']
total_trx_bundle['Fullfee Prop'] = total_trx_bundle['Fullfee Prop'].fillna(0) * total_trx_bundle['Qty. Invoiced']/total_trx_bundle.groupby(['Order Number', 'Bundle Name'])['Qty. Invoiced'].transform('sum')

total_trx_final = total_trx_real.append(total_trx_bundle, ignore_index = True, sort = False)

indeks = no_prop[no_prop['Bundle Name'].isnull()].index.to_list()
no_prop['Fullfee Prop'] = no_prop['Qty. Invoiced'] * -2750

total_trx_final = total_trx_final.append(no_prop, ignore_index = True, sort = False)

sept_total = total_trx_final.append(sept_notpaid, ignore_index = True, sort = False)

indeks = sept_total[(sept_total['WH'] == 'Telkom')].index.to_list()
sept_total['Fullfee Prop'][indeks] = np.nan

total_trx_full = nonsept_trx.append(sept_total, ignore_index = True, sort = False)
total_trx_full
# Out:
# 246
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Order Item Id Order Type Order Flag         Lazada Id         SKU  \
# 0        1032400403793459     NORMAL        NaN  1032400403793459  1101692318
# 1        1032389037672072     NORMAL        NaN  1032389037672072     PT25T74
# 2        1032378095600771     NORMAL        NaN  1032378095600771  2104110110
# 3        1032378095700771     NORMAL        NaN  1032378095700771  2104110110
# 4        1032378095800771     NORMAL        NaN  1032378095800771  2104110110
# ...                   ...        ...        ...               ...         ...
# 1051963  1450112019408504     NORMAL        NaN  1450112019408504  2304051288
# 1051964  1491793146829671     NORMAL        NaN  1491793146829671  2304051288
# 1051965  1491793146929671     NORMAL        NaN  1491793146929671  2304051288
# 1051966  1482823659308111     NORMAL        NaN  1482823659308111  2304051288
# 1051967  1482823659408111     NORMAL        NaN  1482823659408111  2304051288
#
#                         Product ID Order Date Seller Centre Updated at  \
# 0        6087298504_ID-11660714080        05 Jan 2023 23:53        NaN
# 1        7155976060_ID-13469102853        05 Jan 2023 23:33        NaN
# 2         1096720178_ID-1727846672        05 Jan 2023 23:28        NaN
# 3         1096720178_ID-1727846672        05 Jan 2023 23:28        NaN
# 4         1096720178_ID-1727846672        05 Jan 2023 23:28        NaN
# ...                            ...                      ...        ...
# 1051963  8123988410_ID-14518124296        29 May 2024 00:11        NaN
# 1051964  8123988410_ID-14518124296        07 Jul 2024 01:44        NaN
# 1051965  8123988410_ID-14518124296        07 Jul 2024 01:44        NaN
# 1051966  8123988410_ID-14518124296        11 Jul 2024 23:22        NaN
# 1051967  8123988410_ID-14518124296        11 Jul 2024 23:22        NaN
#
#              Order Number Invoice Required                  Customer Name  \
# 0        1032400403693459               No  Bakung Celluler,aswati,nardi.
# 1        1032389037572072               No                  Lisa Fitiatie
# 2        1032378095500771               No                 Hendra Kusumah
# 3        1032378095500771               No                 Hendra Kusumah
# 4        1032378095500771               No                 Hendra Kusumah
# ...                   ...              ...                            ...
# 1051963  1450112018208504               No              Viktor Darmawanto
# 1051964  1491793146629671               No                         Charly
# 1051965  1491793146629671               No                         Charly
# 1051966  1482823659108111               No               bili atau salmah
# 1051967  1482823659108111               No               bili atau salmah
#
#          Customer Email  National Registration Number Shipping Name  \
# 0                   NaN                           NaN           B*i
# 1                   NaN                           NaN           L*e
# 2                   NaN                           NaN           H*h
# 3                   NaN                           NaN           H*h
# 4                   NaN                           NaN           H*h
# ...                 ...                           ...           ...
# 1051963             NaN                           NaN           V*o
# 1051964             NaN                           NaN           C*y
# 1051965             NaN                           NaN           C*y
# 1051966             NaN                           NaN           b*h
# 1051967             NaN                           NaN           b*h
#
#         Shipping Address  Shipping Address2 Shipping Address3  \
# 0                k*3,k*i                NaN               B*n
# 1                V*g,J*9                NaN               B*n
# 2                    p*r                NaN               J*t
# 3                    p*r                NaN               J*t
# 4                    p*r                NaN               J*t
# ...                  ...                ...               ...
# 1051963              J*r                NaN               D*a
# 1051964          J*a,K*h                NaN               J*t
# 1051965          J*a,K*h                NaN               J*t
# 1051966              j*u                NaN               B*n
# 1051967              j*u                NaN               B*n
#
#         Shipping Address4 Shipping Address5  Shipping Phone Number  \
# 0                     K*g               J*i                    NaN
# 1                     K*n               P*g                    NaN
# 2                     K*r               B*a                    NaN
# 3                     K*r               B*a                    NaN
# 4                     K*r               B*a                    NaN
# ...                   ...               ...                    ...
# 1051963               K*a               K*g                    NaN
# 1051964               K*g               B*r                    NaN
# 1051965               K*g               B*r                    NaN
# 1051966               K*n               C*t                    NaN
# 1051967               K*n               C*t                    NaN
#
#          Shipping Phone Number2 Shipping City Shipping Postcode  \
# 0                           NaN           K*g               NaN
# 1                           NaN           K*n               NaN
# 2                           NaN           K*r               NaN
# 3                           NaN           K*r               NaN
# 4                           NaN           K*r               NaN
# ...                         ...           ...               ...
# 1051963                     NaN           K*a               NaN
# 1051964                     NaN           K*g               NaN
# 1051965                     NaN           K*g               NaN
# 1051966                     NaN           K*n               NaN
# 1051967                     NaN           K*n               NaN
#
#         Shipping Country  Shipping Region Billing Name Billing Address  \
# 0              Indonesia              NaN          B*i             NaN
# 1              Indonesia              NaN          L*e             NaN
# 2              Indonesia              NaN          H*h             NaN
# 3              Indonesia              NaN          H*h             NaN
# 4              Indonesia              NaN          H*h             NaN
# ...                  ...              ...          ...             ...
# 1051963        Indonesia              NaN          V*o             NaN
# 1051964        Indonesia              NaN          C*y             NaN
# 1051965        Indonesia              NaN          C*y             NaN
# 1051966        Indonesia              NaN          b*h             NaN
# 1051967        Indonesia              NaN          b*h             NaN
#
#          Billing Address2 Billing Address3 Billing Address4 Billing Address5  \
# 0                     NaN              NaN              NaN              NaN
# 1                     NaN              NaN              NaN              NaN
# 2                     NaN              NaN              NaN              NaN
# 3                     NaN              NaN              NaN              NaN
# 4                     NaN              NaN              NaN              NaN
# ...                   ...              ...              ...              ...
# 1051963               NaN              NaN              NaN              NaN
# 1051964               NaN              NaN              NaN              NaN
# 1051965               NaN              NaN              NaN              NaN
# 1051966               NaN              NaN              NaN              NaN
# 1051967               NaN              NaN              NaN              NaN
#
#         Billing Phone Number  Billing Phone Number2 Billing City  \
# 0                        NaN                    NaN          K*g
# 1                        NaN                    NaN          K*n
# 2                        NaN                    NaN          K*r
# 3                        NaN                    NaN          K*r
# 4                        NaN                    NaN          K*r
# ...                      ...                    ...          ...
# 1051963                  NaN                    NaN          K*a
# 1051964                  NaN                    NaN          K*g
# 1051965                  NaN                    NaN          K*g
# 1051966                  NaN                    NaN          K*n
# 1051967                  NaN                    NaN          K*n
#
#         Billing Postcode Billing Country Payment Method  Total Seller Centre  \
# 0                    NaN       Indonesia            NaN         14100.000000
# 1                    NaN       Indonesia            NaN         99000.000000
# 2                    NaN       Indonesia            NaN         17900.000000
# 3                    NaN       Indonesia            NaN         17900.000000
# 4                    NaN       Indonesia            NaN         17900.000000
# ...                  ...             ...            ...                  ...
# 1051963              NaN       Indonesia            NaN         40572.666667
# 1051964              NaN       Indonesia            NaN        116397.000000
# 1051965              NaN       Indonesia            NaN        116397.500000
# 1051966              NaN       Indonesia            NaN        117096.500000
# 1051967              NaN       Indonesia            NaN        117097.000000
#
#          Unit Price  Selcen Shipping Fee  Wallet Credits  \
# 0           14100.0          7900.000000             NaN
# 1           99000.0          7900.000000             NaN
# 2           17900.0          1580.000000             NaN
# 3           17900.0          1580.000000             NaN
# 4           17900.0          1580.000000             NaN
# ...             ...                  ...             ...
# 1051963     41500.0           416.666667             NaN
# 1051964    124500.0          1000.000000             NaN
# 1051965    124500.0          1000.000000             NaN
# 1051966    124500.0             0.000000             NaN
# 1051967    124500.0             0.000000             NaN
#
#                                                  Item Name Variation  \
# 0        Lokalate Kopi Pisang Bakar Epe 10 Sachet - Tin...       NaN
# 1        BUY 1 GET 1 - Tropicana Slim Peanut Almond But...       NaN
# 2        Tropicana Slim Sweet Orange Sugar Free 10 Sach...       NaN
# 3        Tropicana Slim Sweet Orange Sugar Free 10 Sach...       NaN
# 4        Tropicana Slim Sweet Orange Sugar Free 10 Sach...       NaN
# ...                                                    ...       ...
# 1051963                     L-Men Gain Mass Chocolate 800g       NaN
# 1051964                     L-Men Gain Mass Chocolate 800g       NaN
# 1051965                     L-Men Gain Mass Chocolate 800g       NaN
# 1051966                     L-Men Gain Mass Chocolate 800g       NaN
# 1051967                     L-Men Gain Mass Chocolate 800g       NaN
#
#          CD Shipping Provider Shipping Provider Warehouse Origin  \
# 0                         NaN            LEX ID    own_warehouse
# 1                         NaN            LEX ID    own_warehouse
# 2                         NaN            LEX ID    own_warehouse
# 3                         NaN            LEX ID    own_warehouse
# 4                         NaN            LEX ID    own_warehouse
# ...                       ...               ...              ...
# 1051963                   NaN            LEX ID    own_warehouse
# 1051964                   NaN            LEX ID    own_warehouse
# 1051965                   NaN            LEX ID    own_warehouse
# 1051966                   NaN            LEX ID    own_warehouse
# 1051967                   NaN            LEX ID    own_warehouse
#
#         Shipping Provider Type  CD Tracking Code    Tracking Code  \
# 0                     STANDARD               NaN  LXAT-8001238174
# 1                     STANDARD               NaN  LXAT-8001237989
# 2                     STANDARD               NaN  LXAT-8001238067
# 3                     STANDARD               NaN  LXAT-8001238067
# 4                     STANDARD               NaN  LXAT-8001238067
# ...                        ...               ...              ...
# 1051963                ECONOMY               NaN  LXAT-9005702994
# 1051964               STANDARD               NaN  LXAT-8015038947
# 1051965               STANDARD               NaN  LXAT-8015038947
# 1051966               STANDARD               NaN  LXAT-1019346619
# 1051967               STANDARD               NaN  LXAT-1019346619
#
#          Tracking URL Shipping Provider (first mile)  \
# 0                 NaN                            NaN
# 1                 NaN                            NaN
# 2                 NaN                            NaN
# 3                 NaN                            NaN
# 4                 NaN                            NaN
# ...               ...                            ...
# 1051963           NaN                            NaN
# 1051964           NaN                            NaN
# 1051965           NaN                            NaN
# 1051966           NaN                            NaN
# 1051967           NaN                            NaN
#
#          Tracking Code (first mile)  Tracking URL (first mile)  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 1051963                         NaN                        NaN
# 1051964                         NaN                        NaN
# 1051965                         NaN                        NaN
# 1051966                         NaN                        NaN
# 1051967                         NaN                        NaN
#
#          Promised shipping time Premium Order Status  \
# 0                           NaN      No    confirmed
# 1                           NaN      No    confirmed
# 2                           NaN      No    confirmed
# 3                           NaN      No    confirmed
# 4                           NaN      No    confirmed
# ...                         ...     ...          ...
# 1051963                     NaN      No    confirmed
# 1051964                     NaN      No    delivered
# 1051965                     NaN      No    delivered
# 1051966                     NaN      No    delivered
# 1051967                     NaN      No    delivered
#
#         Cancel / Return Initiator Reason  Reason Detail  Editor  Bundle ID  \
# 0                             NaN    NaN            NaN     NaN        NaN
# 1                             NaN    NaN            NaN     NaN        NaN
# 2                             NaN    NaN            NaN     NaN        NaN
# 3                             NaN    NaN            NaN     NaN        NaN
# 4                             NaN    NaN            NaN     NaN        NaN
# ...                           ...    ...            ...     ...        ...
# 1051963                       NaN    NaN            NaN     NaN        NaN
# 1051964                       NaN    NaN            NaN     NaN        NaN
# 1051965                       NaN    NaN            NaN     NaN        NaN
# 1051966                       NaN    NaN            NaN     NaN        NaN
# 1051967                       NaN    NaN            NaN     NaN        NaN
#
#          Bundle Discount  Refund Amount  \
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ...                  ...            ...
# 1051963              NaN            NaN
# 1051964              NaN            NaN
# 1051965              NaN            NaN
# 1051966              NaN            NaN
# 1051967              NaN            NaN
#
#                                         Source      Guarantee Delivery Type  \
# 0        Seller Center Lazada 20230101-05.xlsx  non-Guarantee      STANDARD
# 1        Seller Center Lazada 20230101-05.xlsx  non-Guarantee      STANDARD
# 2        Seller Center Lazada 20230101-05.xlsx  non-Guarantee      STANDARD
# 3        Seller Center Lazada 20230101-05.xlsx  non-Guarantee      STANDARD
# 4        Seller Center Lazada 20230101-05.xlsx  non-Guarantee      STANDARD
# ...                                        ...            ...           ...
# 1051963  Seller Center Lazada 20240527-31.xlsx  non-Guarantee       ECONOMY
# 1051964  Seller Center Lazada 20240706-10.xlsx  non-Guarantee      STANDARD
# 1051965  Seller Center Lazada 20240706-10.xlsx  non-Guarantee      STANDARD
# 1051966  Seller Center Lazada 20240711-15.xlsx  non-Guarantee      STANDARD
# 1051967  Seller Center Lazada 20240711-15.xlsx  non-Guarantee      STANDARD
#
#          Ware House        Update Time Rts Sla Tts Sla  Invoice Number  \
# 0               NaN  22 Jan 2023 15:40     NaN     NaN             NaN
# 1               NaN  07 Jan 2023 18:54     NaN     NaN             NaN
# 2               NaN  07 Jan 2023 16:19     NaN     NaN             NaN
# 3               NaN  07 Jan 2023 16:19     NaN     NaN             NaN
# 4               NaN  07 Jan 2023 16:19     NaN     NaN             NaN
# ...             ...                ...     ...     ...             ...
# 1051963         NaN  05 Jun 2024 09:12     NaN     NaN             NaN
# 1051964         NaN  09 Jul 2024 16:16     NaN     NaN             NaN
# 1051965         NaN  09 Jul 2024 16:16     NaN     NaN             NaN
# 1051966         NaN  14 Jul 2024 18:49     NaN     NaN             NaN
# 1051967         NaN  14 Jul 2024 18:49     NaN     NaN             NaN
#
#             Delivered Date  Shipping Phone  Shipping Phone2  \
# 0        07 Jan 2023 15:40             NaN              NaN
# 1        07 Jan 2023 13:44             NaN              NaN
# 2        07 Jan 2023 14:39             NaN              NaN
# 3        07 Jan 2023 14:39             NaN              NaN
# 4        07 Jan 2023 14:39             NaN              NaN
# ...                    ...             ...              ...
# 1051963  30 May 2024 16:43             NaN              NaN
# 1051964  09 Jul 2024 16:16             NaN              NaN
# 1051965  09 Jul 2024 16:16             NaN              NaN
# 1051966  14 Jul 2024 18:48             NaN              NaN
# 1051967  14 Jul 2024 18:48             NaN              NaN
#
#         Shipping Post Code  ... Subtotal Produk 1  Harga Display 1  \
# 0                      NaN  ...               NaN              NaN
# 1                      NaN  ...           69930.0          99800.0
# 2                      NaN  ...               0.0              0.0
# 3                      NaN  ...               0.0              0.0
# 4                      NaN  ...               0.0              0.0
# ...                    ...  ...               ...              ...
# 1051963                NaN  ...          399600.0         498000.0
# 1051964                NaN  ...          399600.0         498000.0
# 1051965                NaN  ...          399600.0         498000.0
# 1051966                NaN  ...          399600.0         498000.0
# 1051967                NaN  ...          399600.0         498000.0
#
#         Harga Cost 1                             Produk 2 SKU Produk 2  \
# 0                NaN                                  NaN          NaN
# 1            69930.0  Tropicana Slim Strawberry Jam 375gr   2104228230
# 2                0.0                                  NaN          NaN
# 3                0.0                                  NaN          NaN
# 4                0.0                                  NaN          NaN
# ...              ...                                  ...          ...
# 1051963     399600.0                                  NaN          NaN
# 1051964     399600.0                                  NaN          NaN
# 1051965     399600.0                                  NaN          NaN
# 1051966     399600.0                                  NaN          NaN
# 1051967     399600.0                                  NaN          NaN
#
#         PCS Produk 2  Price List NFI 2 Subtotal Produk 2  Harga Display 2  \
# 0                NaN               NaN               NaN              NaN
# 1                1.0           75480.0           75480.0          99800.0
# 2                NaN               NaN               0.0              0.0
# 3                NaN               NaN               0.0              0.0
# 4                NaN               NaN               0.0              0.0
# ...              ...               ...               ...              ...
# 1051963          NaN               NaN               NaN              NaN
# 1051964          NaN               NaN               NaN              NaN
# 1051965          NaN               NaN               NaN              NaN
# 1051966          NaN               NaN               NaN              NaN
# 1051967          NaN               NaN               NaN              NaN
#
#          Harga Cost 2 Produk 3 SKU Produk 3  PCS Produk 3  Price List NFI 3  \
# 0                 NaN      NaN          NaN           NaN               NaN
# 1             75480.0      NaN          NaN           NaN               NaN
# 2                 0.0      NaN          NaN           NaN               NaN
# 3                 0.0      NaN          NaN           NaN               NaN
# 4                 0.0      NaN          NaN           NaN               NaN
# ...               ...      ...          ...           ...               ...
# 1051963           NaN      NaN          NaN           NaN               NaN
# 1051964           NaN      NaN          NaN           NaN               NaN
# 1051965           NaN      NaN          NaN           NaN               NaN
# 1051966           NaN      NaN          NaN           NaN               NaN
# 1051967           NaN      NaN          NaN           NaN               NaN
#
#          Subtotal Produk 3  Harga Display 3  Harga Cost 3 Produk 4  \
# 0                      NaN              NaN           NaN      NaN
# 1                      NaN              NaN           NaN      NaN
# 2                      0.0              0.0           0.0      NaN
# 3                      0.0              0.0           0.0      NaN
# 4                      0.0              0.0           0.0      NaN
# ...                    ...              ...           ...      ...
# 1051963                NaN              NaN           NaN      NaN
# 1051964                NaN              NaN           NaN      NaN
# 1051965                NaN              NaN           NaN      NaN
# 1051966                NaN              NaN           NaN      NaN
# 1051967                NaN              NaN           NaN      NaN
#
#          SKU Produk 4  PCS Produk 4  Price List NFI 4 Subtotal Produk 4  \
# 0                 NaN           NaN               NaN               NaN
# 1                 NaN           NaN               NaN               NaN
# 2                 NaN           NaN               NaN               0.0
# 3                 NaN           NaN               NaN               0.0
# 4                 NaN           NaN               NaN               0.0
# ...               ...           ...               ...               ...
# 1051963           NaN           NaN               NaN               NaN
# 1051964           NaN           NaN               NaN               NaN
# 1051965           NaN           NaN               NaN               NaN
# 1051966           NaN           NaN               NaN               NaN
# 1051967           NaN           NaN               NaN               NaN
#
#         Harga Display 4  Harga Cost 4  Produk 5  SKU Produk 5 PCS Produk 5  \
# 0                   NaN           NaN       NaN           NaN          NaN
# 1                   NaN           NaN       NaN           NaN          NaN
# 2                   0.0           0.0       NaN           NaN          NaN
# 3                   0.0           0.0       NaN           NaN          NaN
# 4                   0.0           0.0       NaN           NaN          NaN
# ...                 ...           ...       ...           ...          ...
# 1051963             NaN           NaN       NaN           NaN          NaN
# 1051964             NaN           NaN       NaN           NaN          NaN
# 1051965             NaN           NaN       NaN           NaN          NaN
# 1051966             NaN           NaN       NaN           NaN          NaN
# 1051967             NaN           NaN       NaN           NaN          NaN
#
#         Price List NFI 5  Subtotal Produk 5  Harga Display 5 Harga Cost 5  \
# 0                    NaN                NaN              NaN          NaN
# 1                    NaN                NaN              NaN          NaN
# 2                    NaN                0.0              0.0          0.0
# 3                    NaN                0.0              0.0          0.0
# 4                    NaN                0.0              0.0          0.0
# ...                  ...                ...              ...          ...
# 1051963              NaN                NaN              NaN          NaN
# 1051964              NaN                NaN              NaN          NaN
# 1051965              NaN                NaN              NaN          NaN
# 1051966              NaN                NaN              NaN          NaN
# 1051967              NaN                NaN              NaN          NaN
#
#          Produk 6 SKU Produk 6 PCS Produk 6 Price List NFI 6  \
# 0             NaN          NaN          NaN              NaN
# 1             NaN          NaN          NaN              NaN
# 2             NaN          NaN          NaN              NaN
# 3             NaN          NaN          NaN              NaN
# 4             NaN          NaN          NaN              NaN
# ...           ...          ...          ...              ...
# 1051963       NaN          NaN          NaN              NaN
# 1051964       NaN          NaN          NaN              NaN
# 1051965       NaN          NaN          NaN              NaN
# 1051966       NaN          NaN          NaN              NaN
# 1051967       NaN          NaN          NaN              NaN
#
#         Subtotal Produk 6 Harga Display 6 Harga Cost 6 Produk 7 SKU Produk 7  \
# 0                     NaN             NaN          NaN      NaN          NaN
# 1                     NaN             NaN          NaN      NaN          NaN
# 2                     0.0             0.0          0.0      NaN          NaN
# 3                     0.0             0.0          0.0      NaN          NaN
# 4                     0.0             0.0          0.0      NaN          NaN
# ...                   ...             ...          ...      ...          ...
# 1051963               NaN             NaN          NaN      NaN          NaN
# 1051964               NaN             NaN          NaN      NaN          NaN
# 1051965               NaN             NaN          NaN      NaN          NaN
# 1051966               NaN             NaN          NaN      NaN          NaN
# 1051967               NaN             NaN          NaN      NaN          NaN
#
#          PCS Produk 7  Price List NFI 7  Subtotal Produk 7  Harga Display 7  \
# 0                 NaN               NaN                NaN              NaN
# 1                 NaN               NaN                NaN              NaN
# 2                 NaN               NaN                0.0              0.0
# 3                 NaN               NaN                0.0              0.0
# 4                 NaN               NaN                0.0              0.0
# ...               ...               ...                ...              ...
# 1051963           NaN               NaN                NaN              NaN
# 1051964           NaN               NaN                NaN              NaN
# 1051965           NaN               NaN                NaN              NaN
# 1051966           NaN               NaN                NaN              NaN
# 1051967           NaN               NaN                NaN              NaN
#
#          Harga Cost 7 Price List NFI Harga Cost  Total Net  Total Harga Cost  \
# 0                 NaN          15151      15151    15151.0             15151
# 1                 NaN         145410     145410   145410.0            145410
# 2                 0.0          21645      21645    21645.0             21645
# 3                 0.0          21645      21645    21645.0             21645
# 4                 0.0          21645      21645    21645.0             21645
# ...               ...            ...        ...        ...               ...
# 1051963           NaN         199800     199800   399600.0            399600
# 1051964           NaN         199800     199800   399600.0            399600
# 1051965           NaN         199800     199800   399600.0            399600
# 1051966           NaN         199800     199800   399600.0            399600
# 1051967           NaN         199800     199800   399600.0            399600
#
#          Total Net Before PPN  \
# 0                 13649.54955
# 1                131000.00000
# 2                 19500.00000
# 3                 19500.00000
# 4                 19500.00000
# ...                       ...
# 1051963          360000.00000
# 1051964          360000.00000
# 1051965          360000.00000
# 1051966          360000.00000
# 1051967          360000.00000
#
#                                                Bundle Name  Bundle Flag  \
# 0                                                      NaN          NaN
# 1                                                      NaN          NaN
# 2                                                      NaN          NaN
# 3                                                      NaN          NaN
# 4                                                      NaN          NaN
# ...                                                    ...          ...
# 1051963  BUY 1 GET 1 FREE : L-Men Gain Mass Chocolate 8...          NaN
# 1051964  Twin Pack : L-Men Gain Mass Chocolate 800g - 2...          NaN
# 1051965  Twin Pack : L-Men Gain Mass Chocolate 800g - 2...          NaN
# 1051966  Twin Pack : L-Men Gain Mass Chocolate 800g - 2...          NaN
# 1051967  Twin Pack : L-Men Gain Mass Chocolate 800g - 2...          NaN
#
#                             Parent Item Parent SKU  Customer Order No.  \
# 0                                   NaN        NaN    1032400403693459
# 1                                   NaN        NaN    1032389037572072
# 2                                   NaN        NaN    1032378095500771
# 3                                   NaN        NaN    1032378095500771
# 4                                   NaN        NaN    1032378095500771
# ...                                 ...        ...                 ...
# 1051963  L-Men Gain Mass Chocolate 800g        NaN                 NaN
# 1051964  L-Men Gain Mass Chocolate 800g        NaN                 NaN
# 1051965  L-Men Gain Mass Chocolate 800g        NaN                 NaN
# 1051966  L-Men Gain Mass Chocolate 800g        NaN                 NaN
# 1051967  L-Men Gain Mass Chocolate 800g        NaN                 NaN
#
#                       Platform SKU  Status Gudang  Warehouse Quantity  \
# 0        6087298504_ID-11660714080      Delivered                 1.0
# 1        7155976060_ID-13469102853      Delivered                 1.0
# 2         1096720178_ID-1727846672      Delivered                 1.0
# 3         1096720178_ID-1727846672      Delivered                 1.0
# 4         1096720178_ID-1727846672      Delivered                 1.0
# ...                            ...            ...                 ...
# 1051963                        NaN            NaN                 NaN
# 1051964                        NaN            NaN                 NaN
# 1051965                        NaN            NaN                 NaN
# 1051966                        NaN            NaN                 NaN
# 1051967                        NaN            NaN                 NaN
#
#                        WH       Order No._x  Seller SKU  Comfee Prop  \
# 0        Lazada Warehouse  1032400403693459  1101692318   -704.00000
# 1        Lazada Warehouse  1032389037572072     PT25T74  -4945.00000
# 2        Lazada Warehouse  1032378095500771  2104110110   -894.00000
# 3        Lazada Warehouse  1032378095500771  2104110110   -894.00000
# 4        Lazada Warehouse  1032378095500771  2104110110   -894.00000
# ...                   ...               ...         ...          ...
# 1051963               NaN               NaN         NaN   2410.01310
# 1051964               NaN               NaN         NaN   2304.66555
# 1051965               NaN               NaN         NaN   2304.66555
# 1051966               NaN               NaN         NaN   2318.51565
# 1051967               NaN               NaN         NaN   2318.51565
#
#          Fullfee Prop  Payment Fee_x  Shipping Fee  Total Transfer  \
# 0             -2775.0         -257.0           0.0    14100.000000
# 1             -2775.0        -1802.0           0.0    99000.000000
# 2             -2775.0         -326.0           0.0    17900.000000
# 3             -2775.0         -326.0           0.0    17900.000000
# 4             -2775.0         -326.0           0.0    17900.000000
# ...               ...            ...           ...             ...
# 1051963        3000.0            NaN           0.0    40572.666667
# 1051964        3000.0            NaN           0.0   116397.000000
# 1051965        3000.0            NaN           0.0   116397.500000
# 1051966        3000.0            NaN           0.0   117096.500000
# 1051967        3000.0            NaN           0.0   117097.000000
#
#         Payment Fee_y Payment Fee  Order No.    Paid   Order Paid  \
# 0                 NaN      -257.0        NaN    Paid         Paid
# 1                 NaN     -1802.0        NaN    Paid         Paid
# 2                 NaN      -326.0        NaN    Paid         Paid
# 3                 NaN      -326.0        NaN    Paid         Paid
# 4                 NaN      -326.0        NaN    Paid         Paid
# ...               ...         ...        ...     ...          ...
# 1051963           NaN         0.0        NaN  Unpaid  Paid,Unpaid
# 1051964           NaN         0.0        NaN  Unpaid  Paid,Unpaid
# 1051965           NaN         0.0        NaN  Unpaid  Paid,Unpaid
# 1051966           NaN         0.0        NaN  Unpaid  Paid,Unpaid
# 1051967           NaN         0.0        NaN  Unpaid  Paid,Unpaid
#
#          Order No._y  Total Produk Prop       BTL Cost Total Produk Prop Adj
# 0                NaN       14100.000000    -946.846847          12702.702703
# 1                NaN       99000.000000  -41810.810811          89189.189189
# 2                NaN       17900.000000   -3373.873874          16126.126126
# 3                NaN       17900.000000   -3373.873874          16126.126126
# 4                NaN       17900.000000   -3373.873874          16126.126126
# ...              ...                ...            ...                   ...
# 1051963          NaN       40572.666667 -323448.048048          36551.951952
# 1051964          NaN      116397.000000 -255137.837838         104862.162162
# 1051965          NaN      116397.500000 -255137.387387         104862.612613
# 1051966          NaN      117096.500000 -254507.657658         105492.342342
# 1051967          NaN      117097.000000 -254507.207207         105492.792793
#
# [1051968 rows x 192 columns]

# %%
total_trx_full[total_trx_full['Year']==2024]['Month'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July'],
#       dtype=object)

# %%
### run 44
total_trx_full.to_csv(r"Settlement Project\Backup\Realisasi Jul 2024\Final Result\Before Compare\Lazada Testing by Selcen Compare v8.csv",sep=';')

# %%
# total_trx_fullcp=total_trx_full.copy()

# %%
## run 45
import pandas as pd
import numpy as np
import os

# total_trx = pd.read_csv(r'D:\Backup\Backup 26 Mei\Settlement Project Backup/Lazada Testing by Selcen Compare v8.csv', sep = ';')
total_trx_full=pd.read_csv(r"D:\6. settlement\Code\Settlement Project\Backup\Realisasi Jul 2024\Final Result\Before Compare\Lazada Testing by Selcen Compare v8.csv",sep=';')
total_trx_full = total_trx_full.rename(columns = {'Total Produk Prop by Selcen': 'Total Produk Prop', 
                                                   'Total Net by Selcen' : 'Total Net', 
                                                   'Fullfee Prop by Selcen' : 'Fullfee Prop', 
                                                   'Comfee Prop by Selcen' : 'Comfee Prop'})


source = pd.read_csv(r"D:\6. settlement\Code\Settlement Project\Backup\Realisasi Jun 2024\Final Result\Raw Unpivoted\CSV\Running Lazada By Selcen Jan 2022 - Jun 2024.csv", sep = ';')


source['True datetime'] = pd.to_datetime(source['True datetime'])
source = source[(source['Year'] > 2022)]

prevmonth='June'

# selcen_sku['OrderId'] = selcen_sku['OrderId'].astype(str)
source['Order #'] = source['Order Number'].astype(str)
source['Real SKU'] = source['Real SKU'].astype(str)

# selcen_old = selcen_sku[selcen_sku['OrderId'].isin(source['Order #'])]

source['Product Name'] = source['Item Name'].fillna(source['Real Nama Produk'])

total_trx_full['Order Number'] = total_trx_full['Order Number'].astype(str)

total_trx_merge = total_trx_full.merge(source.groupby(['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Paid '+prevmonth])['Qty. Invoiced', 'Total Net', 'Total Produk Prop', 'Comfee Prop'].sum().reset_index(), how = 'left', left_on = ['Order Number', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'], right_on = ['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'])
cek=total_trx_merge.copy()
# total_trx_merge['Total Net_y'] = total_trx_merge['Total Net_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', ])['Total Net Before PPN'].transform('sum')
# total_trx_merge['Total Produk Prop_y'] = total_trx_merge['Total Produk Prop_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', ])['Total Net Before PPN'].transform('sum')
# total_trx_merge['Comfee Prop_y'] = total_trx_merge['Comfee Prop_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', ])['Total Net Before PPN'].transform('sum')
# display(total_trx_null[total_trx_null['Order Number']=='829299019029418'][['Real Nama Produk','Real SKU','Paid','Paid June']])
total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

total_trx_null = total_trx_null.drop(['Order #', 'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y', 'Paid '+prevmonth], axis = 1)
total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net', 
                                                  'Total Produk Prop_x' : 'Total Produk Prop',
                                                  'Comfee Prop_x' : 'Comfee Prop'})

total_trx_null = total_trx_null.merge(source.groupby(['Order #', 'Product Name', 'Bundle Name', 'Paid '+prevmonth])['Total Net', 'Total Produk Prop', 'Comfee Prop'].sum().reset_index(), how = 'left', left_on = ['Order Number', 'Item Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(total_trx_null.index) 

cek2=total_trx_null.copy()

total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
total_trx_merge['Paid '+prevmonth][total_trx_null.index] = total_trx_null['Paid '+prevmonth]


# total_trx_merge['Total Net_y'] = total_trx_merge['Total Net_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', ])['Total Net Before PPN'].transform('sum')
# total_trx_merge['Total Produk Prop_y'] = total_trx_merge['Total Produk Prop_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', ])['Total Net Before PPN'].transform('sum')
# total_trx_merge['Comfee Prop_y'] = total_trx_merge['Comfee Prop_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', ])['Total Net Before PPN'].transform('sum')
# display(total_trx_null[total_trx_null['Order Number']=='829299019029418'][['Real Nama Produk','Real SKU','Paid','Paid June']])


total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

total_trx_null = total_trx_null.drop(['Order #', 'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y', 'Paid '+prevmonth], axis = 1)
total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net',
                                                  'Total Produk Prop_x' : 'Total Produk Prop',
                                                  'Comfee Prop_x' : 'Comfee Prop'})

total_trx_null = total_trx_null.merge(source[['Order #', 'Real SKU', 'Bundle Name', 'Total Net', 'Total Produk Prop',
                                              'Comfee Prop', 'Paid '+prevmonth]].drop_duplicates(['Order #', 'Real SKU',
                                                                                            'Bundle Name']), how = 'left', left_on = ['Order Number',
                                                                                                                                      'Real SKU',  'Bundle Name'], right_on = ['Order #', 'Real SKU', 'Bundle Name']).set_index(total_trx_null.index) 
cek3=total_trx_null.copy()


total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
total_trx_merge['Paid '+prevmonth][total_trx_null.index] = total_trx_null['Paid '+prevmonth]

total_trx_merge['Total Net_y'] = total_trx_merge['Total Net_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', 'Bundle Name'], dropna = False)['Total Net Before PPN'].transform('sum')
total_trx_merge['Total Produk Prop_y'] = total_trx_merge['Total Produk Prop_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', 'Bundle Name'], dropna = False)['Total Net Before PPN'].transform('sum')
total_trx_merge['Comfee Prop_y'] = total_trx_merge['Comfee Prop_y'] * total_trx_merge['Total Net Before PPN']/total_trx_merge.groupby(['Order Number', 'Real SKU', 'Bundle Name'], dropna = False)['Total Net Before PPN'].transform('sum')


# # total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

# # source2 = source.copy()

# # source2['Real SKU'] = source2['Real SKU'].astype(str).str.replace('2309005305', '2309005300')

# # indeks = source2[source2['Real SKU'] == '(B)2101809250'].index.to_list()
# # source2['Real SKU'][indeks] = '(U)2101809250'

# # indeks = source2[source2['Real SKU'] == 'PH48(3)B35'].index.to_list()
# # source2['Real SKU'][indeks] = '2101941250P4'

# # indeks = source2[source2['Real SKU'] == 'PH39(3)B17'].index.to_list()
# # source2['Real SKU'][indeks] = '2101809250P4'

# # total_trx_null = total_trx_null.drop(['Order #', 'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
# # total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net', 
# #                                                   'Total Produk Prop_x' : 'Total Produk Prop',
# #                                                   'Comfee Prop_x' : 'Comfee Prop'})

# # total_trx_null = total_trx_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name']), how = 'left', left_on = ['Order Number', 'Product Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(total_trx_null.index) 
# # total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
# # total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
# # total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']

total_trx_merge = total_trx_merge.rename(columns = {'Total Produk Prop_x' : 'Total Produk Prop by Selcen', 
                                                   'Total Produk Prop_y' : 'Total Produk Prop Real Jan',
                                                   'Total Net_x' : 'Total Net by Selcen', 
                                                   'Total Net_y' : 'Total Net Real Jan',
                                                   'Fullfee Prop_x' : 'Fullfee Prop by Selcen', 
                                                   'Fullfee Prop_y' : 'Fullfee Prop Real Jan',
                                                   'Comfee Prop_x' : 'Comfee Prop by Selcen', 
                                                   'Comfee Prop_y' : 'Comfee Prop Real Jan'})

total_trx_merge['Delta Total Net'] = total_trx_merge['Total Net by Selcen'] - total_trx_merge['Total Net Real Jan']
total_trx_merge['Delta Total Produk Prop'] = total_trx_merge['Total Produk Prop by Selcen'] - total_trx_merge['Total Produk Prop Real Jan']
total_trx_merge['Delta Comfee Prop'] = total_trx_merge['Comfee Prop by Selcen'] - total_trx_merge['Comfee Prop Real Jan']

total_trx_merge = total_trx_merge.rename(columns = {'Total Produk Prop by Selcen': 'Total Produk Prop', 
                                                   'Total Net by Selcen' : 'Total Net', 
                                                   'Fullfee Prop by Selcen' : 'Fullfee Prop', 
                                                   'Comfee Prop by Selcen' : 'Comfee Prop'})


total_trx_merge = total_trx_merge.drop(['Order #', 'Total Net Real Jan', 'Total Produk Prop Real Jan',
       'Comfee Prop Real Jan', 'Delta Total Net', 'Delta Total Produk Prop',
       'Delta Comfee Prop'], axis = 1)

total_trx_merge.loc[(total_trx_merge['Paid']=='Unpaid')&(total_trx_merge['Paid '+prevmonth]=='Cancel'),'Paid']='Cancel' ### add cancel
# total_trx_merge.loc[(total_trx_merge['Paid'].isnull())&(total_trx_merge['Paid July']=='Cancel'),'Paid']='Cancel' ### add cancel
# total_trx_merge.loc[(total_trx_merge['Paid'].isnull())&(total_trx_merge['Paid July']=='Paid'),'Paid']='Paid' ### add cancel
# total_trx_merge.loc[(total_trx_merge['Paid'].isnull())&(total_trx_merge['Paid July']=='Refund'),'Paid']='Refund' ### add cancel
total_trx_merge['Paid Beda'] = np.nan

indeks = total_trx_merge[total_trx_merge['Paid'] != total_trx_merge['Paid '+prevmonth]].index.to_list()
total_trx_merge['Paid Beda'][indeks] = 'Beda'

total_trx_merge['Paid Beda'] = total_trx_merge['Paid Beda'].fillna('Sama')
# total_trx_merge[total_trx_merge['Paid Beda'] == 'Beda'][['Order #','Brand','Real SKU','Month', 'Paid_x', 'Paid_y', 'Paid Beda']]
total_trx_merge[total_trx_merge['Paid Beda'] == 'Beda'].groupby(['Month', 'Paid', 'Paid '+prevmonth], dropna  = False)['Order Number'].nunique()
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (43,45,49,69,70,72,93,102,103,109,121,122,128,129,135,136,142,143,149,156,168,170,173,174,176,178) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (42,44,48,68,69,71,92,105,110,111,117,118,124,125,131,132,138,139,145,152,164,166,169,170,172,173,185) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:32: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:45: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Month  Paid       Paid June
# July   Cancel     NaN           2321
#        Half Paid  NaN              1
#        Paid       NaN          12485
#        Refund     NaN            228
#        Unpaid     NaN            993
# June   Cancel     Unpaid          10
#                   NaN           4114
#        Half Paid  Paid             1
#                   NaN              1
#        Paid       Refund          46
#                   Unpaid          19
#                   NaN          19709
#        Refund     Paid             4
#                   NaN             70
#        Unpaid     NaN            192
# May    Refund     Paid             1
# Name: Order Number, dtype: int64

# %%
# %whos

# %%
cek=source[source['Paid '+prevmonth]=='Paid']['Order Item Id'].unique()
total_trx_merge[(total_trx_merge['Paid'].isnull())&(total_trx_merge['Order Item Id'].isin(cek))]
# ini harus null
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Order Item Id, Order Type, Order Flag, Lazada Id, SKU, Product ID, Order Date Seller Centre, Updated at, Order Number, Invoice Required, Customer Name, Customer Email, National Registration Number, Shipping Name, Shipping Address, Shipping Address2, Shipping Address3, Shipping Address4, Shipping Address5, Shipping Phone Number, Shipping Phone Number2, Shipping City, Shipping Postcode, Shipping Country, Shipping Region, Billing Name, Billing Address, Billing Address2, Billing Address3, Billing Address4, Billing Address5, Billing Phone Number, Billing Phone Number2, Billing City, Billing Postcode, Billing Country, Payment Method, Total Seller Centre, Unit Price, Selcen Shipping Fee, Wallet Credits, Item Name, Variation, CD Shipping Provider, Shipping Provider, Warehouse Origin, Shipping Provider Type, CD Tracking Code, Tracking Code, Tracking URL, Shipping Provider (first mile), Tracking Code (first mile), Tracking URL (first mile), Promised shipping time, Premium, Order Status, Cancel / Return Initiator, Reason, Reason Detail, Editor, Bundle ID, Bundle Discount, Refund Amount, Source, Guarantee, Delivery Type, Ware House, Update Time, Rts Sla, Tts Sla, Invoice Number, Delivered Date, Shipping Phone, Shipping Phone2, Shipping Post Code, Billing Addr, Billing Addr2, Billing Addr3, Billing Addr4, Billing Addr5, Billing Phone, Billing Phone2, Billing Post Code, Tax Code, Branch Number, Tax Invoice Requested, Pay Method, Seller Discount Total, Wallet Credit, Cd Shipping Provider, Cd Tracking Code, Tracking Url, Shipping Provider F M, Tracking Code F M, Tracking Url F M, Promised Shipping Time, Buyer Failed Delivery Return Initiator, Buyer Failed Delivery Reason, Buyer Failed Delivery Detail, ...]
# Index: []
#
# [0 rows x 195 columns]

# %%
## run 46
total_trx_merge = total_trx_merge.rename(columns = {'Paid' : 'Paid July'})

# %%
total_trx_merge['Disc 2 Faktur Pajak']=total_trx_merge['Shipping Fee']+total_trx_merge['Payment Fee']
total_trx_merge['Disc 2 Non Faktur Pajak']=total_trx_merge['Fullfee Prop']

# %%
## run 47
# finres=pd.read_excel("Settlement Project\Backup\Realisasi April 2022\Final Result\Ke Mbak May\Running Lazada By Selcen Jan 22 - Apr 22 With LazSub and Free Ship Rev 1.xlsx",sheet_name='Running Lazada')
finres=pd.read_csv(r"D:\6. settlement\Code\Settlement Project\Backup\Realisasi Jan 2024\Final Result\Raw Unpivoted\CSV\Running Lazada By Selcen Jan 2022 - Jan 2024.csv",sep=';')
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (42,44,48,68,69,71,92,105,110,111,117,118,124,125,131,132,138,139,145,152,164,166,169,170,172,173,185) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
del(source)

# %%
## run 48
finres=finres.rename(columns={'Paid January':'Paid July'})
finres=finres.rename(columns={'Paid December':'Paid June'})

# finres=finres.rename(columns={'Paid March':'Paid January'})
# finres=finres.head(0).append(total_trx_merge)

finres['Pemilik Budget']=np.nan

# %%
## run 48.1
finres=total_trx_merge[[x for x in total_trx_merge.columns if x in finres.columns]+['Disc 2 Faktur Pajak','Disc 2 Non Faktur Pajak']]

# %%
## run 49
finres[(finres['Year']>2023)].to_excel(r'Settlement Project\Backup\Realisasi Jul 2024\Final Result\Raw Unpivoted\Excel/Running Lazada By Selcen Jan 2023 - Jul 2024.xlsx', index = False)
print('excel sdh')
finres.to_csv(r'Settlement Project\Backup\Realisasi Jul 2024\Final Result\Raw Unpivoted\CSV/Running Lazada By Selcen Jan 2022 - Jul 2024.csv', sep = ';', index = False)
# Out:
# excel sdh

# %%
### lazada Selesai ####
finres[['Paid April','Paid March','Paid Beda']]
# Out:
#        Paid April Paid March Paid Beda
# 0            Paid       Paid      Sama
# 1            Paid       Paid      Sama
# 2            Paid       Paid      Sama
# 3            Paid       Paid      Sama
# 4            Paid       Paid      Sama
# ...           ...        ...       ...
# 893380     Refund     Refund      Sama
# 893381     Refund     Refund      Sama
# 893382     Refund     Refund      Sama
# 893383     Refund     Refund      Sama
# 893384     Refund     Refund      Sama
#
# [893385 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
import os

# total_trx = pd.read_csv(r'D:\Backup\Backup 26 Mei\Settlement Project Backup/Lazada Testing by Selcen Compare v8.csv', sep = ';')
total_trx_full=pd.read_csv(r"D:\6. settlement\Code\Settlement Project\Backup\Realisasi Jul 2024\Final Result\Raw Unpivoted\CSV\Running Lazada By Selcen Jan 2022 - Jul 2024.csv",sep=';')
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (42,44,48,68,69,71,92,105,117,118,124,125,131,132,138,139,145,152,164,166,169,170,172,173,185) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
total_trx_full[total_trx_full['Year']==2024][['Order Item Id','Order Date Seller Centre','Order Number','Warehouse Origin','Order Status','Qty. Invoiced','Year','Month','Real SKU','Brand','Paid June','Paid July','Paid Beda']].to_excel('Lazada July str.xlsx',index=False)

# %%
total_trx_full['Order Item Id']=total_trx_full['Order Item Id'].astype(str)
total_trx_full['Order Number']=total_trx_full['Order Number'].astype(str)
