# %%
## run 1

import pandas as pd
import numpy as np
import os
import re
import csv

selcen = pd.DataFrame()
for i in os.listdir('Settlement Project\Blibli L-Men\Seller Centre = warehouse'):
    print(i)
    if '$' not in i:
        if 'csv' in i:
            temp = pd.read_csv('Settlement Project\Blibli L-Men\Seller Centre = warehouse/' + str(i), skipinitialspace=True)
            if 'rusak' in i or '202101' in i or '202103' in i or '202104' in i or '202105' in i or '202106' in i or '202107' in i or '202108' in i:
                names= temp.columns
                temp2 = pd.DataFrame()
                for line in csv.reader(temp['No. Order'], skipinitialspace=True):
                    temp2 = temp2.append(pd.DataFrame(np.reshape(line, (1,16))), ignore_index = True, sort = False)
                temp2.columns = names
                temp = temp2.copy()
            temp['Source'] = i
            for j in ['No. Order', 'No. Order Item', 'No. Awb', 'Kode SKU', 'Merchant SKU']:
                temp[j] = temp[j].astype(str).str.replace('"', '', regex = False).str.replace('=', '', regex = False)
            true_col = ['No. Order', 'No. Order Item', 'No. Awb', 'Tanggal Order', 'Nama Pemesan', 'Kode SKU', 'Blibli SKU', 'Merchant SKU', 'Nama Produk', 'Total Barang', 
                        'Harga Produk', 'Servis Logistik', 'Kode Merchant', 'Nama Store', 'Order Status', 'Toko/Gudang', 'Source']
            if temp.columns.to_list() == true_col :
                print('Column sama')
            else:
                print('Column beda')
                print([x for x in true_col if x not in temp.columns.to_list()])
                print([x for x in temp.columns.to_list() if x not in true_col])
            if 'No. Order Item' in selcen.columns:
                temp=temp[~temp['No. Order'].isin(selcen['No. Order'].unique())]
            selcen = selcen.append(temp, ignore_index = True, sort = False)
# Out:
# bulk-order-download-template 202101.csv
# Column sama
# bulk-order-download-template 202102.csv
# Column sama
# bulk-order-download-template 202103.csv
# Column sama
# bulk-order-download-template 202104.csv
# Column sama
# bulk-order-download-template 202105.csv
# Column sama
# bulk-order-download-template 202106.csv
# Column sama
# bulk-order-download-template 202109.csv
# Column sama
# bulk-order-download-template 202110.csv
# Column sama
# bulk-order-download-template 202111.csv
# Column sama
# bulk-order-download-template 202112.csv
# Column sama
# bulk-order-download-template 202201.csv
# Column sama
# bulk-order-download-template 202202.csv
# Column sama
# bulk-order-download-template 202203.csv
# Column sama
# bulk-order-download-template 202204.csv
# Column sama
# bulk-order-download-template 202205.csv
# Column sama
# bulk-order-download-template 202206.csv
# Column beda
# []
# ['Unnamed: 0']
# bulk-order-download-template 202207.csv
# Column sama
# bulk-order-download-template 202208.csv
# Column sama
# bulk-order-download-template 202209.csv
# Column sama
# bulk-order-download-template 202210.csv
# Column sama
# bulk-order-download-template 202211.csv
# Column sama
# bulk-order-download-template 202212.csv
# Column sama
# bulk-order-download-template 202301.csv
# Column sama
# bulk-order-download-template 202302.csv
# Column sama
# bulk-order-download-template 202303.csv
# Column sama
# bulk-order-download-template 202304.csv
# Column sama
# bulk-order-download-template 202305.csv
# Column sama
# bulk-order-download-template 202306.csv
# Column sama
# bulk-order-download-template 202307.csv
# Column sama
# bulk-order-download-template 202308.csv
# Column sama
# bulk-order-download-template 202309.csv
# Column sama
# bulk-order-download-template 202310.csv
# Column sama
# bulk-order-download-template 202311.csv
# Column sama
# bulk-order-download-template 202312.csv
# Column sama
# bulk-order-download-template 202401.csv
# Column beda
# ['Harga Produk', 'Toko/Gudang']
# ['Alamat pengambilan', 'Alamat', 'Kota', 'Provinsi', 'Harga item pesanan', 'Total harga item pesanan', 'Total', 'Diskon', 'Nama diskon', 'Kode diskon', 'Voucher seller', 'Nama voucher seller', 'Kode voucher seller', 'Nama voucher gratis ongkir', 'Kode voucher gratis ongkir', 'Catatan produk', 'Tanggal pengiriman']
# bulk-order-download-template 202402.csv
# Column beda
# ['Harga Produk', 'Toko/Gudang']
# ['Alamat pengambilan', 'Alamat', 'Kota', 'Provinsi', 'Harga item pesanan', 'Total harga item pesanan', 'Total', 'Diskon', 'Nama diskon', 'Kode diskon', 'Voucher seller', 'Nama voucher seller', 'Kode voucher seller', 'Nama voucher gratis ongkir', 'Kode voucher gratis ongkir', 'Catatan produk', 'Tanggal pengiriman']
# bulk-order-download-template 202403.csv
# Column beda
# ['Harga Produk', 'Toko/Gudang']
# ['Alamat pengambilan', 'Alamat', 'Kota', 'Provinsi', 'Harga item pesanan', 'Total harga item pesanan', 'Total', 'Diskon', 'Nama diskon', 'Kode diskon', 'Voucher seller', 'Nama voucher seller', 'Kode voucher seller', 'Nama voucher gratis ongkir', 'Kode voucher gratis ongkir', 'Catatan produk', 'Tanggal pengiriman']
# bulk-order-download-template 202404.csv
# Column beda
# ['Harga Produk', 'Toko/Gudang']
# ['Alamat pengambilan', 'Alamat', 'Kota', 'Provinsi', 'Harga item pesanan', 'Total harga item pesanan', 'Total', 'Diskon', 'Nama diskon', 'Kode diskon', 'Voucher seller', 'Nama voucher seller', 'Kode voucher seller', 'Nama voucher gratis ongkir', 'Kode voucher gratis ongkir', 'Catatan produk', 'Tanggal pengiriman']
# bulk-order-download-template 202405.csv
# Column beda
# ['Harga Produk', 'Toko/Gudang']
# ['Alamat pengambilan', 'Alamat', 'Kota', 'Provinsi', 'Harga item pesanan', 'Total harga item pesanan', 'Total', 'Diskon', 'Nama diskon', 'Kode diskon', 'Voucher seller', 'Nama voucher seller', 'Kode voucher seller', 'Nama voucher gratis ongkir', 'Kode voucher gratis ongkir', 'Catatan produk', 'Tanggal pengiriman']
# bulk-order-download-template 202406.csv
# Column beda
# ['Harga Produk', 'Toko/Gudang']
# ['Alamat pengambilan', 'Alamat', 'Kota', 'Provinsi', 'Harga item pesanan', 'Total harga item pesanan', 'Total', 'Diskon', 'Nama diskon', 'Kode diskon', 'Voucher seller', 'Nama voucher seller', 'Kode voucher seller', 'Nama voucher gratis ongkir', 'Kode voucher gratis ongkir', 'Catatan produk', 'Tanggal pengiriman']
# bulk-order-download-template 202407.csv
# Column beda
# ['Harga Produk', 'Toko/Gudang']
# ['Alamat pengambilan', 'Alamat', 'Kota', 'Provinsi', 'Harga item pesanan', 'Total harga item pesanan', 'Total', 'Diskon', 'Nama diskon', 'Kode diskon', 'Voucher seller', 'Nama voucher seller', 'Kode voucher seller', 'Nama voucher gratis ongkir', 'Kode voucher gratis ongkir', 'Catatan produk', 'Tanggal pengiriman']
# bulk-order-download-template 202408.csv
# Column beda
# ['Harga Produk', 'Toko/Gudang']
# ['Alamat pengambilan', 'Alamat', 'Kota', 'Provinsi', 'Harga item pesanan', 'Total harga item pesanan', 'Total', 'Diskon', 'Nama diskon', 'Kode diskon', 'Voucher seller', 'Nama voucher seller', 'Kode voucher seller', 'Nama voucher gratis ongkir', 'Kode voucher gratis ongkir', 'Catatan produk', 'Tanggal pengiriman']
# Seller Centre Blibli Lmen Store Agustus 2021.csv
# Column sama
# Seller Centre Blibli Lmen Store Juli 2021.csv
# Column sama

# %%
### run 2 make sure no duplicate
selcen[selcen[['No. Order','No. Order Item', 'Kode SKU', 'Blibli SKU', 'Merchant SKU', 'Nama Produk', 'Total Barang']].duplicated(keep = False)]['Source'].unique()
# Out:
# array([], dtype=object)

# %%
### optional if duplicate
selcen = selcen.drop_duplicates(['No. Order','No. Order Item', 'Kode SKU', 'Blibli SKU', 'Merchant SKU', 'Nama Produk'], keep = 'last')

# %%
### run 3
selcen = selcen.rename(columns = {'Merchant SKU' : 'SKU', 'Total Barang' : 'Qty. Invoiced'})
selcen['Qty. Invoiced'] = selcen['Qty. Invoiced'].astype(int)

selcen['Date'] = np.nan
selcen['Month'] = np.nan
selcen['Year'] = np.nan

### tambahan timo April 23
selcen['true datetime']=np.nan

indeks = selcen[pd.to_datetime(selcen['Tanggal Order']).dt.strftime('%d').astype(int) <= 12].index.to_list()
selcen['Date'][indeks] = pd.to_datetime(pd.to_datetime(selcen['Tanggal Order'][indeks]).dt.strftime('%Y-%d-%m %H:%M')).dt.day
selcen['Month'][indeks] = pd.to_datetime(pd.to_datetime(selcen['Tanggal Order'][indeks]).dt.strftime('%Y-%d-%m %H:%M')).dt.month_name()
selcen['Year'][indeks] = pd.to_datetime(pd.to_datetime(selcen['Tanggal Order'][indeks]).dt.strftime('%Y-%d-%m %H:%M')).dt.year

### tambahan timo April 23
selcen['true datetime'][indeks] = pd.to_datetime(pd.to_datetime(selcen['Tanggal Order'][indeks]).dt.strftime('%Y-%d-%m %H:%M'))

non_indeks = selcen[~selcen.index.isin(indeks)].index.to_list()
selcen['Date'][non_indeks] = pd.to_datetime(selcen['Tanggal Order'][non_indeks]).dt.day
selcen['Month'][non_indeks] = pd.to_datetime(selcen['Tanggal Order'][non_indeks]).dt.month_name()
selcen['Year'][non_indeks] = pd.to_datetime(selcen['Tanggal Order'][non_indeks]).dt.year

### tambahan timo April 23
selcen['true datetime'][non_indeks] = pd.to_datetime(selcen['Tanggal Order'][non_indeks])
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
selcen[selcen['Qty. Invoiced'].isnull()]
# Out:
# Empty DataFrame
# Columns: [No. Order, No. Order Item, No. Awb, Tanggal Order, Nama Pemesan, Kode SKU, Blibli SKU, SKU, Nama Produk, Qty. Invoiced, Harga Produk, Servis Logistik, Kode Merchant, Nama Store, Order Status, Toko/Gudang, Source, Unnamed: 0, Alamat pengambilan, Alamat, Kota, Provinsi, Harga item pesanan, Total harga item pesanan, Total, Diskon, Nama diskon, Kode diskon, Voucher seller, Nama voucher seller, Kode voucher seller, Nama voucher gratis ongkir, Kode voucher gratis ongkir, Catatan produk, Tanggal pengiriman, Date, Month, Year, true datetime]
# Index: []
#
# [0 rows x 39 columns]

# %%
#### cek bulan realisasi
selcen[['Year', 'Month']].drop_duplicates()
# Out:
#          Year      Month
# 0      2021.0    January
# 427    2021.0   February
# 688    2021.0      March
# 1092   2021.0      April
# 1379   2021.0        May
# 1704   2021.0       June
# 2012   2021.0  September
# 2347   2021.0    October
# 2765   2021.0   November
# 3193   2021.0   December
# 3648   2022.0    January
# 4087   2022.0   February
# 4349   2022.0      March
# 4629   2022.0      April
# 4882   2022.0        May
# 5252   2022.0       June
# 5563   2022.0       July
# 6116   2022.0     August
# 6742   2022.0  September
# 7147   2022.0    October
# 7693   2022.0   November
# 8151   2022.0   December
# 8503   2023.0    January
# 8796   2023.0   February
# 9063   2023.0      March
# 9297   2023.0      April
# 9720   2023.0        May
# 10105  2023.0       June
# 10321  2023.0       July
# 10674  2023.0     August
# 10964  2023.0  September
# 11191  2023.0    October
# 11408  2023.0   November
# 11679  2023.0   December
# 11933  2024.0    January
# 12140  2024.0   February
# 12317  2024.0      March
# 12460  2024.0      April
# 12607  2024.0        May
# 12925  2024.0       June
# 13417  2024.0       July
# 13793  2024.0     August
# 13965  2021.0     August
# 14354  2021.0       July

# %%
#### run 4
selcen_new = selcen[selcen['Year'] > 2022]

# %%
### run 5
selcen_new.loc[selcen_new['Nama Produk']=='WHS - L-Men Protein Crunch BBQ Beef (20gr)','SKU']='2309005305'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - L-Men High Protein 2 Go 200 ml x 4 pcs','SKU']='2307061250P4'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - FREE PROTEIN CRUNCH - L-Men PlantProtein Ogura 216g - Suplemen Tinggi Protein Nabati Rendah Lemak Vegan Lactose Free','SKU']='PL24B102'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - L-Men Platinum Choco Latte 800g (25g protein / serving) - Suplemen Tinggi Whey Protein Rendah Lemak','SKU']='2305551288'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - L-Men Platinum Choco Latte 800g x 3 pcs (25g protein / serving) - Suplemen Tinggi Whey Protein Rendah Lemak','SKU']='2305551288P3'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - L-Men Proteinmix Coffee 6 sachet (12g protein) - Suplemen 3 in 1 Tinggi Protein Rendah Lemak','SKU']='2301050106'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - L-Men Gain Mass Banana 225g - Suplemen Penambah Massa Otot Tinggi Whey Protein','SKU']='2304036151'

selcen_new.loc[selcen_new['Nama Produk']=='WHS - L-Men Protein Crunch BBQ Beef (20gr) x 10 pcs','SKU']='2309005305P10'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - Twin Pack - L-Men Whey Advanced Choco Vanilla 500g - Suplemen Tinggi Whey Protein','SKU']='2303056180P2'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - L-Men Protein Crunch BBQ Beef (20gr) x 5 pcs','SKU']='2309005305P5'

selcen_new.loc[selcen_new['Nama Produk']=='WHS - Daily Package - L-Men Daily Chocolate 250gr & Popcorn Caramel 250gr - Suplemen Tinggi Whey Protein','SKU']='PL1L23'
selcen_new.loc[selcen_new['Nama Produk']=='WHS - Twin Pack - L-Men Whey Daily Dark Chocolate 250g - Suplemen Tinggi Whey Protein','SKU']='2300551155P2'
selcen_new.loc[selcen_new['Nama Produk']=='Daily Package - L-Men Daily Chocolate 250gr & Popcorn Caramel 250gr - Suplemen Tinggi Whey Protein','SKU']='PL1L23'
selcen_new.loc[selcen_new['Nama Produk']=='Twin Pack - L-Men Protein Bar Crunchy Chocolate 12 sachet (7g protein / serving) - Camilan Rendah Lemak dengan Whey Protein ','SKU']='2306551173P2'
selcen_new.loc[selcen_new['Nama Produk']=='L-Men Platinum Refill Choco Latte 800g - Suplemen Tinggi Whey Protein Rendah Lemak ','SKU']='2305551028'
selcen_new.loc[selcen_new['Nama Produk']=='FREE Mini Juicer Ecentio - Twin Pack : L-Men Platinum Basic Whey Protein Unflavoured 800gr/1.8lbs - 25g Whey Protein – 24 Serving – 6,5g BCAA','SKU']='2LG0908060P2'
selcen_new.loc[selcen_new['Nama Produk']=='L-Men Whey Daily Dark Chocolate 250g - Suplemen Tinggi Whey Protein ','SKU']='2300551155'
selcen_new.loc[selcen_new['Nama Produk']=='Triple Pack - L-Men Whey Daily Dark Chocolate 250g - Suplemen Tinggi Whey Protein ','SKU']='2300551155P3'
# selcen_new.loc[selcen_new['Nama Produk']=='FREE Mini Juicer Ecentio - Twin Pack : L-Men Platinum Basic Whey Protein Unflavoured 800gr/1.8lbs - 25g Whey Protein – 24 Serving – 6,5g BCAA','SKU']='2309005305P10'
selcen_new.loc[selcen_new['Nama Produk']=='Gym Starter Pack: L-Men Platinum Vanilla Caramel 800gr & L-Men Isopower Creatine Stargizing 30 Sachet ','SKU']='PL30L32'
selcen_new.loc[selcen_new['Nama Produk']=='L-Men Lose Weight Chocolate Cereal 300g (2 pcs) - Suplemen Penurun Berat Badan Tinggi Whey Protein ','SKU']='2304558112P2'
selcen_new.loc[selcen_new['Nama Produk']=='Harga Spesial - L-Men Platinum Kacang Hijau 800g (25g protein) - Suplemen Tinggi Whey Protein Rendah Lemak ','SKU']='(E)2305507288'



for i in selcen_new[selcen_new['SKU']=='nan']['Blibli SKU'].unique():
    print(i)
    listskunfi=selcen_new[(selcen_new['Blibli SKU']==i)&(selcen_new['SKU']!='nan')].reset_index()['SKU']#[0]
    if len(listskunfi)>0:
        selcen_new.loc[(selcen_new['Blibli SKU']==i)&(selcen_new['SKU']=='nan'),'SKU']=listskunfi[0]
    else:
        
        prodnamewhs=selcen_new[(selcen_new['Blibli SKU']==i)]['Nama Produk'].unique()[0]
        # print(prodnamewhs)
        prodnamereal=prodnamewhs.replace("WHS - ","")
        # print(prodnamereal)
        skuprodnamereal=selcen_new[selcen_new['Nama Produk']==prodnamereal]['SKU'].unique()[-1]
        selcen_new.loc[(selcen_new['Blibli SKU']==i)&
                       (selcen_new['SKU']=='nan')&
                       (selcen_new['Nama Produk']==prodnamewhs),'SKU']=skuprodnamereal

# %%
# print(selcen_new[selcen_new['Nama Produk'].str.contains('L-Men Lose Weight Chocolate Cereal 300g')]['SKU'].unique())
selcen_new[selcen_new['SKU']=='nan'][['SKU','Nama Produk']].drop_duplicates().values
# i
# Out:
# array([], shape=(0, 2), dtype=object)

# %%
cek_dups = selcen_new[(selcen_new[['No. Order', 'SKU']].duplicated(keep = False)) & (selcen_new['SKU'].notnull())].groupby('SKU')['Nama Produk'].unique().reset_index()
( cek_dups.join( pd.DataFrame(cek_dups['Nama Produk'].to_list())
                 .add_prefix('array_') )
        .drop('Nama Produk', axis = 1) )#.values
# Out:
#               SKU                                            array_0
# 0   (E)2LD0905181  L-Men Gain Mass Klepon Latte 500g - Suplemen P...
# 1      2300551155  L-Men Whey Daily Dark Chocolate 250g - Supleme...
# 2    2300551155P3  Triple Pack - L-Men Whey Daily Dark Chocolate ...
# 3      2303054155  L-Men Whey Advanced Cappuccino 250g - Suplemen...
# 4      2304051151  L-Men Gain Mass Chocolate 225g - Suplemen Pena...
# 5    2304051180P2  L-Men Gain Mass Chocolate 500g (2 pcs) - Suple...
# 6      2305551028  L-Men Platinum Refill Choco Latte 800g - Suple...
# 7      2306551173  L-Men Protein Bar Crunchy Chocolate 12 sachet ...
# 8    2306551173P2  Twin Pack - L-Men Protein Bar Crunchy Chocolat...
# 9    2307061250P4            L-Men High Protein 2 Go 200 ml x 4 pcs
# 10  2309005305P20      L-Men Protein Crunch BBQ Beef (20gr) x 20 pcs

# %%
# selcen_new[(selcen_new[['No. Order', 'SKU']].duplicated(keep = False))]

# %%
# np.unique([len(x) for x in cek_dups['Nama Produk']])

# %%
## run 5.1 buang gimmick colab
selcen_new=selcen_new[selcen_new['SKU']!='380000']

# %%
### run 6

temp2 = selcen_new.copy()

import time
import pandas as pd
import numpy as np
import math

import smtplib 
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
from smtplib import SMTP
import smtplib
import sys
import requests
import os
    
data_SKU = pd.read_excel(r"D:\1. Masterdata\SKU_File\data_SKU.xlsx",engine='openpyxl')

s = requests.Session()
s.get("https://tatanama.pythonanywhere.com")
s.post("https://tatanama.pythonanywhere.com", data = {'username' : 'ecommerce', 'password' : 'ttnmecom24'})
r = s.get("https://tatanama.pythonanywhere.com/download")

with open(r"D:\1. Masterdata\SKU_File\Master tatanama.xlsx", 'wb') as output:
    output.write(r.content)

if os.path.isfile(r"D:\1. Masterdata\SKU_File\Master tatanama.xlsx"):    
    SKU_append = pd.read_excel(r"D:\1. Masterdata\SKU_File\Master tatanama.xlsx")
    SKU_append.columns = [x.replace('_', ' ') for x in SKU_append.columns]
    data_SKU = data_SKU[~data_SKU['SKU'].astype(str).isin(SKU_append['SKU'].astype(str))]
    data_SKU = data_SKU.append(SKU_append, ignore_index = True, sort = False)

to_excel = data_SKU.to_excel(r"D:\1. Masterdata\SKU_File\data_SKU.xlsx", index = False)

# %%
## run 7 must null
temp2[~temp2['SKU'].isin(data_SKU['SKU'])][['No. Order', 'Nama Produk', 'SKU']].drop_duplicates('SKU').values
# Out:
# array([], shape=(0, 3), dtype=object)

# %%
## run 7.1
from datetime import datetime,timedelta
listjanjian=requests.get('http://event.l-men.com/apiv1?type=janjian')
for i in listjanjian.json():
    sku=i['realsku']
    print(sku)
    start=datetime.fromtimestamp(int(i['startdate']/1000)).replace(hour=0)
    end=datetime.fromtimestamp(int(i['enddate']/1000)).replace(hour=23)
    print(i['notes'])
    selcen_new.loc[(selcen_new['SKU']==sku)&(selcen_new['true datetime']>=start)&(selcen_new['true datetime']<end),'Pemilik Budget']=i['notes']
    print('=====')
    # print(str(datetime.fromtimestamp(int(i['enddate']/1000)).replace(hour=0)))
# Out:
# 2T00803164
# Launching tahap 2
# =====
# 2T00803164P3
# Launching tahap 2
# =====
# 2T02703229P2
# Launching
# =====
# PT25T74
# Launching
# =====
# 2T02703229
# Launching tahap 2
# =====
# 2104115110
# Launching tahap 2
# =====
# 2104115110P2
# Launching tahap 2
# =====
# 2104148024
# Launching tahap 2
# =====
# 2104148024P2
# Launching tahap 2
# =====
# 1N01402250P24
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 2104010270
# Marketing
# =====
# 1101909331
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 2HF0114021
# Launching tahap 2
# =====
# 2101751112
# Marketing
# =====
# 2101751112P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101384106
# Internal
# =====
# 2101384106P3
# Internal
# =====
# 2105055180P2
# Internal
# =====
# 2104523105P3
# Internal
# =====
# 2104508105P3
# Internal
# =====
# 2104543105P3
# Internal
# =====
# 2104589105P3
# Internal
# =====
# 2104241210P2
# Internal
# =====
# 2106386249P24
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101151180
# Internal
# =====
# 2101150180
# Internal
# =====
# 2101200180
# Internal
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102900130
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2309005305P20
# Marketing
# =====
# 2T01813126P2
# Launching
# =====
# PH22T17
# Marketing
# =====
# PH22T41
# Marketing
# =====
# PH19H22
# Launching
# =====
# PH22H95G277
# Marketing
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2101845360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 2101888360
# Marketing
# =====
# PH19H103
# Launching
# =====
# PH35H103
# Launching
# =====
# 2305551028
# Launching
# =====
# 2HF0113021
# Launching tahap 2
# =====
# 2HF0112021
# Launching tahap 2
# =====
# 1N01402250P4
# Internal
# =====
# 1N01402250P24
# Internal
# =====
# 2T00803164
# Internal
# =====
# 2T00803164P2
# Internal
# =====
# 2T00803164P3
# Internal
# =====
# 1101686318
# Marketing
# =====
# 1101694318
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 2T00803164
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 1101618318P2
# Marketing
# =====
# 1101618318
# Marketing
# =====
# 2309005305
# Marketing
# =====
# 2309005305P5
# Marketing
# =====
# 2309005305P10
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# (E)2101469180
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 2T01402249P4
# Launching
# =====
# 2T01402249P24
# Launching
# =====
# 1100534034
# Launching
# =====
# 2HC0109021
# Launching tahap 2
# =====
# 2305551028
# Launching tahap 2
# =====
# PH19H22
# Marketing
# =====
# PH22T41
# Marketing
# =====
# PH22T17
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# 2T01813126
# Launching tahap 2
# =====
# 2T01813126P2
# Launching tahap 2
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900130
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2101150180
# Internal
# =====
# 2101151180
# Internal
# =====
# 2101200180
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2101150180P2
# Internal
# =====
# 2101151180P2
# Internal
# =====
# 2101200180P2
# Internal
# =====
# 2304097159
# Internal
# =====
# 2104394210P2
# Internal
# =====
# 2104394210
# Internal
# =====
# PT26T54
# Internal
# =====
# 2T01705164P2
# Launching
# =====
# 2305551028
# Launching tahap 2
# =====
# PH22H95G277
# Marketing
# =====
# 1101665318
# Marketing
# =====
# 1101677318
# Marketing
# =====
# 1101653318
# Marketing
# =====
# 1101618318
# Marketing
# =====
# 2HH0813443P2
# Launching
# =====
# 2HF0114021P2
# Marketing
# =====
# 2LL1402249P4
# Launching
# =====
# 2LL1402249P24
# Launching
# =====
# 2LM0801029
# Launching
# =====
# PL32L33
# Launching
# =====
# 2HF0114021
# Marketing
# =====
# 2101651195
# Marketing
# =====
# 2101651195P2
# Marketing
# =====
# 2101453195
# Marketing
# =====
# 2305551028
# Internal
# =====
# 2101453195P2
# Marketing
# =====
# 2101486195
# Marketing
# =====
# 2101486195P2
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# (E)1101505453
# Internal
# =====
# 2304051180
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2304008180
# Internal
# =====
# 2TA0102180
# Launching tahap 2
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102000180
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2102000180P2
# Internal
# =====
# 2102900130
# Internal
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 1N03301456
# Launching
# =====
# 2T01402249P24
# Launching tahap 2
# =====
# 2LM0801029
# Launching tahap 2
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2T01402249P24
# Internal
# =====
# 2106386249P24
# Internal
# =====
# 2106386249P12
# Internal
# =====
# 2101888360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 2101845360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2305551028P3
# Internal
# =====
# 2305551028
# Internal
# =====
# 2305507288
# Internal
# =====
# 2305545288
# Internal
# =====
# 2305559288
# Internal
# =====
# 2305584288
# Internal
# =====
# 2105028180P2
# Internal
# =====
# 1N01402250P24
# Internal
# =====
# 2LM0801029P2
# Marketing
# =====
# PT25T41
# Internal
# =====
# 2104228230P2
# Internal
# =====
# 2104251230P2
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2304097159
# Marketing
# =====
# 2T00805043P2
# Launching
# =====
# 2T00805043P2
# Launching tahap 2
# =====
# 2105028180P2
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2T01402249P24
# Internal
# =====
# 2304051180P2
# Marketing
# =====
# PL7(2)G26
# Internal
# =====
# PL25(2)G26
# Internal
# =====
# PL27(2)G26
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# PL6(2)L28L31
# Internal
# =====
# 2304558112P4
# Internal
# =====
# (E)2101907250P4
# Marketing
# =====
# (E)2101845360
# Marketing
# =====
# 2101478180
# Internal
# =====
# 2101452195
# Internal
# =====
# 2101452190
# Internal
# =====
# 2101466148
# Internal
# =====
# 2101485195
# Internal
# =====
# 2101485180
# Internal
# =====
# 2101524180
# Internal
# =====
# 2101551195
# Internal
# =====
# 2101551190
# Internal
# =====
# 2101551180
# Internal
# =====
# 2101500180
# Internal
# =====
# 2101500190
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101150180P2
# Internal
# =====
# 2101151180P2
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2T02703229P2
# Internal
# =====
# 1N00838454
# Launching
# =====
# 2101500195
# Internal
# =====
# 2101578180
# Internal
# =====
# 2101452180
# Internal
# =====
# 2304558112P4
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2101459180
# Internal
# =====
# 2101479180
# Internal
# =====
# 2101401180
# Internal
# =====
# 2101444180
# Internal
# =====
# 2101428180
# Internal
# =====
# 2101428180P2
# Internal
# =====
# 2101401180P2
# Internal
# =====
# PL25(2)G26
# Internal
# =====
# PL27(2)G26
# Internal
# =====
# PL7(2)G26
# Internal
# =====
# 2HC0112021P2
# Launching
# =====
# 2HG0103050P2
# Launching
# =====
# 2101584180
# Internal
# =====
# 2101478180P2
# Internal
# =====
# 2101452195P2
# Internal
# =====
# 2101452180P2
# Internal
# =====
# 2101452190P2
# Internal
# =====
# 2101466148P2
# Internal
# =====
# 2101485195P2
# Internal
# =====
# 2101485180P2
# Internal
# =====
# 2101524180P2
# Internal
# =====
# 2101551195P2
# Internal
# =====
# 2101551180P2
# Internal
# =====
# 2101551190P2
# Internal
# =====
# 2101500180P2
# Internal
# =====
# 2101500190P2
# Internal
# =====
# 2101500195P2
# Internal
# =====
# 2101578180P2
# Internal
# =====
# 2101584180P2
# Internal
# =====
# 2HC0112021
# Launching tahap 2
# =====
# 2HC0112021P2
# Launching tahap 2
# =====
# 2104406
# Marketing
# =====
# (E)1101693318
# Internal
# =====
# 2101845360
# Marketing
# =====
# 2101888360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2101710110
# Marketing
# =====
# 2101710110P2
# Marketing
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2306551173P2
# Marketing
# =====
# 2306551173
# Marketing
# =====
# 2304051180
# Internal
# =====
# 2304034180
# Internal
# =====
# 2304008180
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2304034180P2
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# (E)2309005305P20
# Marketing
# =====
# 2T01813126
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2T01814125P2
# Launching
# =====
# 1N01402250P24
# Internal
# =====
# 2T00806053P2
# Launching
# =====
# 2T00806053P2
# Launching
# =====
# 2T00806053P2
# Launching
# =====
# 2T01705024P2
# Launching
# =====
# 2HH0816450P2
# Launching
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Marketing
# =====
# 2HF0111003P3
# Marketing
# =====
# 2HG0103050P2
# Launching tahap 2
# =====
# (E)2101845360
# Marketing
# =====
# 2T01403249P24
# Launching
# =====
# 2T01403249P4
# Launching
# =====
# 2T00806053P2
# Launching tahap 2
# =====
# 2T01705024P2
# Launching tahap 2
# =====
# 2T01814125P2
# Launching tahap 2
# =====
# 2T01814125
# Launching tahap 2
# =====
# 2T01403249P24
# Launching tahap 2
# =====
# 2T01403249P4
# Launching tahap 2
# =====
# (E)2106317152P2
# Marketing
# =====
# (E)2106317152
# Marketing
# =====
# 2103300316
# Marketing
# =====
# PT79T81
# Internal
# =====
# 2305551028P3
# Internal
# =====
# (E)2101469180
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101466148
# Marketing
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Internal
# =====
# 2HF0111003P3
# Marketing
# =====
# 2106386249P24
# Internal
# =====
# 2106386249P12
# Internal
# =====
# 2T01402249P24
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2T01403249P12
# Internal
# =====
# 2T01403249P24
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2LG0906288
# Launching
# =====
# 2LG0906288
# Launching
# =====
# PH107(2)G331
# Marketing
# =====
# PT79T81
# Internal
# =====
# (E)2305551288P2
# Internal
# =====
# (E)2305551288P3
# Internal
# =====
# 1N00804229
# Launching
# =====
# 2T00804164P2
# Launching
# =====
# 2T01705024P2
# Internal
# =====
# 2HC0112021P2
# Internal
# =====
# 2HC0113021P2
# Launching
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2101609180
# Marketing
# =====
# 2104241210
# Marketing
# =====
# 2104153110
# Marketing
# =====
# LN00000002
# Marketing
# =====
# 2LG0906288
# Launching tahap 2
# =====
# 2104115110P2
# Marketing
# =====
# 2T01813126
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# PL32L33
# Internal
# =====
# PL6(2)L32
# Marketing
# =====
# (E)2104406P2
# Marketing
# =====
# (E)2104406
# Marketing
# =====
# PH106H109(2)G334
# Launching
# =====
# PH64H109(2)G334
# Launching
# =====
# 2305551028P3
# Internal
# =====
# (E)2101524180P2
# Marketing
# =====
# (E)2305551288
# Internal
# =====
# (E)2HF0112021
# Marketing
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Marketing
# =====
# 2HF0111003P3
# Marketing
# =====
# 2304051180
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# 2304008180
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304558112P4
# Internal
# =====
# 2T01402249P4
# Internal
# =====
# 2106386249P4
# Internal
# =====
# 2T01403249P4
# Internal
# =====
# 2LC0903181P2
# Launching
# =====
# 2LH1204172P2
# Launching
# =====
# 2T01813126
# Internal
# =====
# 2101700037
# Internal
# =====
# 2T02603203P2
# Launching
# =====
# 2HH1409249P4
# Launching
# =====
# 2HH1409249P24
# Launching
# =====
# (E)2101469180
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101466148
# Marketing
# =====
# (E)2LD0905181
# Internal
# =====
# (E)2LD0905181P2
# Internal
# =====
# PB121H107
# Launching
# =====
# PH107B23
# Launching
# =====
# 2HC0112021P2
# Internal
# =====
# 2HC0113021P2
# Launching
# =====
# 2HC0113021
# Launching tahap 2
# =====
# 2HG0103050
# Launching
# =====
# 2HH0817441P2
# Launching
# =====
# (E)2106317152P2
# Marketing
# =====
# 2103300316
# Marketing
# =====
# 2T02603203P2
# Launching tahap 2
# =====
# (E)2HF0112021
# Marketing
# =====
# (E)2101864443
# Marketing
# =====
# 2LC0903181
# Launching tahap 2
# =====
# 2LH1204172
# Launching tahap 2
# =====
# 2HH1409249P4
# Launching tahap 2
# =====
# 2HH1409249P24
# Launching tahap 2
# =====
# 2104405
# Marketing
# =====
# 2104405P2
# Marketing
# =====
# 2106023014P3
# Marketing
# =====
# (E)2LD0905181
# Marketing
# =====
# 2HH0817441
# Launching tahap 2
# =====
# 2305507288
# Internal
# =====
# 2305545288
# Internal
# =====
# 2101684195
# Launching
# =====
# 2305551028P3
# Internal
# =====
# 2T01812126
# Marketing
# =====
# 2T00805043
# Marketing
# =====
# 2HH1409249P4
# Marketing
# =====
# 2HH1409249P24
# Marketing
# =====
# 2HH1409249P24
# Launching tahap 2
# =====
# 2HH1409249P4
# Launching tahap 2
# =====
# 2T00806053
# Marketing
# =====
# 2T01705024
# Marketing
# =====
# 2104148024
# Marketing
# =====
# 2HC0112021
# Marketing
# =====
# 2106023014P1
# Marketing
# =====
# 2HC0113021
# Marketing
# =====
# 2105028180
# Marketing
# =====
# 2T03201001
# Marketing
# =====
# 2101609180
# Marketing
# =====
# 2104241210
# Marketing
# =====
# 2104394210
# Marketing
# =====
# 2102300105
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 1101182250P24
# Marketing
# =====
# 1N00838454
# Marketing
# =====
# 2LH1204172
# Marketing
# =====
# 1N03301456
# Marketing
# =====
# 2LH1204172
# Launching tahap 2
# =====
# 1N00804229
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 1101656318
# Marketing
# =====
# 2304515112
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 1101677318
# Marketing
# =====
# 2LM0801029
# Marketing
# =====
# 2T01403249P4
# Marketing
# =====
# 2T01403249P24
# Marketing
# =====
# 2T02603203
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 1101182250P4
# Marketing
# =====
# 2HG0103050
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 2304051180
# Marketing
# =====
# PL32L33
# Marketing
# =====
# PL30L32
# Marketing
# =====
# PL32L35
# Marketing
# =====
# PL6L32
# Marketing
# =====
# PL7L32
# Marketing
# =====
# 2101684195
# Launching tahap 2
# =====
# 2T01402249P4
# Marketing
# =====
# 2T01402249P24
# Marketing
# =====
# 2T01403249P4
# Marketing
# =====
# 2T01403249P24
# Marketing
# =====
# 2106386249P4
# Marketing
# =====
# 2106386249P24
# Marketing
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0113021P2
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2HF0112021P2
# Marketing
# =====
# 2HF0114021P2
# Marketing
# =====
# 2101699155P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T01813126P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00804164P2
# Marketing
# =====
# 2104405
# Marketing
# =====
# 2LM0801029
# Marketing
# =====
# PL6L32
# Marketing
# =====
# PL32L33
# Launching
# =====
# PL7L32
# Marketing
# =====
# PL32L35
# Marketing
# =====
# PL30L32
# Marketing
# =====
# 2T02604203P2
# Launching
# =====
# 2306551173
# Marketing
# =====
# 2LH1204172
# Marketing
# =====
# PT79T86(4)
# Launching
# =====
# 2HF0114021
# Marketing
# =====
# 2HF0114021P2
# Marketing
# =====
# 2T01813126P2
# Marketing
# =====
# 2T01813126
# Marketing
# =====
# LN00000002
# Marketing
# =====
# 2T01404249P4
# Launching
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00804164P2
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 2LG0908060
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2T01813126
# Marketing
# =====
# 2T00805043
# Marketing
# =====
# 2T00805043P2
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0114021
# Marketing
# =====
# 2T00805043P2
# Marketing
# =====
# 2T00804024P2
# Launching
# =====
# 2101452195
# Marketing
# =====
# 2101485195
# Marketing
# =====
# 2101651195
# Marketing
# =====
# 2101684195
# Marketing
# =====
# 2101453195
# Marketing
# =====
# 2101486195
# Marketing
# =====
# 2101500195
# Marketing
# =====
# 2101551195
# Marketing
# =====
# 2HC0113021
# Marketing
# =====
# 2T00806053P2
# Internal
# =====
# 2HC0112021
# Marketing
# =====
# 2HH1409249P4
# Marketing
# =====
# 2101751112
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2HG0103050
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 2HH0817441
# Marketing
# =====
# 2HC0112021P2
# Marketing
# =====
# 2HC0113021P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2HH1409249P24
# Marketing
# =====
# 2T02604203P2
# Launching tahap 2
# =====
# 2304097159
# Marketing
# =====
# 2T01404249P4
# Launching tahap 2
# =====
# 2T01404249P24
# Launching tahap 2
# =====
# 1N03302456
# Launching
# =====
# 2T02604203
# Launching tahap 2
# =====
# PT79T85
# Launching tahap 2
# =====
# 2304051288
# Launching
# =====
# PN125N150
# Launching
# =====
# 1102560453
# Launching
# =====
# 1N01402250P4
# Launching
# =====
# 1N01402250P24
# Launching
# =====
# PT79G342
# Internal
# =====
# PT79G343
# Internal
# =====
# 2T01705024P2
# Marketing
# =====
# 2T01705024P2
# Marketing
# =====
# 2304051288P2
# Launching
# =====
# 2304051288
# Launching tahap 2
# =====
# 1N00840454
# Launching
# =====
# 1N00840454
# Launching
# =====
# 1N00840454
# Launching
# =====
# 2HF0115003P2
# Launching
# =====
# 1101677104
# Launching
# =====
# 2T01705024
# Marketing
# =====
# 2104115110
# Marketing
# =====
# 2104115110P2
# Marketing
# =====
# 2T00803164
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 2104148024
# Marketing
# =====
# 2104148024P2
# Marketing
# =====
# 2104119110
# Marketing
# =====
# 2104119110P2
# Marketing
# =====
# 2T00804024
# Launching tahap 2
# =====
# 2T02604203
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2HC0113021P2
# Marketing
# =====
# 2HC0112021P2
# Marketing
# =====
# 2306551173
# Internal
# =====
# 2LH1204172
# Internal
# =====
# 1NC1710075
# Launching
# =====
# 1NC1711075
# Launching
# =====
# 2LC0903181
# Marketing
# =====
# 2LC0903181P2
# Marketing
# =====
# 2104119110
# Marketing
# =====
# 2104119110P2
# Marketing
# =====
# 2305507288
# Marketing
# =====
# 2305559288
# Marketing
# =====
# 2106395308
# Marketing
# =====
# 2106395308P2
# Marketing
# =====
# 2106395308P3
# Marketing
# =====
# 2102300105
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 2304008180P2
# Marketing
# =====
# 2106023014
# Marketing
# =====
# 2106023014P2
# Marketing
# =====
# 2106023014P3
# Marketing
# =====
# 2T02604203P2
# Internal
# =====
# 2T02604203
# Internal
# =====
# 1N00804229P2
# Marketing
# =====
# 2103300316
# Marketing
# =====
# 2HF0115003
# Launching tahap 2
# =====
# 2304576112
# Marketing
# =====
# 2304576112P2
# Marketing
# =====
# 2304515112C2
# Marketing
# =====
# 2LM0801029
# Marketing
# =====
# 2LM0801029P2
# Marketing
# =====
# PL32L33
# Marketing
# =====
# 2305551028
# Marketing
# =====
# (J)71110157
# Launching
# =====
# (J)71110158
# Launching
# =====
# 1N00841454
# Launching
# =====
# 2LH1204172
# Marketing
# =====
# 2T02604203
# Internal
# =====
# 2T02604203P2
# Internal
# =====
# 2304008180
# Marketing
# =====
# 2304008180P2
# Marketing
# =====
# 2304576112
# Marketing
# =====
# 2304576112P2
# Marketing
# =====
# 2T01705024P2
# Marketing
# =====
# 2104115110
# Marketing
# =====
# 2104115110P2
# Marketing
# =====
# 2T00803164
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 2104148024
# Marketing
# =====
# 2104148024P2
# Marketing
# =====
# 2104119110
# Marketing
# =====
# 2104119110P2
# Marketing
# =====
# 2105055180
# Marketing
# =====
# 2105055180P2
# Marketing
# =====
# 2HF0113021
# Marketing
# =====
# 2LH1204172
# Marketing
# =====

# %%
## run 8
# Merging with SKU Attributes
print('== Merging with SKU Attributes ==')

temp2 = selcen_new.copy()

temp2 = temp2.rename(columns = {'Nama Produk' : 'Product Name'})

data_SKU.loc[data_SKU['Price List NFI']=='-','Price List NFI']=0
data_SKU['Price List NFI'] = data_SKU['Price List NFI'].astype(float).astype('int64')
data_SKU['Real SKU'] = data_SKU['SKU'].astype(str).str.replace('(S)', '', regex = False)
data_SKU['Real Nama Produk'] = data_SKU['Nama Produk'].astype(str)
list_col = ['Real SKU', 'Real Nama Produk', 'Brand', 'Sub Brand']

temp_merge = temp2.merge(data_SKU[list_col].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU').set_index(temp2.index)
for i in list_col:
    temp2[i] = temp_merge[str(i)]

list_col = ['SKU'] + data_SKU.columns[data_SKU.columns.get_loc('Produk 1'):data_SKU.columns.get_loc('Harga Organik 7')+1].to_list()
temp_merge = temp2.merge(data_SKU[list_col].drop_duplicates(['SKU']), how = 'left', left_on = 'Real SKU', right_on = 'SKU').set_index(temp2.index)
list_pcs = [x for x in temp_merge.columns if 'PCS' in x]
for i in list_pcs:
    temp_merge[i] = temp_merge[i] * temp_merge['Qty. Invoiced']

list_col = data_SKU.columns[data_SKU.columns.get_loc('Produk 1'):data_SKU.columns.get_loc('Harga Organik 7')+1].to_list()    
for i in list_col:
    temp2[i] = temp_merge[str(i)]
    
print('== Unbundling ==')
data_bundle1 = temp2[~temp2['Produk 1'].isnull()]
data_bundle1['Bundle Name'] = data_bundle1['Product Name']
data_bundle1['Product Name'] = data_bundle1['Produk 1']
data_bundle1['SKU'] = data_bundle1['SKU Produk 1']
data_bundle1['Qty. Invoiced'] = data_bundle1['PCS Produk 1']
data_bundle1['Price List NFI'] = data_bundle1['Price List NFI 1']
data_bundle1['Total Net'] = data_bundle1['Price List NFI 1']
data_bundle1['Bundle Flag'] = np.nan

data_bundle2 = temp2[~temp2['Produk 2'].isnull()]
data_bundle2['Bundle Name'] = data_bundle2['Product Name']
data_bundle2['Product Name'] = data_bundle2['Produk 2']
data_bundle2['SKU'] = data_bundle2['SKU Produk 2']
data_bundle2['Qty. Invoiced'] = data_bundle2['PCS Produk 2']
data_bundle2['Price List NFI'] = data_bundle2['Price List NFI 2']
data_bundle2['Total Net'] = data_bundle2['Price List NFI 2'] 
data_bundle2['Bundle Flag'] = np.nan

data_bundle3 = temp2[~temp2['Produk 3'].isnull()]
data_bundle3['Bundle Name'] = data_bundle3['Product Name']
data_bundle3['Product Name'] = data_bundle3['Produk 3']
data_bundle3['SKU'] = data_bundle3['SKU Produk 3']
data_bundle3['Qty. Invoiced'] = data_bundle3['PCS Produk 3']
data_bundle3['Price List NFI'] = data_bundle3['Price List NFI 3']
data_bundle3['Total Net'] = data_bundle3['Price List NFI 3'] 
data_bundle3['Bundle Flag'] = np.nan

data_bundle4 = temp2[~temp2['Produk 4'].isnull()]
data_bundle4['Bundle Name'] = data_bundle4['Product Name']
data_bundle4['Product Name'] = data_bundle4['Produk 4']
data_bundle4['SKU'] = data_bundle4['SKU Produk 4']
data_bundle4['Qty. Invoiced'] = data_bundle4['PCS Produk 4']
data_bundle4['Price List NFI'] = data_bundle4['Price List NFI 4']
data_bundle4['Total Net'] = data_bundle4['Price List NFI 4'] 
data_bundle4['Bundle Flag'] = np.nan

data_bundle5 = temp2[~temp2['Produk 5'].isnull()]
data_bundle5['Bundle Name'] = data_bundle5['Product Name']
data_bundle5['Product Name'] = data_bundle5['Produk 5']
data_bundle5['SKU'] = data_bundle5['SKU Produk 5']
data_bundle5['Qty. Invoiced'] = data_bundle5['PCS Produk 5']
data_bundle5['Price List NFI'] = data_bundle5['Price List NFI 5']
data_bundle5['Total Net'] = data_bundle5['Price List NFI 5']
data_bundle5['Bundle Flag'] = np.nan

data_bundle6 = temp2[~temp2['Produk 6'].isnull()]
data_bundle6['Bundle Name'] = data_bundle6['Product Name']
data_bundle6['Product Name'] = data_bundle6['Produk 6']
data_bundle6['SKU'] = data_bundle6['SKU Produk 6']
data_bundle6['Qty. Invoiced'] = data_bundle6['PCS Produk 6']
data_bundle6['Price List NFI'] = data_bundle6['Price List NFI 6']
data_bundle6['Total Net'] = data_bundle6['Price List NFI 6']
data_bundle6['Bundle Flag'] = np.nan

data_bundle7 = temp2[~temp2['Produk 7'].isnull()]
data_bundle7['Bundle Name'] = data_bundle7['Product Name']
data_bundle7['Product Name'] = data_bundle7['Produk 7']
data_bundle7['SKU'] = data_bundle7['SKU Produk 7']
data_bundle7['Qty. Invoiced'] = data_bundle7['PCS Produk 7']
data_bundle7['Price List NFI'] = data_bundle7['Price List NFI 7']
data_bundle7['Total Net'] = data_bundle7['Price List NFI 7']
data_bundle7['Bundle Flag'] = np.nan

data_bundle = data_bundle1.append([data_bundle2, data_bundle3, data_bundle4, data_bundle5, data_bundle6, data_bundle7], ignore_index = True, sort = False)
data_bundle['SKU'] = data_bundle['SKU'].astype(str)
data_bundle['SKU'] = data_bundle['SKU'].str.replace('\.0$', '', regex = True)
data_bundle[['Real SKU', 'Real Nama Produk', 'Brand', 'Sub Brand', 'Parent Item', 'Parent SKU']] = data_bundle.merge(data_SKU[['Real SKU', 'Nama Produk', 'Brand', 'Sub Brand', 'Parent Item', 'Parent SKU']].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU')[['Real SKU_y', 'Nama Produk', 'Brand_y', 'Sub Brand_y', 'Parent Item', 'Parent SKU']]

print("== Pricing ==")
temp2 = temp2.append(data_bundle, ignore_index = True, sort = False)
list_col = ['Real SKU', 'Price List NFI', 'Harga Cost']

temp_merge = temp2.merge(data_SKU[list_col].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU').set_index(temp2.index)
for i in list_col:
    if i == 'Real SKU' or i == 'Price List NFI':
        temp2[i] = temp_merge[str(i) + '_y']
    else :
        temp2[i] = temp_merge[str(i)]
    
temp2['Price List NFI'] = pd.to_numeric(temp2['Price List NFI']).astype(int)
temp2['Harga Cost'] = pd.to_numeric(temp2['Harga Cost']).astype(int)
temp2['Qty. Invoiced'] = pd.to_numeric(temp2['Qty. Invoiced']).astype(int)

temp2['Total Net'] = temp2['Price List NFI'] * temp2['Qty. Invoiced']
temp2['Total Harga Cost'] = temp2['Harga Cost'] * temp2['Qty. Invoiced']

selcen_sku = temp2.copy()

# Merging with J Converter
print('== Merging with J Converter ==')
j_conv = pd.read_excel("Settlement Project\Rumus Realisasi.xlsx", sheet_name = 'Paket Brand')
j_conv = j_conv.iloc[:,:5]
j_conv = j_conv.rename(columns = {'SKU' : 'Real SKU', 'SKU.1' : 'SKU Produk'})
j_conv = j_conv[j_conv['Real SKU'].notnull()]
j_conv['SKU Produk'] = j_conv['SKU Produk'].astype(str).str.replace('.0', '',regex = False)

temp_all = selcen_sku.copy()

temp_all['Real SKU'] = temp_all['Real SKU'].astype(str)
j_conv['Real SKU'] = j_conv['Real SKU'].astype(str)

temp_all = temp_all.merge(j_conv, how = 'left', on = 'Real SKU')

paket_j = temp_all[temp_all['SKU Produk'].notnull()]

paket_j['Bundle Name'] = paket_j['Product Name']
paket_j['Product Name'] = paket_j['Name']
paket_j['SKU'] = paket_j['SKU Produk']
paket_j['Qty. Invoiced'] = paket_j['Qty. Invoiced'] * paket_j['Konversi ke UOM'].astype(float)
paket_j['Bundle Flag'] = np.nan
    
data_SKU['Real SKU'] = data_SKU['SKU'].astype(str)
data_SKU['Real Nama Produk'] = data_SKU['Nama Produk'].astype(str)
if 'Real SKU_y' in paket_j.columns:
    paket_j = paket_j.drop('Real SKU_y', axis = 1)
paket_j['SKU'] = paket_j['SKU'].astype(str)
paket_j[['Real SKU', 'Real Nama Produk', 'Brand', 'Sub Brand', 'Parent Item', 'Parent SKU', 'Price List NFI']] = paket_j.merge(data_SKU[['Real SKU', 'Nama Produk', 'Brand', 'Sub Brand', 'Parent Item', 'Parent SKU', 'Price List NFI']].drop_duplicates(['Real SKU']), how = 'left', left_on = 'SKU', right_on = 'Real SKU').set_index(paket_j.index)[['Real SKU_y', 'Nama Produk', 'Brand_y', 'Sub Brand_y', 'Parent Item_y', 'Parent SKU_y', 'Price List NFI_y']]

paket_j['Total Net'] = paket_j['Price List NFI'] * paket_j['Qty. Invoiced']

paket_j = paket_j.drop(['Nama Paket', 'SKU Produk', 'Name', 'Konversi ke UOM'], axis = 1)
selcen_sku = selcen_sku.append(paket_j, ignore_index = True, sort = False)
indeks = selcen_sku[selcen_sku['Product Name'].isin(paket_j['Bundle Name'])].index.to_list()
selcen_sku['Brand'][indeks] = 'Bundle'

indeks = selcen_sku[(selcen_sku['Real SKU'].astype(str).str.contains('^\(B\)', regex = True)) &
      (~selcen_sku['Brand'].isin(['Bonus Produk', 'Gimmick']))].index.to_list()

selcen_sku['Brand'][indeks] = 'Bonus Produk'

indeks = selcen_sku[(selcen_sku['Real SKU'].astype(str).str.contains('^\(U\)', regex = True)) &
      (~selcen_sku['Brand'].isin(['Bonus Produk', 'Gimmick']))].index.to_list()

selcen_sku['Brand'][indeks] = 'Bonus Produk'

# Selcen Done
print('== Selcen Done ==')
# Out:
# == Merging with SKU Attributes ==
# == Unbundling ==
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# == Pricing ==
# == Merging with J Converter ==
# == Selcen Done ==
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run 8.1
for i in listjanjian.json():
    sku=i['realsku']
    print(sku)
    start=datetime.fromtimestamp(int(i['startdate']/1000)).replace(hour=0)
    end=datetime.fromtimestamp(int(i['enddate']/1000)).replace(hour=23)
    print(i['notes'])
    selcen_sku.loc[(selcen_sku['Pemilik Budget'].isnull())&(selcen_sku['SKU']==sku)&(selcen_sku['true datetime']>=start)&(selcen_sku['true datetime']<end),'Pemilik Budget']=i['notes']
    print('=====')
# Out:
# 2T00803164
# Launching tahap 2
# =====
# 2T00803164P3
# Launching tahap 2
# =====
# 2T02703229P2
# Launching
# =====
# PT25T74
# Launching
# =====
# 2T02703229
# Launching tahap 2
# =====
# 2104115110
# Launching tahap 2
# =====
# 2104115110P2
# Launching tahap 2
# =====
# 2104148024
# Launching tahap 2
# =====
# 2104148024P2
# Launching tahap 2
# =====
# 1N01402250P24
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 2104010270
# Marketing
# =====
# 1101909331
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 2HF0114021
# Launching tahap 2
# =====
# 2101751112
# Marketing
# =====
# 2101751112P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101384106
# Internal
# =====
# 2101384106P3
# Internal
# =====
# 2105055180P2
# Internal
# =====
# 2104523105P3
# Internal
# =====
# 2104508105P3
# Internal
# =====
# 2104543105P3
# Internal
# =====
# 2104589105P3
# Internal
# =====
# 2104241210P2
# Internal
# =====
# 2106386249P24
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101151180
# Internal
# =====
# 2101150180
# Internal
# =====
# 2101200180
# Internal
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102900130
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2309005305P20
# Marketing
# =====
# 2T01813126P2
# Launching
# =====
# PH22T17
# Marketing
# =====
# PH22T41
# Marketing
# =====
# PH19H22
# Launching
# =====
# PH22H95G277
# Marketing
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2101845360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 2101888360
# Marketing
# =====
# PH19H103
# Launching
# =====
# PH35H103
# Launching
# =====
# 2305551028
# Launching
# =====
# 2HF0113021
# Launching tahap 2
# =====
# 2HF0112021
# Launching tahap 2
# =====
# 1N01402250P4
# Internal
# =====
# 1N01402250P24
# Internal
# =====
# 2T00803164
# Internal
# =====
# 2T00803164P2
# Internal
# =====
# 2T00803164P3
# Internal
# =====
# 1101686318
# Marketing
# =====
# 1101694318
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 2T00803164
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 1101618318P2
# Marketing
# =====
# 1101618318
# Marketing
# =====
# 2309005305
# Marketing
# =====
# 2309005305P5
# Marketing
# =====
# 2309005305P10
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# (E)2101469180
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 2T01402249P4
# Launching
# =====
# 2T01402249P24
# Launching
# =====
# 1100534034
# Launching
# =====
# 2HC0109021
# Launching tahap 2
# =====
# 2305551028
# Launching tahap 2
# =====
# PH19H22
# Marketing
# =====
# PH22T41
# Marketing
# =====
# PH22T17
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# 2T01813126
# Launching tahap 2
# =====
# 2T01813126P2
# Launching tahap 2
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900130
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2101150180
# Internal
# =====
# 2101151180
# Internal
# =====
# 2101200180
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2101150180P2
# Internal
# =====
# 2101151180P2
# Internal
# =====
# 2101200180P2
# Internal
# =====
# 2304097159
# Internal
# =====
# 2104394210P2
# Internal
# =====
# 2104394210
# Internal
# =====
# PT26T54
# Internal
# =====
# 2T01705164P2
# Launching
# =====
# 2305551028
# Launching tahap 2
# =====
# PH22H95G277
# Marketing
# =====
# 1101665318
# Marketing
# =====
# 1101677318
# Marketing
# =====
# 1101653318
# Marketing
# =====
# 1101618318
# Marketing
# =====
# 2HH0813443P2
# Launching
# =====
# 2HF0114021P2
# Marketing
# =====
# 2LL1402249P4
# Launching
# =====
# 2LL1402249P24
# Launching
# =====
# 2LM0801029
# Launching
# =====
# PL32L33
# Launching
# =====
# 2HF0114021
# Marketing
# =====
# 2101651195
# Marketing
# =====
# 2101651195P2
# Marketing
# =====
# 2101453195
# Marketing
# =====
# 2305551028
# Internal
# =====
# 2101453195P2
# Marketing
# =====
# 2101486195
# Marketing
# =====
# 2101486195P2
# Marketing
# =====
# 2309005305P20
# Marketing
# =====
# (E)1101505453
# Internal
# =====
# 2304051180
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2304008180
# Internal
# =====
# 2TA0102180
# Launching tahap 2
# =====
# 2102500125
# Internal
# =====
# 2102500130
# Internal
# =====
# 2102900125
# Internal
# =====
# 2102000180
# Internal
# =====
# 2102500125P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2102900125P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2102000180P2
# Internal
# =====
# 2102900130
# Internal
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 1N03301456
# Launching
# =====
# 2T01402249P24
# Launching tahap 2
# =====
# 2LM0801029
# Launching tahap 2
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2T01402249P24
# Internal
# =====
# 2106386249P24
# Internal
# =====
# 2106386249P12
# Internal
# =====
# 2101888360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 2101845360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2305551028P3
# Internal
# =====
# 2305551028
# Internal
# =====
# 2305507288
# Internal
# =====
# 2305545288
# Internal
# =====
# 2305559288
# Internal
# =====
# 2305584288
# Internal
# =====
# 2105028180P2
# Internal
# =====
# 1N01402250P24
# Internal
# =====
# 2LM0801029P2
# Marketing
# =====
# PT25T41
# Internal
# =====
# 2104228230P2
# Internal
# =====
# 2104251230P2
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2304097159
# Marketing
# =====
# 2T00805043P2
# Launching
# =====
# 2T00805043P2
# Launching tahap 2
# =====
# 2105028180P2
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2T01402249P24
# Internal
# =====
# 2304051180P2
# Marketing
# =====
# PL7(2)G26
# Internal
# =====
# PL25(2)G26
# Internal
# =====
# PL27(2)G26
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# PL6(2)L28L31
# Internal
# =====
# 2304558112P4
# Internal
# =====
# (E)2101907250P4
# Marketing
# =====
# (E)2101845360
# Marketing
# =====
# 2101478180
# Internal
# =====
# 2101452195
# Internal
# =====
# 2101452190
# Internal
# =====
# 2101466148
# Internal
# =====
# 2101485195
# Internal
# =====
# 2101485180
# Internal
# =====
# 2101524180
# Internal
# =====
# 2101551195
# Internal
# =====
# 2101551190
# Internal
# =====
# 2101551180
# Internal
# =====
# 2101500180
# Internal
# =====
# 2101500190
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101150180P2
# Internal
# =====
# 2101151180P2
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2T02703229P2
# Internal
# =====
# 1N00838454
# Launching
# =====
# 2101500195
# Internal
# =====
# 2101578180
# Internal
# =====
# 2101452180
# Internal
# =====
# 2304558112P4
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2101459180
# Internal
# =====
# 2101479180
# Internal
# =====
# 2101401180
# Internal
# =====
# 2101444180
# Internal
# =====
# 2101428180
# Internal
# =====
# 2101428180P2
# Internal
# =====
# 2101401180P2
# Internal
# =====
# PL25(2)G26
# Internal
# =====
# PL27(2)G26
# Internal
# =====
# PL7(2)G26
# Internal
# =====
# 2HC0112021P2
# Launching
# =====
# 2HG0103050P2
# Launching
# =====
# 2101584180
# Internal
# =====
# 2101478180P2
# Internal
# =====
# 2101452195P2
# Internal
# =====
# 2101452180P2
# Internal
# =====
# 2101452190P2
# Internal
# =====
# 2101466148P2
# Internal
# =====
# 2101485195P2
# Internal
# =====
# 2101485180P2
# Internal
# =====
# 2101524180P2
# Internal
# =====
# 2101551195P2
# Internal
# =====
# 2101551180P2
# Internal
# =====
# 2101551190P2
# Internal
# =====
# 2101500180P2
# Internal
# =====
# 2101500190P2
# Internal
# =====
# 2101500195P2
# Internal
# =====
# 2101578180P2
# Internal
# =====
# 2101584180P2
# Internal
# =====
# 2HC0112021
# Launching tahap 2
# =====
# 2HC0112021P2
# Launching tahap 2
# =====
# 2104406
# Marketing
# =====
# (E)1101693318
# Internal
# =====
# 2101845360
# Marketing
# =====
# 2101888360
# Marketing
# =====
# 2101847360
# Marketing
# =====
# 2101819360
# Marketing
# =====
# 1101685360
# Marketing
# =====
# 1101656360
# Marketing
# =====
# 2101710110
# Marketing
# =====
# 2101710110P2
# Marketing
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2306551173P2
# Marketing
# =====
# 2306551173
# Marketing
# =====
# 2304051180
# Internal
# =====
# 2304034180
# Internal
# =====
# 2304008180
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2304034180P2
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# (E)2309005305P20
# Marketing
# =====
# 2T01813126
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2T01814125P2
# Launching
# =====
# 1N01402250P24
# Internal
# =====
# 2T00806053P2
# Launching
# =====
# 2T00806053P2
# Launching
# =====
# 2T00806053P2
# Launching
# =====
# 2T01705024P2
# Launching
# =====
# 2HH0816450P2
# Launching
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Marketing
# =====
# 2HF0111003P3
# Marketing
# =====
# 2HG0103050P2
# Launching tahap 2
# =====
# (E)2101845360
# Marketing
# =====
# 2T01403249P24
# Launching
# =====
# 2T01403249P4
# Launching
# =====
# 2T00806053P2
# Launching tahap 2
# =====
# 2T01705024P2
# Launching tahap 2
# =====
# 2T01814125P2
# Launching tahap 2
# =====
# 2T01814125
# Launching tahap 2
# =====
# 2T01403249P24
# Launching tahap 2
# =====
# 2T01403249P4
# Launching tahap 2
# =====
# (E)2106317152P2
# Marketing
# =====
# (E)2106317152
# Marketing
# =====
# 2103300316
# Marketing
# =====
# PT79T81
# Internal
# =====
# 2305551028P3
# Internal
# =====
# (E)2101469180
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101466148
# Marketing
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Internal
# =====
# 2HF0111003P3
# Marketing
# =====
# 2106386249P24
# Internal
# =====
# 2106386249P12
# Internal
# =====
# 2T01402249P24
# Internal
# =====
# 2T01402249P12
# Internal
# =====
# 2T01403249P12
# Internal
# =====
# 2T01403249P24
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2101000195
# Internal
# =====
# 2101000195P2
# Internal
# =====
# 2102900130P2
# Internal
# =====
# 2102500130P2
# Internal
# =====
# 2LG0906288
# Launching
# =====
# 2LG0906288
# Launching
# =====
# PH107(2)G331
# Marketing
# =====
# PT79T81
# Internal
# =====
# (E)2305551288P2
# Internal
# =====
# (E)2305551288P3
# Internal
# =====
# 1N00804229
# Launching
# =====
# 2T00804164P2
# Launching
# =====
# 2T01705024P2
# Internal
# =====
# 2HC0112021P2
# Internal
# =====
# 2HC0113021P2
# Launching
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2101609180
# Marketing
# =====
# 2104241210
# Marketing
# =====
# 2104153110
# Marketing
# =====
# LN00000002
# Marketing
# =====
# 2LG0906288
# Launching tahap 2
# =====
# 2104115110P2
# Marketing
# =====
# 2T01813126
# Internal
# =====
# 2LD0905181
# Internal
# =====
# 2LD0905181P2
# Internal
# =====
# PL32L33
# Internal
# =====
# PL6(2)L32
# Marketing
# =====
# (E)2104406P2
# Marketing
# =====
# (E)2104406
# Marketing
# =====
# PH106H109(2)G334
# Launching
# =====
# PH64H109(2)G334
# Launching
# =====
# 2305551028P3
# Internal
# =====
# (E)2101524180P2
# Marketing
# =====
# (E)2305551288
# Internal
# =====
# (E)2HF0112021
# Marketing
# =====
# 2101454302P3
# Marketing
# =====
# 2101484302P3
# Marketing
# =====
# 2HF0111003P3
# Marketing
# =====
# 2304051180
# Internal
# =====
# 2304051180P2
# Internal
# =====
# 2304051180P4
# Internal
# =====
# 2304008180
# Internal
# =====
# 2304008180P2
# Internal
# =====
# 2304558112
# Internal
# =====
# 2304515112
# Internal
# =====
# 2304576112
# Internal
# =====
# 2304558112P2
# Internal
# =====
# 2304515112C2
# Internal
# =====
# 2304576112P2
# Internal
# =====
# 2304558112P4
# Internal
# =====
# 2T01402249P4
# Internal
# =====
# 2106386249P4
# Internal
# =====
# 2T01403249P4
# Internal
# =====
# 2LC0903181P2
# Launching
# =====
# 2LH1204172P2
# Launching
# =====
# 2T01813126
# Internal
# =====
# 2101700037
# Internal
# =====
# 2T02603203P2
# Launching
# =====
# 2HH1409249P4
# Launching
# =====
# 2HH1409249P24
# Launching
# =====
# (E)2101469180
# Marketing
# =====
# (E)2101487148
# Marketing
# =====
# (E)2101466148
# Marketing
# =====
# (E)2LD0905181
# Internal
# =====
# (E)2LD0905181P2
# Internal
# =====
# PB121H107
# Launching
# =====
# PH107B23
# Launching
# =====
# 2HC0112021P2
# Internal
# =====
# 2HC0113021P2
# Launching
# =====
# 2HC0113021
# Launching tahap 2
# =====
# 2HG0103050
# Launching
# =====
# 2HH0817441P2
# Launching
# =====
# (E)2106317152P2
# Marketing
# =====
# 2103300316
# Marketing
# =====
# 2T02603203P2
# Launching tahap 2
# =====
# (E)2HF0112021
# Marketing
# =====
# (E)2101864443
# Marketing
# =====
# 2LC0903181
# Launching tahap 2
# =====
# 2LH1204172
# Launching tahap 2
# =====
# 2HH1409249P4
# Launching tahap 2
# =====
# 2HH1409249P24
# Launching tahap 2
# =====
# 2104405
# Marketing
# =====
# 2104405P2
# Marketing
# =====
# 2106023014P3
# Marketing
# =====
# (E)2LD0905181
# Marketing
# =====
# 2HH0817441
# Launching tahap 2
# =====
# 2305507288
# Internal
# =====
# 2305545288
# Internal
# =====
# 2101684195
# Launching
# =====
# 2305551028P3
# Internal
# =====
# 2T01812126
# Marketing
# =====
# 2T00805043
# Marketing
# =====
# 2HH1409249P4
# Marketing
# =====
# 2HH1409249P24
# Marketing
# =====
# 2HH1409249P24
# Launching tahap 2
# =====
# 2HH1409249P4
# Launching tahap 2
# =====
# 2T00806053
# Marketing
# =====
# 2T01705024
# Marketing
# =====
# 2104148024
# Marketing
# =====
# 2HC0112021
# Marketing
# =====
# 2106023014P1
# Marketing
# =====
# 2HC0113021
# Marketing
# =====
# 2105028180
# Marketing
# =====
# 2T03201001
# Marketing
# =====
# 2101609180
# Marketing
# =====
# 2104241210
# Marketing
# =====
# 2104394210
# Marketing
# =====
# 2102300105
# Marketing
# =====
# 1N01402250P24
# Marketing
# =====
# 1101182250P24
# Marketing
# =====
# 1N00838454
# Marketing
# =====
# 2LH1204172
# Marketing
# =====
# 1N03301456
# Marketing
# =====
# 2LH1204172
# Launching tahap 2
# =====
# 1N00804229
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 1101656318
# Marketing
# =====
# 2304515112
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 1101677318
# Marketing
# =====
# 2LM0801029
# Marketing
# =====
# 2T01403249P4
# Marketing
# =====
# 2T01403249P24
# Marketing
# =====
# 2T02603203
# Marketing
# =====
# 1N01402250P4
# Marketing
# =====
# 1101182250P4
# Marketing
# =====
# 2HG0103050
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 2304051180
# Marketing
# =====
# PL32L33
# Marketing
# =====
# PL30L32
# Marketing
# =====
# PL32L35
# Marketing
# =====
# PL6L32
# Marketing
# =====
# PL7L32
# Marketing
# =====
# 2101684195
# Launching tahap 2
# =====
# 2T01402249P4
# Marketing
# =====
# 2T01402249P24
# Marketing
# =====
# 2T01403249P4
# Marketing
# =====
# 2T01403249P24
# Marketing
# =====
# 2106386249P4
# Marketing
# =====
# 2106386249P24
# Marketing
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0113021P2
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2HF0112021P2
# Marketing
# =====
# 2HF0114021P2
# Marketing
# =====
# 2101699155P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T01813126P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T00806053P2
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00804164P2
# Marketing
# =====
# 2104405
# Marketing
# =====
# 2LM0801029
# Marketing
# =====
# PL6L32
# Marketing
# =====
# PL32L33
# Launching
# =====
# PL7L32
# Marketing
# =====
# PL32L35
# Marketing
# =====
# PL30L32
# Marketing
# =====
# 2T02604203P2
# Launching
# =====
# 2306551173
# Marketing
# =====
# 2LH1204172
# Marketing
# =====
# PT79T86(4)
# Launching
# =====
# 2HF0114021
# Marketing
# =====
# 2HF0114021P2
# Marketing
# =====
# 2T01813126P2
# Marketing
# =====
# 2T01813126
# Marketing
# =====
# LN00000002
# Marketing
# =====
# 2T01404249P4
# Launching
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00804164P2
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 2LG0908060
# Marketing
# =====
# 2T03201001P2
# Marketing
# =====
# 2T01813126
# Marketing
# =====
# 2T00805043
# Marketing
# =====
# 2T00805043P2
# Marketing
# =====
# 2HF0112021
# Marketing
# =====
# 2HF0113021
# Marketing
# =====
# 2HF0114021
# Marketing
# =====
# 2T00805043P2
# Marketing
# =====
# 2T00804024P2
# Launching
# =====
# 2101452195
# Marketing
# =====
# 2101485195
# Marketing
# =====
# 2101651195
# Marketing
# =====
# 2101684195
# Marketing
# =====
# 2101453195
# Marketing
# =====
# 2101486195
# Marketing
# =====
# 2101500195
# Marketing
# =====
# 2101551195
# Marketing
# =====
# 2HC0113021
# Marketing
# =====
# 2T00806053P2
# Internal
# =====
# 2HC0112021
# Marketing
# =====
# 2HH1409249P4
# Marketing
# =====
# 2101751112
# Marketing
# =====
# 2101700166
# Marketing
# =====
# 2HG0103050
# Marketing
# =====
# 2LC0903181
# Marketing
# =====
# 2HH0817441
# Marketing
# =====
# 2HC0112021P2
# Marketing
# =====
# 2HC0113021P2
# Marketing
# =====
# 2101700166P2
# Marketing
# =====
# 2HH1409249P24
# Marketing
# =====
# 2T02604203P2
# Launching tahap 2
# =====
# 2304097159
# Marketing
# =====
# 2T01404249P4
# Launching tahap 2
# =====
# 2T01404249P24
# Launching tahap 2
# =====
# 1N03302456
# Launching
# =====
# 2T02604203
# Launching tahap 2
# =====
# PT79T85
# Launching tahap 2
# =====
# 2304051288
# Launching
# =====
# PN125N150
# Launching
# =====
# 1102560453
# Launching
# =====
# 1N01402250P4
# Launching
# =====
# 1N01402250P24
# Launching
# =====
# PT79G342
# Internal
# =====
# PT79G343
# Internal
# =====
# 2T01705024P2
# Marketing
# =====
# 2T01705024P2
# Marketing
# =====
# 2304051288P2
# Launching
# =====
# 2304051288
# Launching tahap 2
# =====
# 1N00840454
# Launching
# =====
# 1N00840454
# Launching
# =====
# 1N00840454
# Launching
# =====
# 2HF0115003P2
# Launching
# =====
# 1101677104
# Launching
# =====
# 2T01705024
# Marketing
# =====
# 2104115110
# Marketing
# =====
# 2104115110P2
# Marketing
# =====
# 2T00803164
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 2104148024
# Marketing
# =====
# 2104148024P2
# Marketing
# =====
# 2104119110
# Marketing
# =====
# 2104119110P2
# Marketing
# =====
# 2T00804024
# Launching tahap 2
# =====
# 2T02604203
# Internal
# =====
# 2T00805043P2
# Internal
# =====
# 2HC0113021P2
# Marketing
# =====
# 2HC0112021P2
# Marketing
# =====
# 2306551173
# Internal
# =====
# 2LH1204172
# Internal
# =====
# 1NC1710075
# Launching
# =====
# 1NC1711075
# Launching
# =====
# 2LC0903181
# Marketing
# =====
# 2LC0903181P2
# Marketing
# =====
# 2104119110
# Marketing
# =====
# 2104119110P2
# Marketing
# =====
# 2305507288
# Marketing
# =====
# 2305559288
# Marketing
# =====
# 2106395308
# Marketing
# =====
# 2106395308P2
# Marketing
# =====
# 2106395308P3
# Marketing
# =====
# 2102300105
# Marketing
# =====
# 2304008180
# Marketing
# =====
# 2304008180P2
# Marketing
# =====
# 2106023014
# Marketing
# =====
# 2106023014P2
# Marketing
# =====
# 2106023014P3
# Marketing
# =====
# 2T02604203P2
# Internal
# =====
# 2T02604203
# Internal
# =====
# 1N00804229P2
# Marketing
# =====
# 2103300316
# Marketing
# =====
# 2HF0115003
# Launching tahap 2
# =====
# 2304576112
# Marketing
# =====
# 2304576112P2
# Marketing
# =====
# 2304515112C2
# Marketing
# =====
# 2LM0801029
# Marketing
# =====
# 2LM0801029P2
# Marketing
# =====
# PL32L33
# Marketing
# =====
# 2305551028
# Marketing
# =====
# (J)71110157
# Launching
# =====
# (J)71110158
# Launching
# =====
# 1N00841454
# Launching
# =====
# 2LH1204172
# Marketing
# =====
# 2T02604203
# Internal
# =====
# 2T02604203P2
# Internal
# =====
# 2304008180
# Marketing
# =====
# 2304008180P2
# Marketing
# =====
# 2304576112
# Marketing
# =====
# 2304576112P2
# Marketing
# =====
# 2T01705024P2
# Marketing
# =====
# 2104115110
# Marketing
# =====
# 2104115110P2
# Marketing
# =====
# 2T00803164
# Marketing
# =====
# 2T00803164P2
# Marketing
# =====
# 2T00803164P3
# Marketing
# =====
# 2104148024
# Marketing
# =====
# 2104148024P2
# Marketing
# =====
# 2104119110
# Marketing
# =====
# 2104119110P2
# Marketing
# =====
# 2105055180
# Marketing
# =====
# 2105055180P2
# Marketing
# =====
# 2HF0113021
# Marketing
# =====
# 2LH1204172
# Marketing
# =====

# %%
### run 9

import numpy as np

selcen_sku['Product Name'] = selcen_sku['Product Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)
indeks = selcen_sku[selcen_sku['Bundle Name'].isnull()].index.to_list()
selcen_sku['Bundle Name'] = selcen_sku['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)
selcen_sku['Bundle Name'][indeks] = np.nan
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
### run 10

source = pd.read_csv(r"D:\6. settlement\Code\Settlement Project\Backup\Realisasi Jan 2023\Final Result\Raw Unpivoted\CSV\Runningan Blibli L-Men By Selcen Jan 2022 - Jan 2023.csv", sep = ';')

# source['True datetime'] = pd.to_datetime(source['True datetime'])
# source = source[(source['Year'] > 2021) & (source['True datetime']<'2022-02-01')]
source = source[(source['Year'] <2022)]
source['Order #'] = source['No. Order'].astype(str)
# source['Order #'] = source['Order #'].astype(str)

selcen_old = selcen_sku[selcen_sku['No. Order'].isin(source['Order #'])]

source['Product Name'] = source['Product Name'].fillna(source['Real Nama Produk'])

selcen_bundle_null = selcen_old[selcen_old['Bundle Name'].isnull()].index.to_list()
source_bundle_null = source[source['Bundle Name'].isnull()].index.to_list()

selcen_old['Bundle Name'] = selcen_old['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)
source['Bundle Name'] = source['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)

source['Product Name'] = source['Product Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)

dict_change = {'Buy 12 Get 12 ? HiLo School Chocolate RTD 200ml (ED 6 bulan)':'Buy 12 Get 12 – HiLo School Chocolate RTD 200ml (ED 6 bulan)'}

for key in dict_change:
    selcen_old['Bundle Name'] = selcen_old['Bundle Name'].astype(str).str.replace(key, dict_change[key], regex = False)
    source['Bundle Name'] = source['Bundle Name'].astype(str).str.replace(key, dict_change[key], regex = False)
    
import numpy as np

selcen_old['Bundle Name'][selcen_bundle_null] = np.nan
source['Bundle Name'][source_bundle_null] = np.nan


selcen_old_merge = selcen_old.merge(source[['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Price List NFI', 'Qty. Invoiced']].drop_duplicates(['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced']), how = 'left', left_on = ['No. Order', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'], right_on = ['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced']) 

selcen_old_null = selcen_old_merge[selcen_old_merge['Price List NFI_y'].isnull()]

selcen_old_null = selcen_old_null.drop(['Order #', 'Price List NFI_y'], axis = 1)
selcen_old_null = selcen_old_null.rename(columns = {'Price List NFI_x' : 'Price List NFI'})

selcen_old_null = selcen_old_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Price List NFI']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name', 'Price List NFI']), how = 'left', left_on = ['No. Order', 'Product Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(selcen_old_null.index) 
selcen_old_merge['Price List NFI_y'][selcen_old_null.index] = selcen_old_null['Price List NFI_y']

selcen_old_null = selcen_old_merge[selcen_old_merge['Price List NFI_y'].isnull()]

source2 = source.copy()

# source2['Real SKU'] = source2['Real SKU'].astype(str).str.replace('2309005305', '2309005300')

# indeks = source2[source2['Real SKU'] == '(B)2101809250'].index.to_list()
# source2['Real SKU'][indeks] = '(U)2101809250'

# indeks = source2[source2['Real SKU'] == 'PH48(3)B35'].index.to_list()
# source2['Real SKU'][indeks] = '2101941250P4'

# indeks = source2[source2['Real SKU'] == 'PH39(3)B17'].index.to_list()
# source2['Real SKU'][indeks] = '2101809250P4'

selcen_old_null = selcen_old_null.drop(['Order #', 'Price List NFI_y'], axis = 1)
selcen_old_null = selcen_old_null.rename(columns = {'Price List NFI_x' : 'Price List NFI'})

selcen_old_null = selcen_old_null.merge(source2[['Order #', 'Real SKU', 'Bundle Name', 'Price List NFI']].drop_duplicates(['Order #', 'Real SKU', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Real SKU',  'Bundle Name'], right_on = ['Order #', 'Real SKU', 'Bundle Name']).set_index(selcen_old_null.index) 

selcen_old_merge['Price List NFI_y'][selcen_old_null.index] = selcen_old_null['Price List NFI_y']
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# len(selcen_old_merge)
# source

# %%
# selcen_old_merge[selcen_old_merge['Price List NFI_y'].isnull()][['No. Order','Product Name','Real Nama Produk', 'Real SKU','Bundle Name', 'Price List NFI_x', 'Price List NFI_y','Qty. Invoiced']].drop_duplicates('Real SKU')

# %%
### run 11
selcen_old_merge = selcen_old_merge.drop(['Price List NFI_x', 'Order #'], axis = 1)
selcen_old_merge = selcen_old_merge.rename(columns = {'Price List NFI_y' : 'Price List NFI'})

selcen_old_merge['Price List NFI'] = pd.to_numeric(selcen_old_merge['Price List NFI']).astype(float)
selcen_old_merge['Qty. Invoiced'] = pd.to_numeric(selcen_old_merge['Qty. Invoiced']).astype(float)

selcen_old_merge['Total Net'] = selcen_old_merge['Price List NFI'] * selcen_old_merge['Qty. Invoiced']

selcen_sku = selcen_sku[~selcen_sku['No. Order'].isin(selcen_old_merge['No. Order'])]
selcen_sku = selcen_sku.append(selcen_old_merge, ignore_index = True, sort = False)

selcen_sku['Total Net Before PPN'] = selcen_sku['Total Net']/1.11

# %%
### run 12
import os
import pandas as pd

col_ren=pd.read_excel(r"Settlement Project\Blibli NutriMart\rename_col_sett.xlsx")#.to_dict(orient='list')
col_ren.set_index('Kolom baru')['Kolom Lama'].to_dict()

settlement = pd.DataFrame()
for i in os.listdir('Settlement Project\Blibli L-Men\Settlement'):
    if 'xlsx' in i:
        temp = pd.read_excel('Settlement Project\Blibli L-Men\Settlement/' + str(i))
        
        if 'Promo shipping (Shipping promo)' in temp.columns:
            temp=temp.drop(columns=['Promo shipping (Shipping promo)'])
            #,'Seller SKU','Pickup Point Code','Pickup Point Name','Settlement Code'
        if 'Seller SKU' in temp.columns:
            temp=temp.drop(columns=['Seller SKU'])
        if 'Note' in temp.columns:
            temp=temp.drop(columns=['Note'])
        if 'Source' in temp.columns:
            temp=temp.drop(columns=['Source'])
        if 'Pickup Point Code' in temp.columns:
            temp=temp.drop(columns=['Pickup Point Code','Pickup Point Name'])
        if 'Settlement Code' in temp.columns:
            temp=temp.drop(columns=['Settlement Code'])
        if 'Total Margin' in temp.columns:
            temp['Biaya komisi (Commission fee)']=temp['Total Margin']
            temp=temp.drop(columns=['Regular Margin', 'Special Margin', 'Add On Margin', 'Total Margin'])
        # if temp.columns.to_list() == col_ren['Kolom baru'].to_list():
        if len([x for x in temp.columns.to_list() if x not in col_ren['Kolom baru'].to_list()])==0:
            # print('rename')
            temp=temp.rename(columns=col_ren.set_index('Kolom baru')['Kolom Lama'].to_dict())
        temp['Source'] = i
        if 'Description' in temp.columns:
            temp = temp.rename(columns = {'Description' : 'Keterangan',
                                         'Unit Price' : 'Harga Satuan',
                                         'Total Price' : 'Jumlah',
                                          'Merchant Promotion' : 'Promosi Merchant',
                                          'Transaction Fee' : 'Biaya Transaksi',
                                          'Merchant Shipping Fee' : 'Biaya Kirim Seller'
                                         })
        # if 'Nomor pesanan (Order ID)' in temp.columns:
        #     temp=temp.rename(columns={'Nomor pesanan (Order ID)':'Order ID', 'Nomor item pesanan (Order item ID)':'Order Item ID',
        #                               'Nama produk (Product name)':'Product Name', 'Transaksi (Transaction)':'Transaction',
        #                               'Tanggal terkirim (Delivered date)':'Delivered Date', 'Jumlah (Quantity)':'Quantity',
        #                               'Harga satuan (Price per unit)':'Harga satuan','Promo seller (Seller promo)':'Seller Promo',
        #                               'Biaya komisi (Commission fee)':'Commission Fee', 'Promo shipping (Shipping promo)':'Shipping Promo',
        #                               'Promo biaya pembayaran (Payment fee promo)':'Payment Fee Promo',
        #                               'Biaya transaksi (Transaction fee)':'Transaction Fee', 'PPH 23 (WHT 23)':'PPH 23',
        #                               'Biaya pengiriman Seller (Seller shipping fee)':'Merchant Shipping Fee',
        #                               'Total pembayaran (Total payment)':'Total payment', 'Sumber (Source)':'Source'})
        print(i)
        true_col = ['Trx ID', 'Order ID', 'Order Item ID', 'Keterangan', 'Transaction', 'Delivered Date', 'Qty', 'Harga Satuan', 'Jumlah', 'Promosi Merchant', 'Fee', 
                    'Payment Fee Merchant', 'Biaya Transaksi', 'PPH 23', 'Biaya Kirim Seller', 'Total', 'Trx Source', 'Source']
        temp=temp[true_col]
        if temp.columns.to_list() == true_col :
            print('Column sama')
        else:
            print('Column beda')
            print([x for x in true_col if x not in temp.columns.to_list()])
            print([x for x in temp.columns.to_list() if x not in true_col])
            
        if 'Order ID' in settlement.columns:
            temp=temp[~temp['Order Item ID'].isin(settlement['Order Item ID'].unique())]
        settlement = settlement.append(temp, ignore_index = True, sort = False)
settlementcp=settlement.copy()
# Out:
# 20210103_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210104_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210105_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210107_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210109_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210110_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210111_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210112_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210114_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210116_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210117_LMS-60022_SettlementReport (1).xlsx
# Column sama
# 20210118_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210119_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210121_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210123_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210124_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210125_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210126_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210128_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210130_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210131_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210201_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210202_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210204_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210206_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210207_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210208_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210211_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210213_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210214_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210215_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210216_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210218_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210220_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210221_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210222_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210223_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210225_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210227_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210228_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210301_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210302_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210304_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210306_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210307_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210309_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210311_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210313_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210314_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210315_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210316_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210318_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210320_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210321_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210322_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210323_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210325_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210327_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210328_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210329_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210331_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210402_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210403_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210404_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210405_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210406_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210408_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210410_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210411_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210412_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210413_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210415_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210417_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210418_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210419_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210420_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210422_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210424_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210425_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210426_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210427_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210429_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210501_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210502_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210503_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210504_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210506_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210509_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210515_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210516_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210517_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210518_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210520_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210523_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210524_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210525_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210527_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210530_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210531_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210601_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210603_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210605_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210606_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210607_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210608_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210610_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210612_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210613_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210614_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210615_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210617_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210619_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210620_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210621_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210622_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210624_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210626_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210627_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210628_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210629_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210701_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210703_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210704_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210705_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210706_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210708_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210710_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210711_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210712_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210713_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210715_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210718_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210719_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210720_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210722_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210724_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210725_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210726_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210727_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210729_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210731_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210801_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210802_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210803_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210805_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210808_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210809_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210810_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210812_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210815_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210816_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210817_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210819_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210821_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210822_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210823_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210824_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210826_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210828_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210829_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210830_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210831_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210902_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210904_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210905_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210906_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210907_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210909_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210911_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210912_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210913_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210914_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210916_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210918_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210919_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210920_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210921_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210923_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210925_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210926_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210927_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210928_LMS-60022_SettlementReport.xlsx
# Column sama
# 20210930_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211002_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211003_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211004_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211005_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211007_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211009_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211010_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211011_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211012_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211014_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211017_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211018_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211019_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211021_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211023_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211024_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211025_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211026_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211028_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211030_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211031_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211101_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211102_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211104_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211106_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211107_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211108_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211109_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211111_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211113_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211114_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211115_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211116_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211118_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211120_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211121_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211122_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211123_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211125_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211127_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211128_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211129_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211130_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211202_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211204_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211205_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211206_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211207_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211209_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211211_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211212_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211213_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211214_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211216_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211218_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211219_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211220_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211222_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211225_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211226_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211227_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211229_LMS-60022_SettlementReport.xlsx
# Column sama
# 20211231_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220102_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220103_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220104_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220106_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220108_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220109_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220110_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220111_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220113_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220115_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220116_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220117_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220118_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220120_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220122_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220123_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220124_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220125_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220127_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220130_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220131_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220201_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220203_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220205_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220206_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220207_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220208_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220210_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220212_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220213_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220214_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220215_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220217_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220219_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220220_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220221_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220222_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220227_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220301_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220303_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220305_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220306_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220307_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220308_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220310_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220312_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220313_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220314_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220315_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220317_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220319_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220320_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220321_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220322_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220324_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220326_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220327_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220328_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220329_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220331_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220402_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220403_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220404_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220405_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220407_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220409_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220410_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220413_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220416_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220417_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220418_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220419_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220421_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220423_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220424_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220426_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220501_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220508_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220509_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220510_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220512_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220515_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220516_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220517_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220519_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220521_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220522_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220524_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220526_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220528_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220529_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220531_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220602_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220604_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220605_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220606_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220607_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220609_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220611_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220612_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220613_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220614_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220616_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220618_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220619_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220620_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220621_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220623_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220625_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220626_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220627_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220628_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220630_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220702_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220703_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220704_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220705_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220707_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220709_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220710_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220711_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220712_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220714_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220716_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220717_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220718_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220719_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220721_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220723_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220724_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220725_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220726_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220728_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220730_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220731_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220801_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220802_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220804_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220806_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220807_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220808_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220809_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220811_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220813_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220814_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220816_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220818_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220820_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220821_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220822_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220823_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220825_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220827_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220828_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220829_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220830_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220901_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220903_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220904_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220905_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220906_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220908_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220910_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220911_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220912_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220913_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220915_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220917_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220918_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220919_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220920_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220922_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220924_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220925_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220926_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220927_LMS-60022_SettlementReport.xlsx
# Column sama
# 20220929_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221001_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221002_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221003_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221004_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221006_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221008_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221009_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221010_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221011_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221013_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221015_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221016_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221017_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221018_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221020_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221022_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221023_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221024_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221025_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221027_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221029_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221030_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221031_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221101_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221103_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221105_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221106_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221107_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221108_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221110_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221112_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221113_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221116_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221117_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221120_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221121_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221122_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221123_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221124_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221127_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221128_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221129_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221130_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221201_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221204_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221205_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221206_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221207_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221208_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221211_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221212_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221213_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221214_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221215_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221218_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221219_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221220_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221221_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221222_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221225_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221226_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221227_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221228_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221229_LMS-60022_SettlementReport.xlsx
# Column sama
# 20221231_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230103_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230104_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230105_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230108_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230109_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230110_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230111_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230112_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230115_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230116_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230117_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230118_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230119_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230123_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230124_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230125_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230126_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230129_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230130_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230131_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230201_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230202_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230205_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230206_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230207_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230208_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230209_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230212_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230213_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230214_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230215_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230216_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230219_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230220_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230221_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230222_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230223_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230226_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230227_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230228_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230301_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230302_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230305_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230306_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230307_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230308_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230309_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230312_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230313_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230314_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230315_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230316_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230319_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230320_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230323_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230326_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230327_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230328_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230329_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230330_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230402_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230403_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230404_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230405_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230406_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230409_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230410_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230411_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230412_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230413_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230416_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230417_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230425_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230426_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230427_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230501_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230502_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230503_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230504_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230507_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230508_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230509_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230510_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230511_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230514_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230515_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230516_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230518_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230521_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230522_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230523_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230524_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230525_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230528_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230529_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230530_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230604_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230605_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230606_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230607_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230608_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230611_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230612_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230613_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230614_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230615_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230618_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230619_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230620_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230621_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230622_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230625_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230626_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230702_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230703_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230704_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230705_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230706_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230709_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230710_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230711_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230712_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230713_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230716_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230717_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230719_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230720_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230723_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230724_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230725_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230726_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230727_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230730_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230731_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230801_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230802_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230803_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230806_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230807_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230808_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230809_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230810_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230813_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230814_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230815_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230817_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230820_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230821_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230822_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230823_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230824_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230827_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230828_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230829_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230830_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230831_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230903_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230904_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230905_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230906_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230907_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230910_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230911_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230912_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230913_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230914_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230917_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230918_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230919_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230920_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230921_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230924_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230925_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230926_LMS-60022_SettlementReport.xlsx
# Column sama
# 20230928_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231001_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231002_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231003_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231004_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231005_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231008_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231009_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231010_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231011_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231012_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231015_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231016_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231017_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231018_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231019_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231022_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231023_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231024_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231025_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231026_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231029_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231030_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231031_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231101_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231102_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231105_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231106_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231107_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231108_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231109_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231112_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231113_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231114_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231115_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231116_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231119_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231120_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231121_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231122_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231123_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231126_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231127_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231128_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231129_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231130_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231203_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231204_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231205_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231206_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231207_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231210_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231211_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231212_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231213_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231214_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231217_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231218_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231219_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231220_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231221_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231226_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231227_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231228_LMS-60022_SettlementReport.xlsx
# Column sama
# 20231231_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240102_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240103_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240104_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240107_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240108_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240109_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240110_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240111_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240114_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240115_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240116_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240117_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240118_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240121_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240122_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240123_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240124_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240125_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240128_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240129_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240130_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240131_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240201_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240204_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240205_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240206_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240211_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240212_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240214_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240215_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240218_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240220_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240221_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240222_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240225_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240226_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240227_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240228_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240229_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240303_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240304_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240305_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240306_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240312_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240313_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240314_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240317_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240318_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240319_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240320_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240321_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240324_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240325_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240326_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240327_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240331_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240401_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240402_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240403_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240404_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240415_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240416_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240417_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240418_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240421_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240422_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240423_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240424_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240425_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240428_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240429_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240501_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240502_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240505_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240506_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240507_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240512_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240513_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240514_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240515_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240516_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240519_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240520_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240521_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240526_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240527_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240528_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240529_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240530_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240602_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240603_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240604_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240605_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240606_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240609_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240610_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240611_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240612_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240613_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240618_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240619_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240620_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240623_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240624_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240625_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240626_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240627_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240630_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240701_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240702_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240703_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240704_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240707_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240708_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240709_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240710_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240711_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240714_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240715_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240716_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240717_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240718_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240721_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240722_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240723_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240724_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240725_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240728_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240729_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240730_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240731_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240801_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240804_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240805_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240806_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240807_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240808_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240811_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240812_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240813_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240814_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240815_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240818_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240819_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240820_LMS-60022_SettlementReport.xlsx
# Column sama
# 20240821_LMS-60022_SettlementReport.xlsx
# Column sama

# %%
### for backup
settlement=settlementcp.copy()

# %%
## must null
settlement[(settlement[['Order Item ID', 'Transaction']].duplicated(keep = False)) & 
          (settlement['Order Item ID'].notnull())]['Source'].unique()
# Out:
# array([], dtype=object)

# %%
### run 12.1
settlement=settlement[settlement['Trx ID']!='a']
settlement['Order ID']=settlement['Order ID'].astype(str).str.replace('.0', '', regex = False)
settlement['Order Item ID']=settlement['Order Item ID'].astype(str).str.replace('.0', '', regex = False)

# %%
[x for x in temp.columns.to_list() if x not in col_ren['Kolom baru'].to_list()]
# Out:
# ['Trx ID',
#  'Order ID',
#  'Order Item ID',
#  'Keterangan',
#  'Transaction',
#  'Delivered Date',
#  'Qty',
#  'Harga Satuan',
#  'Jumlah',
#  'Promosi Merchant',
#  'Fee',
#  'Payment Fee Merchant',
#  'Biaya Transaksi',
#  'PPH 23',
#  'Biaya Kirim Seller',
#  'Trx Source',
#  'Source']

# %%
# run 12.2
settdetail = pd.DataFrame()
truecol=['Nomor pesanan (Order ID)', 'Nomor item pesanan (Order item ID)',
       'Nama produk (Product name)', 'Jumlah (Quantity)',
       'Harga satuan (Price per unit)', 'Total', 'Promo seller (Seller promo)',
       'Transaksi', 'Tipe (Type)', 'Nilai margin (Margin Amount)',
       'Margin minimal (Minimum Margin)', 'Margin maksimal (Maximum Margin)',
       'Biaya transaksi (Transaction fee)', 'Sumber (Source)',
       'Tipe Seller (seller type)', 'Dikirim oleh (fulfilled by)',
       'Kategori volume berat (Volume weight category)',
       'Tipe pengiriman (delivery type)', 'Tipe pembayaran (payment type)',
       'Tenor', 'Produk Kategori (category product)', 'Margin ID']
for i in os.listdir('Settlement Project\Blibli L-Men\Settlement'):
    if 'xlsx' in i:
        # temp = pd.read_excel('Settlement Project\Blibli L-Men\Settlement/' + str(i),sheet_name='SSR Detail')
        if 'SSR Detail' in pd.ExcelFile('Settlement Project\Blibli L-Men\Settlement/' + str(i)).sheet_names:
            print(i)
            temp = pd.read_excel('Settlement Project\Blibli L-Men\Settlement/' + str(i),sheet_name='SSR Detail',dtype={'Nomor pesanan (Order ID)': str})
            if 'Submission Group' in temp.columns:
                temp=temp.rename(columns={'Submission Group':'Margin ID'})
            if 'Nama Margin (Margin Name)' in temp.columns:
                temp=temp.rename(columns={'Nama Margin (Margin Name)':'Tipe (Type)'})
            colbeda=[i for i in temp.columns if i not in truecol]
            if len(colbeda)>0:
                print(colbeda)
            settdetail = settdetail.append(temp[truecol], ignore_index = True, sort = False)
settdetailcp=settdetail.copy()
# Out:
# 20231203_LMS-60022_SettlementReport.xlsx
# 20231204_LMS-60022_SettlementReport.xlsx
# 20231205_LMS-60022_SettlementReport.xlsx
# 20231206_LMS-60022_SettlementReport.xlsx
# 20231207_LMS-60022_SettlementReport.xlsx
# 20231210_LMS-60022_SettlementReport.xlsx
# 20231211_LMS-60022_SettlementReport.xlsx
# 20231212_LMS-60022_SettlementReport.xlsx
# 20231213_LMS-60022_SettlementReport.xlsx
# 20231214_LMS-60022_SettlementReport.xlsx
# 20231217_LMS-60022_SettlementReport.xlsx
# 20231218_LMS-60022_SettlementReport.xlsx
# 20231219_LMS-60022_SettlementReport.xlsx
# 20231220_LMS-60022_SettlementReport.xlsx
# 20231221_LMS-60022_SettlementReport.xlsx
# 20231226_LMS-60022_SettlementReport.xlsx
# 20231227_LMS-60022_SettlementReport.xlsx
# 20231228_LMS-60022_SettlementReport.xlsx
# 20231231_LMS-60022_SettlementReport.xlsx
# 20240102_LMS-60022_SettlementReport.xlsx
# 20240103_LMS-60022_SettlementReport.xlsx
# 20240104_LMS-60022_SettlementReport.xlsx
# 20240107_LMS-60022_SettlementReport.xlsx
# 20240108_LMS-60022_SettlementReport.xlsx
# 20240109_LMS-60022_SettlementReport.xlsx
# 20240110_LMS-60022_SettlementReport.xlsx
# 20240111_LMS-60022_SettlementReport.xlsx
# 20240114_LMS-60022_SettlementReport.xlsx
# 20240115_LMS-60022_SettlementReport.xlsx
# 20240116_LMS-60022_SettlementReport.xlsx
# 20240117_LMS-60022_SettlementReport.xlsx
# 20240118_LMS-60022_SettlementReport.xlsx
# 20240121_LMS-60022_SettlementReport.xlsx
# 20240122_LMS-60022_SettlementReport.xlsx
# 20240123_LMS-60022_SettlementReport.xlsx
# 20240124_LMS-60022_SettlementReport.xlsx
# 20240125_LMS-60022_SettlementReport.xlsx
# 20240128_LMS-60022_SettlementReport.xlsx
# 20240129_LMS-60022_SettlementReport.xlsx
# 20240130_LMS-60022_SettlementReport.xlsx
# 20240131_LMS-60022_SettlementReport.xlsx
# 20240201_LMS-60022_SettlementReport.xlsx
# 20240204_LMS-60022_SettlementReport.xlsx
# 20240205_LMS-60022_SettlementReport.xlsx
# 20240206_LMS-60022_SettlementReport.xlsx
# 20240211_LMS-60022_SettlementReport.xlsx
# 20240212_LMS-60022_SettlementReport.xlsx
# 20240214_LMS-60022_SettlementReport.xlsx
# 20240215_LMS-60022_SettlementReport.xlsx
# 20240218_LMS-60022_SettlementReport.xlsx
# 20240220_LMS-60022_SettlementReport.xlsx
# 20240221_LMS-60022_SettlementReport.xlsx
# 20240222_LMS-60022_SettlementReport.xlsx
# 20240225_LMS-60022_SettlementReport.xlsx
# 20240226_LMS-60022_SettlementReport.xlsx
# 20240227_LMS-60022_SettlementReport.xlsx
# 20240228_LMS-60022_SettlementReport.xlsx
# 20240229_LMS-60022_SettlementReport.xlsx
# 20240303_LMS-60022_SettlementReport.xlsx
# 20240304_LMS-60022_SettlementReport.xlsx
# 20240305_LMS-60022_SettlementReport.xlsx
# 20240306_LMS-60022_SettlementReport.xlsx
# 20240312_LMS-60022_SettlementReport.xlsx
# 20240313_LMS-60022_SettlementReport.xlsx
# 20240314_LMS-60022_SettlementReport.xlsx
# 20240317_LMS-60022_SettlementReport.xlsx
# 20240318_LMS-60022_SettlementReport.xlsx
# 20240319_LMS-60022_SettlementReport.xlsx
# 20240320_LMS-60022_SettlementReport.xlsx
# 20240321_LMS-60022_SettlementReport.xlsx
# 20240324_LMS-60022_SettlementReport.xlsx
# 20240325_LMS-60022_SettlementReport.xlsx
# 20240326_LMS-60022_SettlementReport.xlsx
# 20240327_LMS-60022_SettlementReport.xlsx
# 20240331_LMS-60022_SettlementReport.xlsx
# 20240401_LMS-60022_SettlementReport.xlsx
# 20240402_LMS-60022_SettlementReport.xlsx
# 20240403_LMS-60022_SettlementReport.xlsx
# 20240404_LMS-60022_SettlementReport.xlsx
# 20240415_LMS-60022_SettlementReport.xlsx
# 20240416_LMS-60022_SettlementReport.xlsx
# 20240417_LMS-60022_SettlementReport.xlsx
# 20240418_LMS-60022_SettlementReport.xlsx
# 20240421_LMS-60022_SettlementReport.xlsx
# 20240422_LMS-60022_SettlementReport.xlsx
# 20240423_LMS-60022_SettlementReport.xlsx
# 20240424_LMS-60022_SettlementReport.xlsx
# 20240425_LMS-60022_SettlementReport.xlsx
# 20240428_LMS-60022_SettlementReport.xlsx
# 20240429_LMS-60022_SettlementReport.xlsx
# 20240501_LMS-60022_SettlementReport.xlsx
# 20240502_LMS-60022_SettlementReport.xlsx
# 20240505_LMS-60022_SettlementReport.xlsx
# 20240506_LMS-60022_SettlementReport.xlsx
# 20240507_LMS-60022_SettlementReport.xlsx
# 20240512_LMS-60022_SettlementReport.xlsx
# 20240513_LMS-60022_SettlementReport.xlsx
# 20240514_LMS-60022_SettlementReport.xlsx
# 20240515_LMS-60022_SettlementReport.xlsx
# 20240516_LMS-60022_SettlementReport.xlsx
# 20240519_LMS-60022_SettlementReport.xlsx
# 20240520_LMS-60022_SettlementReport.xlsx
# 20240521_LMS-60022_SettlementReport.xlsx
# 20240526_LMS-60022_SettlementReport.xlsx
# 20240527_LMS-60022_SettlementReport.xlsx
# 20240528_LMS-60022_SettlementReport.xlsx
# 20240529_LMS-60022_SettlementReport.xlsx
# 20240530_LMS-60022_SettlementReport.xlsx
# 20240602_LMS-60022_SettlementReport.xlsx
# 20240603_LMS-60022_SettlementReport.xlsx
# 20240604_LMS-60022_SettlementReport.xlsx
# 20240605_LMS-60022_SettlementReport.xlsx
# 20240606_LMS-60022_SettlementReport.xlsx
# 20240609_LMS-60022_SettlementReport.xlsx
# 20240610_LMS-60022_SettlementReport.xlsx
# 20240611_LMS-60022_SettlementReport.xlsx
# 20240612_LMS-60022_SettlementReport.xlsx
# 20240613_LMS-60022_SettlementReport.xlsx
# 20240618_LMS-60022_SettlementReport.xlsx
# 20240619_LMS-60022_SettlementReport.xlsx
# 20240620_LMS-60022_SettlementReport.xlsx
# 20240623_LMS-60022_SettlementReport.xlsx
# 20240624_LMS-60022_SettlementReport.xlsx
# 20240625_LMS-60022_SettlementReport.xlsx
# 20240626_LMS-60022_SettlementReport.xlsx
# 20240627_LMS-60022_SettlementReport.xlsx
# 20240630_LMS-60022_SettlementReport.xlsx
# 20240701_LMS-60022_SettlementReport.xlsx
# 20240702_LMS-60022_SettlementReport.xlsx
# 20240703_LMS-60022_SettlementReport.xlsx
# 20240704_LMS-60022_SettlementReport.xlsx
# 20240707_LMS-60022_SettlementReport.xlsx
# 20240708_LMS-60022_SettlementReport.xlsx
# 20240709_LMS-60022_SettlementReport.xlsx
# 20240710_LMS-60022_SettlementReport.xlsx
# 20240711_LMS-60022_SettlementReport.xlsx
# 20240714_LMS-60022_SettlementReport.xlsx
# 20240715_LMS-60022_SettlementReport.xlsx
# 20240716_LMS-60022_SettlementReport.xlsx
# 20240717_LMS-60022_SettlementReport.xlsx
# 20240718_LMS-60022_SettlementReport.xlsx
# 20240721_LMS-60022_SettlementReport.xlsx
# 20240722_LMS-60022_SettlementReport.xlsx
# 20240723_LMS-60022_SettlementReport.xlsx
# 20240724_LMS-60022_SettlementReport.xlsx
# 20240725_LMS-60022_SettlementReport.xlsx
# 20240728_LMS-60022_SettlementReport.xlsx
# 20240729_LMS-60022_SettlementReport.xlsx
# 20240730_LMS-60022_SettlementReport.xlsx
# 20240731_LMS-60022_SettlementReport.xlsx
# 20240801_LMS-60022_SettlementReport.xlsx
# 20240804_LMS-60022_SettlementReport.xlsx
# 20240805_LMS-60022_SettlementReport.xlsx
# 20240806_LMS-60022_SettlementReport.xlsx
# 20240807_LMS-60022_SettlementReport.xlsx
# 20240808_LMS-60022_SettlementReport.xlsx
# 20240811_LMS-60022_SettlementReport.xlsx
# 20240812_LMS-60022_SettlementReport.xlsx
# 20240813_LMS-60022_SettlementReport.xlsx
# 20240814_LMS-60022_SettlementReport.xlsx
# 20240815_LMS-60022_SettlementReport.xlsx
# 20240818_LMS-60022_SettlementReport.xlsx
# 20240819_LMS-60022_SettlementReport.xlsx
# 20240820_LMS-60022_SettlementReport.xlsx
# 20240821_LMS-60022_SettlementReport.xlsx

# %%
# settdetailcp[settdetailcp['Dikirim oleh (fulfilled by)']=='FBB']
# settlement
settdetail=settdetailcp.copy()
# if settdetail['Order Item ID'].dtype=='float64':
#     settdetail['Order Item ID']=settdetail['Order Item ID'].astype(int).astype(str)

# %%
## run 12.3
settdetail=settdetail[settdetail['Dikirim oleh (fulfilled by)']=='FBB'].groupby(["Nomor pesanan (Order ID)",
                                                                                 'Nomor item pesanan (Order item ID)'])[['Nilai margin (Margin Amount)']].sum().reset_index().rename(columns = {'Nomor pesanan (Order ID)' : 'Order ID','Nomor item pesanan (Order item ID)' : 'Order Item ID'})


if settdetail['Order Item ID'].dtype=='float64':
    settdetail['Order Item ID']=settdetail['Order Item ID'].astype(int).astype(str)
    
    
settlementmod=settlement.merge(settdetail,how='left',on=['Order ID','Order Item ID'])
settlementmod['Nilai margin (Margin Amount)']=settlementmod['Nilai margin (Margin Amount)'].fillna(0)
if len(settlementmod)==len(settlement):
    print('merge berhasil')
settlementmod['New Fee']=settlementmod['Fee']-settlementmod['Nilai margin (Margin Amount)']
# Out:
# merge berhasil

# %%
# run 12.35
if 'Old Fee' not in settlementmod.columns:
    print('replace done')
    settlementmod['Old Fee']=settlementmod['Fee']
    settlementmod['Fee']=settlementmod['New Fee']
    settlementmod['Fullfee']=settlementmod['Nilai margin (Margin Amount)']
# Out:
# replace done

# %%
# run 12.4
settlement=settlementmod.copy()

# %%
#### run 13
blibli_merge = selcen_sku.copy()

# %%
#### run 14
sales = settlement[settlement['Transaction'] == 'Sales']
cancel = settlement[settlement['Transaction'] == 'Cancel Sales']
other = settlement[settlement['Transaction'] == 'Other Adjustments']

cancel['Jumlah Cancel'] = cancel['Jumlah'].abs() * -1
cancel['Fee Cancel'] = cancel['Fee'].abs() * -1
other['Others'] = other['Total']
other['Other Adjustment'] = 'Yes'

sales = sales.merge(cancel[['Order ID', 'Order Item ID', 'Jumlah Cancel', 'Fee Cancel']], how = 'left', on = ['Order ID', 'Order Item ID']).merge(other[['Order ID', 'Order Item ID', 'Others', 'Other Adjustment']], how = 'left', on = ['Order ID', 'Order Item ID'])

settlement = sales.copy()
settlement['Jumlah'] = settlement['Jumlah'] - settlement['Jumlah Cancel'].fillna(0)
settlement['Fee'] = settlement['Fee'] - settlement['Fee Cancel'].fillna(0)

# settlement['Cek'] = settlement['Jumlah'] + settlement['Promosi Merchant'] - settlement['Fee'] - settlement['Payment Fee Merchant'] - settlement['Biaya Transaksi'] + settlement['PPH 23'] - settlement['Biaya Kirim Seller']
settlement['Cek'] = settlement['Jumlah'] + settlement['Promosi Merchant'] - settlement['Fee'] - settlement['Payment Fee Merchant'] - settlement['Biaya Transaksi'] + settlement['PPH 23'] - settlement['Biaya Kirim Seller']- settlement['Fullfee'] # feb 2024

settlement['Selisih'] = settlement['Cek'] - settlement['Total']
settlement['Bi Produk'] = settlement['Jumlah'] + settlement['Promosi Merchant']
settlement['Comfee'] = settlement['Fee']
# settlement['Others'] = settlement['Payment Fee Merchant'] + settlement['Biaya Transaksi'] + settlement['Biaya Kirim Seller'] + settlement['Others'].fillna(0)
settlement['Others'] = settlement['Biaya Kirim Seller']+settlement['Others'].fillna(0) ## di akhir other jadi shipping Fee Feb 2024
settlement['Payment Fee']= settlement['Payment Fee Merchant'] + settlement['Biaya Transaksi']
settlement['Fullfee']=settlement['Fullfee'].astype(int)


indeks = settlement[settlement['Selisih'] > 0].index.to_list()
settlement['Bi Produk'][indeks] = 0
settlement['Comfee'][indeks] = 0

settlement['Order ID'] = settlement['Order ID'].astype(str).str.replace('.0', '', regex = False)
settlement['Order Item ID'] = settlement['Order Item ID'].astype(str).str.replace('.0', '', regex = False)

settlement = settlement[settlement['Order ID'] != 'nan']
# set_pivot = pd.pivot_table(settlement, values = ['Bi Produk', 'Comfee', 'Others'], index = ['Order ID', 'Order Item ID', 'Keterangan'],  aggfunc=np.sum).reset_index()
set_pivot = settlement.groupby(['Order ID', 'Order Item ID', 'Keterangan']).agg({'Bi Produk':'sum', 'Comfee':'sum','Payment Fee':'sum', 'Others':'sum','Fullfee':'sum'}).reset_index()

set_pivot['Order ID'] = set_pivot['Order ID'].astype(str)
set_pivot['Order Item ID'] = set_pivot['Order Item ID'].astype(str)
blibli_merge['No. Order'] = blibli_merge['No. Order'].astype(str)
blibli_merge['No. Order Item'] = blibli_merge['No. Order Item'].astype(str)

no_prop = blibli_merge[blibli_merge['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])]
blibli_prop = blibli_merge[~blibli_merge['Brand'].isin(['Bonus Produk', 'Gimmick', 'Partnership'])]

bundle_wms = blibli_prop[blibli_prop['Bundle Name'].notnull()]
blibli_set = blibli_prop[blibli_prop['Bundle Name'].isnull()]

duplicated = set_pivot[set_pivot[['Order ID', 'Keterangan']].duplicated(keep = False)]
not_duplicate = set_pivot[~set_pivot[['Order ID', 'Keterangan']].duplicated(keep = False)]

duplicated['Bi Produk'] = duplicated.groupby(['Order ID', 'Keterangan'])['Bi Produk'].transform('sum')
duplicated['Comfee'] = duplicated.groupby(['Order ID', 'Keterangan'])['Comfee'].transform('sum')

set_pivot = not_duplicate.append(duplicated, ignore_index = True, sort = False)

set_pivot = set_pivot.drop('Keterangan', axis = 1)

blibli_set = blibli_set.merge(set_pivot.drop_duplicates(['Order ID', 'Order Item ID']), how = 'left', left_on = ['No. Order', 'No. Order Item'], right_on = ['Order ID', 'Order Item ID'])
blibli_set['Bi Produk'] = blibli_set['Bi Produk'].fillna(0) * blibli_set['Total Net Before PPN']/blibli_set.groupby(['No. Order', 'Product Name'])['Total Net Before PPN'].transform('sum')
blibli_set['Comfee'] = blibli_set['Comfee'].fillna(0) * blibli_set['Total Net Before PPN']/blibli_set.groupby(['No. Order', 'Product Name'])['Total Net Before PPN'].transform('sum')
blibli_set['Others'] = blibli_set['Others'].fillna(0) * blibli_set['Total Net Before PPN']/blibli_set.groupby(['No. Order', 'Product Name'])['Total Net Before PPN'].transform('sum')
blibli_set['Payment Fee'] = blibli_set['Payment Fee'].fillna(0) * blibli_set['Total Net Before PPN']/blibli_set.groupby(['No. Order', 'Product Name'])['Total Net Before PPN'].transform('sum')##Feb 2024 
blibli_set['Fullfee'] = blibli_set['Fullfee'].fillna(0) * blibli_set['Total Net Before PPN']/blibli_set.groupby(['No. Order', 'Product Name'])['Total Net Before PPN'].transform('sum')##Feb 2024


bundle_set = bundle_wms.merge(blibli_set.groupby(['No. Order', 'Product Name'])[['Bi Produk', 'Comfee', 'Others','Payment Fee','Fullfee']].sum().reset_index(), how = 'left', left_on = ['No. Order', 'Bundle Name'], right_on = ['No. Order', 'Product Name'])
bundle_set = bundle_set.rename(columns = {'Product Name_x' : 'Product Name'})
bundle_set = bundle_set.drop('Product Name_y', axis = 1)

bundle_set['Bi Produk'] = bundle_set['Bi Produk'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['No. Order', 'Bundle Name'])['Total Net Before PPN'].transform('sum')
bundle_set['Comfee'] = bundle_set['Comfee'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['No. Order', 'Bundle Name'])['Total Net Before PPN'].transform('sum')
bundle_set['Others'] = bundle_set['Others'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['No. Order', 'Bundle Name'])['Total Net Before PPN'].transform('sum')
bundle_set['Payment Fee'] = bundle_set['Payment Fee'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['No. Order', 'Product Name'])['Total Net Before PPN'].transform('sum')##Feb 2024 
bundle_set['Fullfee'] = bundle_set['Fullfee'].fillna(0) * bundle_set['Total Net Before PPN']/bundle_set.groupby(['No. Order', 'Product Name'])['Total Net Before PPN'].transform('sum')##Feb 2024


blibli_set = blibli_set.append(bundle_set, ignore_index = True, sort = False)
blibli_set = blibli_set.append(no_prop, ignore_index = True, sort = False)
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# blibli_set[(blibli_set['Bi Produk'].isnull())
#             & (blibli_set['Bundle Name'].isnull()) &
#             (blibli_set['No. Order'].isin(settlement['Order ID']))].groupby(['Real Nama Produk', 'Real SKU', 'Bundle Name', 'Qty. Invoiced'], dropna = False)['No. Order'].first().reset_index()

# %%
### run 15

cancel['Order Item ID'] = cancel['Order Item ID'].astype(str).str.replace('.0', '', regex = False)
other['Order Item ID'] = other['Order Item ID'].astype(str).str.replace('.0', '', regex = False)

bli_payment = blibli_set[blibli_set['Bundle Name'].isnull()]
bundle_payment = blibli_set[blibli_set['Bundle Name'].notnull()]

bli_payment['Paid'] = np.nan
indeks = bli_payment[bli_payment['Order Item ID'].isin(settlement['Order Item ID'])].index.to_list()
bli_payment['Paid'][indeks] = 'Paid'
bli_payment['Paid'] = bli_payment['Paid'].fillna('Unpaid')

indeks = bli_payment[(bli_payment['Order Item ID'].isin(cancel['Order Item ID'])) & 
                    (bli_payment['Bi Produk'] > 0)].index.to_list()
bli_payment['Paid'][indeks] = 'Half Paid'

indeks = bli_payment[(bli_payment['Order Item ID'].isin(cancel['Order Item ID'])) & 
                    (bli_payment['Bi Produk'] == 0) & (bli_payment['Paid'] == 'Unpaid')].index.to_list()
bli_payment['Paid'][indeks] = 'Cancel'

indeks = bli_payment[(bli_payment['Order Item ID'].isin(other['Order Item ID'])) & 
                    (bli_payment['Bi Produk'] > 0)].index.to_list()
bli_payment['Paid'][indeks] = 'Half Paid'

indeks = bli_payment[(bli_payment['Order Status'] == 'Order Batal')  & (bli_payment['Paid'] == 'Unpaid')].index.to_list()
bli_payment['Paid'][indeks] = 'Cancel'

# indeks = bli_payment[(bli_payment['Order Status'] == 'Pengiriman Gagal') & 
#                     (bli_payment['Bi Produk'] > 0) ].index.to_list()
# bli_payment['Paid'][indeks] = 'Half Paid'

indeks = bli_payment[(bli_payment['Order Status'] == 'Pengiriman Gagal') & 
                    (bli_payment['Bi Produk'] == 0) & (bli_payment['Paid'] == 'Unpaid')].index.to_list()
bli_payment['Paid'][indeks] = 'Cancel'

bundle_payment = bundle_payment.merge(bli_payment.groupby(['No. Order', 'Product Name'])[['Paid']].first().reset_index(), how = 'left', left_on = ['No. Order', 'Bundle Name'], right_on = ['No. Order', 'Product Name'])
bundle_payment = bundle_payment.rename(columns = {'Product Name_x' : 'Product Name'})
bundle_payment = bundle_payment.drop('Product Name_y', axis = 1)

bli_payment = bli_payment.append(bundle_payment, ignore_index = True, sort = False)

bli_payment_gimmick = bli_payment[bli_payment['Brand'].isin(['Gimmick', 'Bonus Produk'])]
paid = bli_payment[bli_payment['Paid'] == 'Paid']['No. Order'].unique()

indeks = bli_payment_gimmick[bli_payment_gimmick['No. Order'].isin(paid)].index.to_list()
bli_payment['Paid'][indeks] = 'Paid'
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py:1135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_values(indexer, value)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == "":
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
### run 16

# bli_payment['Bi Produk Adj'] = bli_payment['Bi Produk']/1.11
# bli_payment['BTL Cost'] = bli_payment['Bi Produk Adj'] - bli_payment['Total Net Before PPN']
bli_payment['Bi Produk Adj'] = bli_payment['Bi Produk']/1.11
bli_payment['BTL Cost'] = bli_payment['Bi Produk Adj'] - bli_payment['Total Net Before PPN']
bli_payment['Comfee'] = bli_payment['Comfee'] * (-1)

# %%
### run 17
tambah_unpaid = pd.read_excel(r'Settlement Project/unpaid order to Andra.xlsx', sheet_name = 'Unpaid to cancel or not found')
tambah_unpaid2 = pd.read_excel(r'Settlement Project/Unpaid Mar.xlsx', sheet_name = 'Blibli L-Men')

tambah_unpaid = tambah_unpaid.append(tambah_unpaid2, ignore_index = True, sort = False)
tambah_unpaid['No. Order'] = tambah_unpaid['Order #'].astype(str)
indeks = bli_payment[bli_payment['No. Order'].isin(tambah_unpaid['Order #'])].index.to_list()
print(len(indeks))
bli_payment['Order Status'][indeks] = 'Cancel'
bli_payment['Paid'][indeks] = 'Cancel'

rumus_status = pd.read_excel(r'Settlement Project/Rumus Status.xlsx', sheet_name = 'Blibli L-Men')
if len(rumus_status != 0):
    for i in range(len(rumus_status)):
        stat = rumus_status['Order Status'][i]
        indeks = bli_payment[(bli_payment['Paid'] == 'Unpaid') &
                             (bli_payment['Order Status'].str.lower() == stat.lower())].index.to_list()
        bli_payment['Order Status'][indeks] = 'Cancel'
        bli_payment['Paid'][indeks] = 'Cancel'
# Out:
# 0
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
### run 18

total_trx_full = bli_payment.rename(columns = {
    'No. Order Item' : 'Product ID',
    'Total Bayar' : 'Total Selcen',
    'Status Seller Centre' : 'Order Status_y',
    'Toko/Gudang' : 'Warehouse Origin',
    'Bi Produk' : 'Total Produk Prop',
    'Comfee' : 'Comfee Prop',
    'Tanggal Order' : 'Order Date Seller Centre',
    'Bi Produk Adj' : 'Bi Bahan Produk Final Adj', 
    'Outbound Qty' : 'Warehouse Quantity'
})

total_trx_full['WH'] = total_trx_full['Warehouse Origin']
total_trx_full['SO STATUS'] = total_trx_full['Order Status']

total_trx_full = total_trx_full.rename(columns = {
    'Total Selcen' : 'Total Seller Centre', 
    'Order Status_y' : 'Order Status Seller Centre',
    'SO STATUS' : 'Status Gudang',
    'Shipment Fee' : 'Shipping Fee', 
    'Bi Bahan Produk Final Adj' : 'Total Produk Prop Adj'
})

# %%
for i in bli_payment.columns:#['Shipping Fee']
    print(i)
# Out:
# No. Order
# No. Order Item
# No. Awb
# Tanggal Order
# Nama Pemesan
# Kode SKU
# Blibli SKU
# SKU
# Product Name
# Qty. Invoiced
# Harga Produk
# Servis Logistik
# Kode Merchant
# Nama Store
# Order Status
# Toko/Gudang
# Source
# Unnamed: 0
# Alamat pengambilan
# Alamat
# Kota
# Provinsi
# Harga item pesanan
# Total harga item pesanan
# Total
# Diskon
# Nama diskon
# Kode diskon
# Voucher seller
# Nama voucher seller
# Kode voucher seller
# Nama voucher gratis ongkir
# Kode voucher gratis ongkir
# Catatan produk
# Tanggal pengiriman
# Date
# Month
# Year
# true datetime
# Pemilik Budget
# Real SKU
# Real Nama Produk
# Brand
# Sub Brand
# Produk 1
# SKU Produk 1
# PCS Produk 1
# Price List NFI 1
# Subtotal Produk 1
# Harga Display 1
# Harga Cost 1
# Harga Organik 1
# Produk 2
# SKU Produk 2
# PCS Produk 2
# Price List NFI 2
# Subtotal Produk 2
# Harga Display 2
# Harga Cost 2
# Harga Organik 2
# Produk 3
# SKU Produk 3
# PCS Produk 3
# Price List NFI 3
# Subtotal Produk 3
# Harga Display 3
# Harga Cost 3
# Harga Organik 3
# Produk 4
# SKU Produk 4
# PCS Produk 4
# Price List NFI 4
# Subtotal Produk 4
# Harga Display 4
# Harga Cost 4
# Harga Organik 4
# Produk 5
# SKU Produk 5
# PCS Produk 5
# Price List NFI 5
# Subtotal Produk 5
# Harga Display 5
# Harga Cost 5
# Harga Organik 5
# Produk 6
# SKU Produk 6
# PCS Produk 6
# Price List NFI 6
# Subtotal Produk 6
# Harga Display 6
# Harga Cost 6
# Harga Organik 6
# Produk 7
# SKU Produk 7
# PCS Produk 7
# Price List NFI 7
# Subtotal Produk 7
# Harga Display 7
# Harga Cost 7
# Harga Organik 7
# Bundle Name
# Price List NFI
# Total Net
# Bundle Flag
# Parent Item
# Parent SKU
# Harga Cost
# Total Harga Cost
# Total Net Before PPN
# Order ID
# Order Item ID
# Bi Produk
# Comfee
# Payment Fee
# Others
# Fullfee
# Paid
# Bi Produk Adj
# BTL Cost

# %%
### run 19

total_trx_full['Duplicated'] = np.nan

dups_order = settlement[(settlement[['Order ID', 'Order Item ID', 'Keterangan', 'Transaction']].duplicated(keep = False)) & 
          (settlement['Order Item ID'].notnull()) & 
          (settlement['Order Item ID'] != 'nan')]['Order ID'].unique()
indeks = total_trx_full[total_trx_full['No. Order'].isin(dups_order)].index.to_list()
total_trx_full['Duplicated'][indeks] = 'Duplicated Order'
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":

# %%
### run 20

source['Order #'] = source['Order #'].astype(str)

total_trx_full['Bundle Name'] = total_trx_full['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)
source['Bundle Name'] = source['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)


# dict_change = {'Buy 12 Get 12 ? HiLo School Chocolate RTD 200ml (ED 6 bulan)':'Buy 12 Get 12 – HiLo School Chocolate RTD 200ml (ED 6 bulan)'}

# for key in dict_change:
#     total_trx_full['Bundle Name'] = total_trx_full['Bundle Name'].astype(str).str.replace(key, dict_change[key], regex = False)
#     source['Bundle Name'] = source['Bundle Name'].astype(str).str.replace(key, dict_change[key], regex = False)
    
               
total_trx_merge = total_trx_full.merge(source[['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced']), how = 'left', left_on = ['No. Order', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'], right_on = ['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'])

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

total_trx_null = total_trx_null.drop(['Order #', 'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net', 
                                                  'Total Produk Prop_x' : 'Total Produk Prop',
                                                  'Comfee Prop_x' : 'Comfee Prop'})

total_trx_null = total_trx_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Product Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(total_trx_null.index) 
total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

total_trx_null = total_trx_null.drop(['Order #', 'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net',
                                                  'Total Produk Prop_x' : 'Total Produk Prop',
                                                  'Comfee Prop_x' : 'Comfee Prop'})

total_trx_null = total_trx_null.merge(source[['Order #', 'Real SKU', 'Bundle Name', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Real SKU', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Real SKU',  'Bundle Name'], right_on = ['Order #', 'Real SKU', 'Bundle Name']).set_index(total_trx_null.index) 
total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

# source2 = source.copy()

# source2['Real SKU'] = source2['Real SKU'].astype(str).str.replace('2309005305', '2309005300')

# # indeks = source2[source2['Real SKU'] == '(B)2101809250'].index.to_list()
# # source2['Real SKU'][indeks] = '(U)2101809250'

# # indeks = source2[source2['Real SKU'] == 'PH48(3)B35'].index.to_list()
# # source2['Real SKU'][indeks] = '2101941250P4'

# # indeks = source2[source2['Real SKU'] == 'PH39(3)B17'].index.to_list()
# # source2['Real SKU'][indeks] = '2101809250P4'

# total_trx_null = total_trx_null.drop(['Order #', 'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
# total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net', 
#                                                   'Total Produk Prop_x' : 'Total Produk Prop',
#                                                   'Comfee Prop_x' : 'Comfee Prop'})

# total_trx_null = total_trx_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Product Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(total_trx_null.index) 
# total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
# total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
# total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# total_trx_null[total_trx_null['No. Order'].isin(source['Order #'])][['No. Order', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Paid', 'Total Net_x', 'Total Net_y']].drop_duplicates(['Real SKU', 'Real Nama Produk', 'Bundle Name'])

# %%
### run 21
total_trx_merge = total_trx_merge.rename(columns = {'Total Produk Prop_x' : 'Total Produk Prop by Selcen', 
                                                   'Total Produk Prop_y' : 'Total Produk Prop Real Jan',
                                                   'Total Net_x' : 'Total Net by Selcen', 
                                                   'Total Net_y' : 'Total Net Real Jan',
                                                   'Fullfee Prop_x' : 'Fullfee Prop by Selcen', 
                                                   'Fullfee Prop_y' : 'Fullfee Prop Real Jan',
                                                   'Comfee Prop_x' : 'Comfee Prop by Selcen', 
                                                   'Comfee Prop_y' : 'Comfee Prop Real Jan'})

total_trx_merge['Delta Total Net'] = total_trx_merge['Total Net by Selcen'] - total_trx_merge['Total Net Real Jan']
total_trx_merge['Delta Total Produk Prop'] = total_trx_merge['Total Produk Prop by Selcen'] - total_trx_merge['Total Produk Prop Real Jan']
total_trx_merge['Delta Comfee Prop'] = total_trx_merge['Comfee Prop by Selcen'] - total_trx_merge['Comfee Prop Real Jan']

# %%
[x for x in total_trx_merge.columns if "Fee" in x]
# for i in total_trx_merge.columns:
#     print(i)
# total_trx_full[['Shipping Fee']]
# Out:
# ['Payment Fee']

# %%
### run 22 ganti nama folder
from datetime import date
total_trx_merge.to_csv(fr'Settlement Project\Backup\Realisasi Aug 2024\Final Result\Before Compare/L-Men Store Testing by Selcen Compare v2 {date.today()}.csv', sep = ';', index = False)

# %% [markdown]
# ## ====================A===================

# %%
total_trx_merge[total_trx_merge['No. Order'] == '12088982330'][['No. Order', 'Product Name','Real SKU', 'Real Nama Produk', 'Bundle Name', 'Paid', 'Total Produk Prop by Selcen', 'Total Produk Prop Real Jan', 'Delta Total Produk Prop']]
# Out:
#         No. Order                                       Product Name  \
# 6289  12088982330  Paket Selai: Tropicana Slim Chocolate Spread 3...
# 9053  12088982330               Tropicana Slim Chocolate Spread 300g
# 9141  12088982330                Tropicana Slim Strawberry Jam 375gr
#
#         Real SKU                                   Real Nama Produk  \
# 6289     PT25T41  Tropicana Slim Chocolate Spread 300gr + Tropic...
# 9053  2104251230               Tropicana Slim Chocolate Spread 300g
# 9141  2104228230                Tropicana Slim Strawberry Jam 375gr
#
#                                             Bundle Name  Paid  \
# 6289                                                nan  Paid
# 9053  Paket Selai: Tropicana Slim Chocolate Spread 3...  Paid
# 9141  Paket Selai: Tropicana Slim Chocolate Spread 3...  Paid
#
#       Total Produk Prop by Selcen  Total Produk Prop Real Jan  \
# 6289                     127800.0               127800.000000
# 9053                     127800.0                67422.047244
# 9141                     127800.0                60377.952756
#
#       Delta Total Produk Prop
# 6289                 0.000000
# 9053             60377.952756
# 9141             67422.047244

# %%
source[source['Order #'] == '12085866563'][['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced', 'Total Net']]
# Out:
#            Order #    Real SKU               Real Nama Produk Bundle Name  \
# 46171  12085866563  2101453195  HiLo School Chocolate 1000 gr         nan
#
#        Qty. Invoiced  Total Net
# 46171            1.0   136400.0

# %%
import pandas as pd
import numpy as np
import os

total_trx = pd.read_csv(r"D:\settlement\Code\Settlement Project\Backup\New folder\backup blibli nut\L-Men Store Testing by Selcen Compare v2 2022-05-09.csv", sep = ';')

total_trx_full = total_trx.rename(columns = {'Total Produk Prop by Selcen': 'Total Produk Prop', 
                                                   'Total Net by Selcen' : 'Total Net', 
                                                   'Fullfee Prop by Selcen' : 'Fullfee Prop', 
                                                   'Comfee Prop by Selcen' : 'Comfee Prop'})


total_trx_full = total_trx_full.drop(['Order #', 'Total Net Real Jan', 'Total Produk Prop Real Jan',
       'Comfee Prop Real Jan', 'Delta Total Net', 'Delta Total Produk Prop',
       'Delta Comfee Prop'], axis = 1)

source = pd.read_csv(r"D:\Downloads\Sett unused\Running Blibli L-Men By Selcen Jan 2022 - Mar 2022.csv", sep = ';')

# source['True datetime'] = pd.to_datetime(source['True datetime'])
source = source[(source['Year'] > 2021)]

# selcen_sku['OrderId'] = selcen_sku['OrderId'].astype(str)
source['Order #'] = source['No. Order']#.astype(str)
source['Order #'] = source['Order #'].astype(str)
source['Real SKU'] = source['Real SKU'].astype(str)
total_trx_full['No. Order'] = total_trx_full['No. Order'].astype(str)

# selcen_old = selcen_sku[selcen_sku['OrderId'].isin(source['Order #'])]

source['Product Name'] = source['Product Name'].fillna(source['Real Nama Produk'])

source['Order #'] = source['Order #'].astype(str)

total_trx_full['Bundle Name'] = total_trx_full['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)
source['Bundle Name'] = source['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)


dict_change = {'Buy 12 Get 12 ? HiLo School Chocolate RTD 200ml (ED 6 bulan)':'Buy 12 Get 12 – HiLo School Chocolate RTD 200ml (ED 6 bulan)'}

for key in dict_change:
    total_trx_full['Bundle Name'] = total_trx_full['Bundle Name'].astype(str).str.replace(key, dict_change[key], regex = False)
    source['Bundle Name'] = source['Bundle Name'].astype(str).str.replace(key, dict_change[key], regex = False)
    
               
total_trx_merge = total_trx_full.merge(source[['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Paid February','Qty. Invoiced', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced']), how = 'left', left_on = ['No. Order', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'], right_on = ['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'])

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

total_trx_null = total_trx_null.drop(['Order #', 'Paid February','Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net', 
                                                  'Total Produk Prop_x' : 'Total Produk Prop',
                                                  'Comfee Prop_x' : 'Comfee Prop'})

total_trx_null = total_trx_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Paid February','Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Product Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(total_trx_null.index) 
total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
total_trx_merge['Paid February'][total_trx_null.index] = total_trx_null['Paid February']

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

total_trx_null = total_trx_null.drop(['Order #', 'Paid February','Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net',
                                                  'Total Produk Prop_x' : 'Total Produk Prop',
                                                  'Comfee Prop_x' : 'Comfee Prop'})

total_trx_null = total_trx_null.merge(source[['Order #', 'Real SKU', 'Bundle Name', 'Paid February','Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Real SKU', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Real SKU',  'Bundle Name'], right_on = ['Order #', 'Real SKU', 'Bundle Name']).set_index(total_trx_null.index) 
total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
total_trx_merge['Paid February'][total_trx_null.index] = total_trx_null['Paid February']

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

# source2 = source.copy()

# source2['Real SKU'] = source2['Real SKU'].astype(str).str.replace('2309005305', '2309005300')

# # indeks = source2[source2['Real SKU'] == '(B)2101809250'].index.to_list()
# # source2['Real SKU'][indeks] = '(U)2101809250'

# # indeks = source2[source2['Real SKU'] == 'PH48(3)B35'].index.to_list()
# # source2['Real SKU'][indeks] = '2101941250P4'

# # indeks = source2[source2['Real SKU'] == 'PH39(3)B17'].index.to_list()
# # source2['Real SKU'][indeks] = '2101809250P4'

# total_trx_null = total_trx_null.drop(['Order #', 'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
# total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net', 
#                                                   'Total Produk Prop_x' : 'Total Produk Prop',
#                                                   'Comfee Prop_x' : 'Comfee Prop'})

# total_trx_null = total_trx_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Product Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(total_trx_null.index) 
# total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
# total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
# total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
total_trx_null[total_trx_null['No. Order'].isin(source['Order #'])][['No. Order', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Paid', 'Total Net_x', 'Total Net_y']].drop_duplicates(['Real SKU', 'Real Nama Produk', 'Bundle Name'])
# Out:
# Empty DataFrame
# Columns: [No. Order, Real SKU, Real Nama Produk, Bundle Name, Paid, Total Net_x, Total Net_y]
# Index: []

# %%
total_trx_merge = total_trx_merge.rename(columns = {'Total Produk Prop_x' : 'Total Produk Prop by Selcen', 
                                                   'Total Produk Prop_y' : 'Total Produk Prop Real Jan',
                                                   'Total Net_x' : 'Total Net by Selcen', 
                                                   'Total Net_y' : 'Total Net Real Jan',
                                                   'Fullfee Prop_x' : 'Fullfee Prop by Selcen', 
                                                   'Fullfee Prop_y' : 'Fullfee Prop Real Jan',
                                                   'Comfee Prop_x' : 'Comfee Prop by Selcen', 
                                                   'Comfee Prop_y' : 'Comfee Prop Real Jan'})

total_trx_merge['Delta Total Net'] = total_trx_merge['Total Net by Selcen'] - total_trx_merge['Total Net Real Jan']
total_trx_merge['Delta Total Produk Prop'] = total_trx_merge['Total Produk Prop by Selcen'] - total_trx_merge['Total Produk Prop Real Jan']
total_trx_merge['Delta Comfee Prop'] = total_trx_merge['Comfee Prop by Selcen'] - total_trx_merge['Comfee Prop Real Jan']

# %%
total_trx_merge.to_csv(r'D:\Backup\Backup 26 Mei\Settlement Project Backup/L-Men Store Testing by Selcen Compare vPaid.csv', sep = ';', index = False)

# %% [markdown]
# ## ======================A=====================

# %%
### run 23
import pandas as pd
import numpy as np
import os

# total_trx = pd.read_csv(r"D:\6. settlement\Code\Settlement Project\Backup\Realisasi Apr 2023\Final Result\Before Compare\L-Men Store Testing by Selcen Compare v2 2023-04-24.csv", sep = ';')
total_trx=total_trx_merge.copy()
total_trx_full = total_trx.rename(columns = {'Total Produk Prop by Selcen': 'Total Produk Prop', 
                                                   'Total Net by Selcen' : 'Total Net', 
                                                   'Fullfee Prop by Selcen' : 'Fullfee Prop', 
                                                   'Comfee Prop by Selcen' : 'Comfee Prop'})


total_trx_full = total_trx_full.drop(['Order #', 'Total Net Real Jan', 'Total Produk Prop Real Jan',
       'Comfee Prop Real Jan', 'Delta Total Net', 'Delta Total Produk Prop',
       'Delta Comfee Prop'], axis = 1)

prevmonth="July"
source = pd.read_csv(r"D:\6. settlement\Code\Settlement Project\Backup\Realisasi Jul 2024\Final Result\Raw Unpivoted\CSV\Runningan Blibli L-Men By Selcen Jan 2022 - Jul 2024.csv", sep = ';')

# source['True datetime'] = pd.to_datetime(source['True datetime'])
source = source[(source['Year'] > 2021)]

# selcen_sku['OrderId'] = selcen_sku['OrderId'].astype(str)
source['Order #'] = source['No. Order']#.astype(str)
source['Order #'] = source['Order #'].astype(str)
source['Real SKU'] = source['Real SKU'].astype(str)
total_trx_full['No. Order'] = total_trx_full['No. Order'].astype(str)

# selcen_old = selcen_sku[selcen_sku['OrderId'].isin(source['Order #'])]

source['Product Name'] = source['Product Name'].fillna(source['Real Nama Produk'])

source['Order #'] = source['Order #'].astype(str)

total_trx_full['Bundle Name'] = total_trx_full['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)
source['Bundle Name'] = source['Bundle Name'].astype(str).str.strip().str.replace('\\n', '', regex = False).str.replace('\n', '', regex = False)


dict_change = {'Buy 12 Get 12 ? HiLo School Chocolate RTD 200ml (ED 6 bulan)':'Buy 12 Get 12 – HiLo School Chocolate RTD 200ml (ED 6 bulan)'}

for key in dict_change:
    total_trx_full['Bundle Name'] = total_trx_full['Bundle Name'].astype(str).str.replace(key, dict_change[key], regex = False)
    source['Bundle Name'] = source['Bundle Name'].astype(str).str.replace(key, dict_change[key], regex = False)
    
               
total_trx_merge = total_trx_full.merge(source[['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Paid '+prevmonth,'Qty. Invoiced', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced']), how = 'left', left_on = ['No. Order', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'], right_on = ['Order #', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced'])

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

total_trx_null = total_trx_null.drop(['Order #', 'Paid '+prevmonth,'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net', 
                                                  'Total Produk Prop_x' : 'Total Produk Prop',
                                                  'Comfee Prop_x' : 'Comfee Prop'})

total_trx_null = total_trx_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Paid '+prevmonth,'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Product Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(total_trx_null.index) 
total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
total_trx_merge['Paid '+prevmonth][total_trx_null.index] = total_trx_null['Paid '+prevmonth]

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]

##### ini coba di komen apa ya, kyk sama dgn atas nya


total_trx_null = total_trx_null.drop(['Order #', 'Paid '+prevmonth,'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net',
                                                  'Total Produk Prop_x' : 'Total Produk Prop',
                                                  'Comfee Prop_x' : 'Comfee Prop'})

total_trx_null = total_trx_null.merge(source[['Order #', 'Real SKU', 'Bundle Name', 'Paid '+prevmonth,'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Real SKU', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Real SKU',  'Bundle Name'], right_on = ['Order #', 'Real SKU', 'Bundle Name']).set_index(total_trx_null.index) 
total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
total_trx_merge['Paid '+prevmonth][total_trx_null.index] = total_trx_null['Paid '+prevmonth]

total_trx_null = total_trx_merge[total_trx_merge['Total Net_y'].isnull()]


#### komen sampai sini 26 Mei 2022



# source2 = source.copy()

# source2['Real SKU'] = source2['Real SKU'].astype(str).str.replace('2309005305', '2309005300')

# # indeks = source2[source2['Real SKU'] == '(B)2101809250'].index.to_list()
# # source2['Real SKU'][indeks] = '(U)2101809250'

# # indeks = source2[source2['Real SKU'] == 'PH48(3)B35'].index.to_list()
# # source2['Real SKU'][indeks] = '2101941250P4'

# # indeks = source2[source2['Real SKU'] == 'PH39(3)B17'].index.to_list()
# # source2['Real SKU'][indeks] = '2101809250P4'

# total_trx_null = total_trx_null.drop(['Order #', 'Total Net_y', 'Total Produk Prop_y', 'Comfee Prop_y'], axis = 1)
# total_trx_null = total_trx_null.rename(columns = {'Total Net_x' : 'Total Net', 
#                                                   'Total Produk Prop_x' : 'Total Produk Prop',
#                                                   'Comfee Prop_x' : 'Comfee Prop'})

# total_trx_null = total_trx_null.merge(source[['Order #', 'Product Name', 'Bundle Name', 'Total Net', 'Total Produk Prop', 'Comfee Prop']].drop_duplicates(['Order #', 'Product Name', 'Bundle Name']), how = 'left', left_on = ['No. Order', 'Product Name',  'Bundle Name'], right_on = ['Order #', 'Product Name', 'Bundle Name']).set_index(total_trx_null.index) 
# total_trx_merge['Total Net_y'][total_trx_null.index] = total_trx_null['Total Net_y']
# total_trx_merge['Total Produk Prop_y'][total_trx_null.index] = total_trx_null['Total Produk Prop_y']
# total_trx_merge['Comfee Prop_y'][total_trx_null.index] = total_trx_null['Comfee Prop_y']
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## run 24

total_trx_merge['Paid Beda'] = np.nan

indeks = total_trx_merge[total_trx_merge['Paid'] != total_trx_merge['Paid '+prevmonth]].index.to_list()
total_trx_merge['Paid Beda'][indeks] = 'Beda'

total_trx_merge['Paid Beda'] = total_trx_merge['Paid Beda'].fillna('Sama')
# total_trx_merge[total_trx_merge['Paid Beda'] == 'Beda'][['Order #','Brand','Real SKU','Month', 'Paid_x', 'Paid_y', 'Paid Beda']]
total_trx_merge[total_trx_merge['Paid Beda']!='Sama'].groupby(['Month', 'Paid', 'Paid '+prevmonth], dropna = False)['No. Order'].nunique()
# Out:
# C:\Users\timotius.giovandi\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Month   Paid    Paid July
# August  Cancel  NaN           12
#         Paid    NaN          110
#         Unpaid  NaN           29
# July    Cancel  Unpaid         1
#                 NaN           11
#         Paid    Unpaid        32
#                 NaN          147
# Name: No. Order, dtype: int64

# %%
### run25
total_trx_merge = total_trx_merge.rename(columns = {'Paid' : 'Paid August'})

total_trx_merge = total_trx_merge.rename(columns = {'Total Produk Prop_x' : 'Total Produk Prop by Selcen', 
                                                   'Total Produk Prop_y' : 'Total Produk Prop Real Jan',
                                                   'Total Net_x' : 'Total Net by Selcen', 
                                                   'Total Net_y' : 'Total Net Real Jan',
                                                   'Fullfee Prop_x' : 'Fullfee Prop by Selcen', 
                                                   'Fullfee Prop_y' : 'Fullfee Prop Real Jan',
                                                   'Comfee Prop_x' : 'Comfee Prop by Selcen', 
                                                   'Comfee Prop_y' : 'Comfee Prop Real Jan'})

total_trx_merge['Delta Total Net'] = total_trx_merge['Total Net by Selcen'] - total_trx_merge['Total Net Real Jan']
total_trx_merge['Delta Total Produk Prop'] = total_trx_merge['Total Produk Prop by Selcen'] - total_trx_merge['Total Produk Prop Real Jan']
total_trx_merge['Delta Comfee Prop'] = total_trx_merge['Comfee Prop by Selcen'] - total_trx_merge['Comfee Prop Real Jan']

# %%
### run26
total_trx_merge = total_trx_merge.rename(columns = {'Total Produk Prop by Selcen': 'Total Produk Prop', 
                                                   'Total Net by Selcen' : 'Total Net', 
                                                   'Fullfee Prop by Selcen' : 'Fullfee Prop', 
                                                    'Fullfee' : 'Fullfee Prop', 
                                                    'Payment Fee' : 'Payment Fee Prop', 
                                                    'Others': 'Shipping Fee Prop',
                                                   'Comfee Prop by Selcen' : 'Comfee Prop'})


total_trx_merge = total_trx_merge.drop(['Order #', 'Total Net Real Jan', 'Total Produk Prop Real Jan',
       'Comfee Prop Real Jan', 'Delta Total Net', 'Delta Total Produk Prop',
       'Delta Comfee Prop'], axis = 1)

# %%
total_trx_merge['Disc 2 Faktur Pajak']=total_trx_merge['Fullfee Prop']
total_trx_merge['Disc 2 Non Faktur Pajak']=total_trx_merge['Shipping Fee Prop']+total_trx_merge['Payment Fee Prop']

# %%
## run27
hasilakhir=pd.read_excel("Settlement Project\Backup\Realisasi Oct 2022\Final Result\Raw Unpivoted\Excel\Runningan Blibli L-Men By Selcen Jan 2022 - Oct 2022.xlsx")

hasilakhir=hasilakhir.rename(columns={'Paid October':'Paid August'})
hasilakhir=hasilakhir.rename(columns={'Paid September':'Paid July'})


hasilakhir['Pemilik Budget']=np.nan
hasilakhir=hasilakhir.head(0)
hasilakhir=total_trx_merge[[x for x in total_trx_merge.columns if x in hasilakhir.columns]+['Shipping Fee Prop','Payment Fee Prop', 'Fullfee Prop','Disc 2 Faktur Pajak','Disc 2 Non Faktur Pajak']]
# hasilakhir=hasilakhir.append(total_trx_merge)

# %%
### run 28
hasilakhir.to_excel(r'Settlement Project\Backup\Realisasi Aug 2024\Final Result\Raw Unpivoted\Excel/Runningan Blibli L-Men By Selcen Jan 2022 - Aug 2024.xlsx', index = False)
hasilakhir.to_csv(r'Settlement Project\Backup\Realisasi Aug 2024\Final Result\Raw Unpivoted\CSV/Runningan Blibli L-Men By Selcen Jan 2022 - Aug 2024.csv', sep = ';', index = False)

# %%
################# selesai :) ######################

# %%
selcen_new[selcen_new['No. Order']=='12141942824']
# Out:
#          No. Order No. Order Item           No. Awb     Tanggal Order  \
# 11458  12141942824    12199467108  BLI2610235031751  07/11/2023 22:39
#
#          Nama Pemesan            Kode SKU             Blibli SKU         SKU  \
# 11458  Tommy Fadillah  MTA-42702739-00001  LMS-60022-00228-00001  2304576112
#
#                                              Nama Produk  Qty. Invoiced  ...  \
# 11458  L-Men Lose Weight Mango Sticky Rice 300g - Sup...              1  ...
#
#                  Nama Store Order Status           Toko/Gudang  \
# 11458  L-Men Official Store     Terkirim  Blibli, Medan Satria
#
#                                         Source Unnamed: 0 Date     Month  \
# 11458  bulk-order-download-template 202311.csv        NaN  7.0  November
#
#          Year        true datetime Pemilik Budget
# 11458  2023.0  2023-11-07 22:39:00       Internal
#
# [1 rows x 23 columns]

# %%
settlement[settlement['Order ID']=='12141942824']
# Out:
#        Trx ID     Order ID Order Item ID  \
# 12185     1.0  12141942824   12199467108
#
#                                               Keterangan Transaction  \
# 12185  L-Men Lose Weight Mango Sticky Rice 300g - Sup...       Sales
#
#                Delivered Date  Qty  Harga Satuan   Jumlah  Promosi Merchant  \
# 12185 2023-11-08 20:30:05.090  1.0       99000.0  99000.0               0.0
#
#        ...  Trx Source                                    Source  \
# 12185  ...      Online  20231108_LMS-60022_SettlementReport.xlsx
#
#        Jumlah Cancel  Fee Cancel  Others  Other Adjustment      Cek Selisih  \
# 12185            NaN         NaN     0.0               NaN  94050.0     0.0
#
#        Bi Produk  Comfee
# 12185    99000.0  4950.0
#
# [1 rows x 26 columns]
